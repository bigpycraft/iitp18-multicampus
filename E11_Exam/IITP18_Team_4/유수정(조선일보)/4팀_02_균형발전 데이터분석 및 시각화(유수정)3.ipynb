# %%
import nltk
from konlpy.tag import Hannanum
import pandas as pd
from time import sleep
import datetime

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook

# %%
df1 = pd.read_csv('./data/final_even.csv', encoding='utf-8')
df1.head(10)

df1['Date'][1][:-3]
# Out:
# '2018. 10. 31 '

# %%
for i in range(len(df1['Date'])):
    df1['Date'][i] = df1['Date'][i][:-3]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2 = pd.read_csv('./data/petition_crawling_equal_dev_with_body.csv', encoding='utf-8')
df2.head(10)
# Out:
#    Unnamed: 0                                               제목        청원시작  \
# 0           0  건전한 게임문화를 확립을 위하여 게임운영사의 게임내 게임 데이터판매응 처벌하여 주세요  2018-10-31
# 1           1                    서민경제 살리고 출산율도 높이는 필수  요소 2가지.  2018-10-31
# 2           2                     서민경제 살리고 출산율도 높이는 필수 요소 2가지.  2018-10-29
# 3           3                     5인 미만 회사는 직원을 마음대로 해고해도 되나요?  2018-10-29
# 4           4                   개인회생 소급적용  인천 의정부 수원은 왜 적용안되나요  2018-10-28
# 5           5                            육군사관학교를 지방으로 이전하여 주세요  2018-10-27
# 6           6                      공공기관 지방이전으로 국토의 균형발전을이루워주세요  2018-10-27
# 7           7                      DMZ에 유엔평화대학교를 설립하여 평화를 구축하자  2018-10-26
# 8           8                      공공기관 지방이전으로 국토의 균형발전을이루워주세요  2018-10-25
# 9           9                                           세가지 제안  2018-10-25
#
#   청원인원                                           Link  \
# 0    3  https://www1.president.go.kr/petitions/426949
# 1    4  https://www1.president.go.kr/petitions/426738
# 2    9  https://www1.president.go.kr/petitions/423705
# 3    7  https://www1.president.go.kr/petitions/423323
# 4   22  https://www1.president.go.kr/petitions/423175
# 5    4  https://www1.president.go.kr/petitions/422213
# 6    6  https://www1.president.go.kr/petitions/422210
# 7  302  https://www1.president.go.kr/petitions/420989
# 8    6  https://www1.president.go.kr/petitions/419942
# 9    3  https://www1.president.go.kr/petitions/419894
#
#                                                   본문
# 0  아래에 적시된 법률 어디에도 바둑이 바다이야기등에만 적용된다는 내용은 없습니다. 겜...
# 1  서민경제 살리고 출산율도 높이는 필수 중요  요소 2가지.  1......출산율이 ...
# 2  서민경제 살리고 출산율도 높이는 중요 요소 2가지.    1......출산율이 폭락...
# 3  저는 얼마 전 근무하던 회사로부터 아무런 이유 없이 해고 되었습니다.  너무나 억울...
# 4  개인회생 소급적용 왜 의정부 인천 수원은 불가한건가요 인천에서 아이둘 키우며 세금 ...
# 5  육군사관학교를 지방으로 이전하여 주세요 좁은 서울에 육군사관학교가 있어 서 불편합니...
# 6  공공기관 지방이전으로 침체된 지방경제를 활성화하고 국토의균형발전과 함께 삶의질을 향...
# 7  DMZ 유엔평화대학교 설립을 통합 평화 구축 손 기 웅(한국DMZ학회 회장) 1. ...
# 8  공공기관 지방이전으로 침체된 지방경제를 활성화하고 국토의균형발전과 함께 삶의질을 향...
# 9  1  1)경제정책에 대한 생각 요즘 범죄 등 사회분위기가 험악해지는데는 정부가 현실...

# %%
df3 = pd.read_csv('./data/균형발전.csv', encoding='utf-8')
df3.head(10)
# Out:
#    Unnamed: 0                                     Title        Date
# 0           0                새만금개발공사 설립...매립, 도시조성 본격화   2018.10.30
# 1           1        “공공기관 지역인재 채용 2022년까지 30%로 늘릴것”     2018.10.30
# 2           2           ‘KTX 세종역’ 공방 확산…충북-호남 ‘세대결’ 조짐   2018.10.30
# 3           3   “은행, 지역 돈 지역에 재투자해야”…지자체·법원 금고선정에도 반영    2018.10.29
# 4           4                시도별 혁신거점 ‘국가혁신클러스터’ 본격 시동   2018.10.25
# 5           5        4조3천억 투입…“10개 혁신도시, 지역성장 거점으로 육성”   2018.10.25
# 6           6               지자체 39% 생존위기…돈맥경화 풀어줄 해법은?   2018.10.25
# 7           7                    136년 역사 인천 개항장이 되살아난다   2018.10.25
# 8           8            충남도 조직개편안…‘새마을’ 지우고 ‘남북교류’ 신설   2018.10.25
# 9           9    “유혹 느껴도 참는다” 했는데, 결국 ‘SOC’에 SOS 친 정부    2018.10.24

# %%
for k in range(len(df1['Date'])):
    df1['Date'][k] = df1['Date'][k].replace(' ',"")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# plt.figure(figsize=(10,4))
# cho_even.plot(50)     # Plot sorted frequency of top 50 tokens
# plt.show()

# %%
df1['date'] = df1['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d'))

# %%
df2['date'] = df2['청원시작'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d'))

# %%
df2
# Out:
#      Unnamed: 0                                                 제목  \
# 0             0    건전한 게임문화를 확립을 위하여 게임운영사의 게임내 게임 데이터판매응 처벌하여 주세요
# 1             1                      서민경제 살리고 출산율도 높이는 필수  요소 2가지.
# 2             2                       서민경제 살리고 출산율도 높이는 필수 요소 2가지.
# 3             3                       5인 미만 회사는 직원을 마음대로 해고해도 되나요?
# 4             4                     개인회생 소급적용  인천 의정부 수원은 왜 적용안되나요
# 5             5                              육군사관학교를 지방으로 이전하여 주세요
# 6             6                        공공기관 지방이전으로 국토의 균형발전을이루워주세요
# 7             7                        DMZ에 유엔평화대학교를 설립하여 평화를 구축하자
# 8             8                        공공기관 지방이전으로 국토의 균형발전을이루워주세요
# 9             9                                             세가지 제안
# 10           10                         신분당선 호매실역 원안대로 하루빨리 착공해주세요
# 11           11  '문재인 대통령'이 속도조절 해야한다는 여론이 높으나 '핵 폐기와 북미관계'에는 매...
# 12           12                                   국회를 세종시로 이전해 주세요
# 13           13                                   새만금에 날개를 달아 주세요!
# 14           14                                    평화의섬 건립을 제안합니다.
# 15           15                     박원순 시장님!! 이러다 서울 망하고 서민들 죽어납니다
# 16           16  주한미군 철수.. 재벌타도.. 반미 친북..  씨벌 내가 낸 피 같은 세금으로 북한...
# 17           17         서안양친환경융합테크노밸리 (박달테크노밸리) 조성사업의 조속한 추진을 원합니다
# 18           18                         ★ 일자리도 없는데 안락사 도입좀 해주세요!!!
# 19           19  제발 한번만 읽어주시기 부탁드립니다. 범죄자의 과한 인권보호와 아동청소년들의 문제 ...
# 20           20                           귀농,귀촌 시 갑질하는 발전기금을 막아주세요
# 21           21                                수도권인구분산 추진해 부동산 잡자!
# 22           22              주식 시장에서 공모주 개인 배정 물량의 입법화를 강력히 요청합니다.
# 23           23                                          부동산정책과 기업
# 24           24                        공공기관 지방이전으로 국토의 균형발전을이루워주세요
# 25           25  후보지만 지정해 놓고 스톱 상태인 대형국책사업인 대구공항이전을 진행하지 않으면 정부...
# 26           26                                  국가 균형발전및 지방활성화 방안
# 27           27    서울 주거 문제, 대학 등록금, 지역균형발전을 위해 거점국립대 집중육성을 제안합니다.
# 28           28                                             여가부 폐지
# 29           29  서울시내 변두리 지역부터 재개발 재건축 다시 시작하자! 3기신도시는 방향이 잘못됬습니다.
# ..          ...                                                ...
# 615         615                       정부는 암호화화폐를 전혀 이해하지 못하고 있습니다.
# 616         616                                      강남집값만 폭등하는 나라
# 617         617                              강남3구 아파트 가격 안전화 방안 제안
# 618         618                                 자신있게살자는데 그게 잘 안됩니다
# 619         619           법무부 장관님, 과연 미래를 감당할 자신이 있습니까??(꼭 읽어주세요!)
# 620         620                          개인회생 기간단축 소급에 관한 법원의 입장표명
# 621         621                                한 해 수십조원 비용 절감 효과+a
# 622         622                             전자파 발생되는 전기장판은 판매금지 요망
# 623         623                 블록체인, 암호화폐의 철학과 시대적 흐름을 준비해야 합니다!!
# 624         624                                      지방 사람들좀 살려주세요
# 625         625                      건설기술진흥법 및 국토부훈령에 대한 일부내용 개선요구
# 626         626                    서민들에게 희망을 주는 가상화폐 거래소 폐지 합당할까요?
# 627         627                            모든 도박관련 거래 금지 특별법 추진 요구
# 628         628                  제4차 산업혁명 가상화폐를 불법투기세력으로 부터 지켜주세요.
# 629         629                        당신들의 이익때문에 203040세대를 죽이지마십쇼
# 630         630                             김천혁신도시의 정주여건 개선을 위한 건의
# 631         631    핌피, 님비 등의 지역이기주의를 제한할 수 있는 정책 또는 법안, 조례가 필요합니다.
# 632         632                             세계전략하의 신남방정책, 신북방정책 소고
# 633         633                             미친 집값(부동산) 잡을 역량이 있나요?
# 634         634                             18년전 밀레니엄 버그는 해결되었습니까?
# 635         635               신남방정책, 신북방정책을 아우르는 세계전략, 한번쯤 생각해볼 필요
# 636         636                             가상화폐 제도화 시켜서 활성시켜야합니다.
# 637         637                                   신탄진역에 ktx 세워 주세요
# 638         638         지방분권 및 수도권 과밀을 억제하기위해서는 공공기관의 지방이전이 필수적입니다
# 639         639                                충북 혁신도시 통근버스를 없애주세요
# 640         640                                    지역할당제의 사각지대(대전)
# 641         641               신남방정책,신북방정책을 제대로 추진하려면 외교부 체제부터 변경해야
# 642         642                                수자원공사 인권침해 및 부당노동행위
# 643         643                                    세종시 부동산들 단속해주세요
# 626  복권, 주식, 강원랜드는 모두 내가 가진 자본을 늘리고 싶다는 공통된 희망이 있는 ... 2018-01-11
# 627  금일 법무장관은 가상화폐에 대해  "국가산업 발전에 긍정적 측면보다는 특히 개인의 ... 2018-01-11
# 628  1. 배경 : 가상화폐는 4차 산업혁으로 비유될 만큼, 미래를 바꿀 혁신적인 기술로... 2018-01-11
# 629  어느 금융권 종사자가 쓴 글을 읽으면서 다시 한번 우리나라 코인시장의 문제가 무엇이... 2018-01-11
# 630  안녕하십니까? 저는 김천 혁신도시에서 거주하며 장사를 업으로 하고 있는 한 시민입니... 2018-01-11
# 631  현재 우리나라에는 많은 님비와 핌피 등의 지역이기주의가 있습니다, 그런데 이 지역이... 2018-01-10
# 632  저는 신남방정책이니 신북방정책이니를 떠나서, "한국의 세계전략"을 먼저 고민해 보고... 2018-01-09
# 633  노무현정부때와 마찬가지로 또 얼치기 정책으로 오히려 집값에 부채질만 하고 있군요. ... 2018-01-09
# 634  Ⅰ. 25년전 세계환경의 날을 맞이하여 환경보전을 위한 국가선언 전문 25년전 ’9... 2018-01-09
# 635  저는 신남방정책이니 신북방정책이니를 떠나서, "한국의 세계전략"을 먼저 고민해 보고... 2018-01-08
# 636  미국,일본등 여러나라가 벌써 가상화폐를 만들고 활성화 시켜가고 있습니다. 우리나라 ... 2018-01-08
# 637  젊은 날 생업차 울산에 와서 살지만 고향이 대전근교(논산시 양촌면)라 노후에는 대전... 2018-01-08
# 638  오늘 “정부 수도권 공공기관 추가 지방이전 백지화”라는 뉴스기사를 읽엇습니다 htt... 2018-01-05
# 639  왜 혈세를 낭비하십니까? 혁신도시  설립 목적이 지역 발전 균형이라했는데 충북 혁신... 2018-01-05
# 640  지역 할당제가 간단히 혁신도시로 이전하는 공기업이 그 지역 청년의 30%를 체용하는... 2018-01-04
# 641  신 외교 전략 :  바다에 기초한 새로운 바운더리 전략              A.... 2018-01-04
# 642  수자원 공사에서의 본인의 생활기록부 1987년 2월 초순 동기들과의 보람된 연수일정... 2018-01-04
# 643  국토균형발전의 취지를 너무나 동감하며 이전 공무원도 아니지만 어렵게 타지에서 세종시... 2018-01-01
# 644  현 정부 들어 국토부에서 ‘국토 균형 발전’ 기조에 맞지 않는 정책들이 다수 나와서... 2018-01-01
#
# [645 rows x 7 columns]

# %%
df3['date'] = df3['Date'].apply(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d'))

# %%
try:
    plt.figure(figsize=(10,5))
    df1.groupby('date').size().plot(color = 'r')
    df3.groupby('date').size().plot(color = 'g')
    df2.groupby('date').size().plot(color = 'b')
    plt.legend(('조선일보','한겨레','청원게시판'))
    date1 = datetime.datetime(2018,9,11)
    plt.annotate('9.11 부동산대책', xy=("2018-09-11", 12.5), xytext=("2018-09-20",10),
                    arrowprops=dict(facecolor='black', shrink=0.1),fontsize = 10, color = "black"
                    )
except: pass
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
? plt.legend

# %%
pet_even = pd.read_csv('./data/petition_crawling_equal_dev_hannanum_nouns.csv', sep=',', encoding='euc-kr')
p_e = pet_even.head(11)
p_e = p_e.drop(1,0)
p_e
# Out:
#     Unnamed: 0     0   1
# 0            0    서울  47
# 2            2    집값  34
# 3            3    지방  32
# 4            4    이전  31
# 5            5   부동산  31
# 6            6    개혁  28
# 7            7  공공기관  26
# 8            8    발전  26
# 9            9   세종시  25
# 10          10    정책  25

# %%
plt.figure(figsize=(5,5))

plt.pie(p_e['1'], 
        
        labels  = p_e['0'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )
# plt.legend(p_e['0'], loc=1, prop={'size': 5})
plt.title("\n청원게시판 '균형발전' 키워드10\n", fontsize=20)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
han_even = pd.read_csv('./data/df_balancecommon.csv', sep=',', encoding='euc-kr')
h_e = han_even.head(10)
type(h_e)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(5,5))

plt.pie(h_e['빈도'], 
        
        labels  = h_e['키워드'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )
# plt.legend(h_e['키워드'], loc=1)
plt.title("\n한겨레 '균형발전' 키워드10\n", fontsize=20)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
cho_even = pd.read_csv('./data/cho_even.csv', sep=',', encoding='euc-kr')
c_e = cho_even.head(10)
type(c_e)
# Out:
# pandas.core.frame.DataFrame

# %%
c_e.columns = ['0','키워드','빈도']
c_e
# Out:
#    0   키워드  빈도
# 0  0    세종   6
# 1  1  공공기관   5
# 2  2    미래   5
# 3  3    지방   4
# 4  4    이전   4
# 5  5   박원순   4
# 6  6    국민   3
# 7  7    기업   3
# 8  8   이해찬   3
# 9  9    사장   3

# %%
plt.figure(figsize=(5,5))

plt.pie(h_e['빈도'], 
        
        labels  = h_e['키워드'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )
# plt.legend(h_e['키워드'], loc=1)
plt.title("\n조선일보 '균형발전' 키워드10\n", fontsize=20)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure(figsize=(10,7))
plt.subplots_adjust(hspace = 0.7, wspace = 0.3) 
plt.subplot(211) 

df1.groupby('date').size().plot(color = 'r')
df3.groupby('date').size().plot(color = 'g')
df2.groupby('date').size().plot(color = 'b')
plt.legend(('조선일보','한겨레','청원게시판'))

plt.subplot(234) 
plt.pie(h_e['빈도'], 
        
        labels  = h_e['키워드'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )

plt.title("\n조선일보 ", fontsize=10)
plt.subplot(235)
plt.pie(h_e['빈도'], 
        
        labels  = h_e['키워드'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )

plt.title("\n한겨레 \n", fontsize=10)



plt.subplot(236)
plt.pie(p_e['1'], 
        
        labels  = p_e['0'],
        autopct = '%.1f%%', 
        shadow  = False, 
        startangle = 270,
       
       )
# plt.legend(p_e['0'], loc=1, prop={'size': 5})
plt.title("\n청원게시판\n", fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'\n청원게시판\n')
