# %%
import nltk
from konlpy.tag import Hannanum
import pandas as pd
from time import sleep
import datetime

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df2 = pd.read_csv("./work2.csv", encoding = "utf-8")

# %%
titlework = []

for i in df2["제목"]:
    if "최저임금" in i:
        titlework.append(i)
        
    else:
        pass

# %%
titlework2 = []

for i in df2["제목"]:
    if "정규직" in i:
        titlework.append(i)
        
    else:
        pass

# %%
han = Hannanum()

# %%
nounswork = []
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120
# 형태소 분석 시작121
# 형태소 분석 시작122
# 형태소 분석 시작123
# 형태소 분석 시작124
# 형태소 분석 시작125
# 형태소 분석 시작126
# 형태소 분석 시작127
# 형태소 분석 시작128
# 형태소 분석 시작129
# 형태소 분석 시작130
# 형태소 분석 시작131
# 형태소 분석 시작132
# 형태소 분석 시작133
# 형태소 분석 시작134
# 형태소 분석 시작135
# 형태소 분석 시작136
# 형태소 분석 시작137
# 형태소 분석 시작138
# 형태소 분석 시작139
# 형태소 분석 시작140
# 형태소 분석 시작141
# 형태소 분석 시작142
# 형태소 분석 시작143
# 형태소 분석 시작144
# 형태소 분석 시작145
# 형태소 분석 시작146
# 형태소 분석 시작147
# 형태소 분석 시작148
# 형태소 분석 시작149
# 형태소 분석 시작150
# 형태소 분석 시작151
# 형태소 분석 시작152
# 형태소 분석 시작153
# 형태소 분석 시작154
# 형태소 분석 시작155
# 형태소 분석 시작156
# 형태소 분석 시작157
# 형태소 분석 시작158
# 형태소 분석 시작159
# 형태소 분석 시작160
# 형태소 분석 시작161
# 형태소 분석 시작162
# 형태소 분석 시작163
# 형태소 분석 시작164
# 형태소 분석 시작165
# 형태소 분석 시작166
# 형태소 분석 시작167
# 형태소 분석 시작168
# 형태소 분석 시작169
# 형태소 분석 시작170
# 형태소 분석 시작171
# 형태소 분석 시작172
# 형태소 분석 시작173
# 형태소 분석 시작174
# 형태소 분석 시작175
# 형태소 분석 시작176
# 형태소 분석 시작177
# 형태소 분석 시작178
# 형태소 분석 시작179
# 형태소 분석 시작180
# 형태소 분석 시작181
# 형태소 분석 시작182
# 형태소 분석 시작183
# 형태소 분석 시작184
# 형태소 분석 시작185
# 형태소 분석 시작186
# 형태소 분석 시작187
# 형태소 분석 시작188
# 형태소 분석 시작189
# 형태소 분석 시작190
# 형태소 분석 시작191
# 형태소 분석 시작192
# 형태소 분석 시작193
# 형태소 분석 시작194
# 형태소 분석 시작195
# 형태소 분석 시작196
# 형태소 분석 시작197
# 형태소 분석 시작198
# 형태소 분석 시작199
# 형태소 분석 시작200
# 형태소 분석 시작201
# 형태소 분석 시작202
# 형태소 분석 시작203
# 형태소 분석 시작204
# 형태소 분석 시작205
# 형태소 분석 시작206
# 형태소 분석 시작207
# 형태소 분석 시작208
# 형태소 분석 시작209
# 형태소 분석 시작210
# 형태소 분석 시작211
# 형태소 분석 시작212
# 형태소 분석 시작213
# 형태소 분석 시작214
# 형태소 분석 시작215
# 형태소 분석 시작216
# 형태소 분석 시작217
# 형태소 분석 시작218
# 형태소 분석 시작219
# 형태소 분석 시작220
# 형태소 분석 시작221
# 형태소 분석 시작222
# 형태소 분석 시작223
# 형태소 분석 시작224
# 형태소 분석 시작225
# 형태소 분석 시작226
# 형태소 분석 시작227
# 형태소 분석 시작228
# 형태소 분석 시작229
# 형태소 분석 시작230
# 형태소 분석 시작231
# 형태소 분석 시작232
# 형태소 분석 시작233
# 형태소 분석 시작234
# 형태소 분석 시작235
# 형태소 분석 시작236
# 형태소 분석 시작237
# 형태소 분석 시작238
# 형태소 분석 시작239
# 형태소 분석 시작240
# 형태소 분석 시작241
# 형태소 분석 시작242
# 형태소 분석 시작243
# 형태소 분석 시작244
# 형태소 분석 시작245
# 형태소 분석 시작246
# 형태소 분석 시작247
# 형태소 분석 시작248
# 형태소 분석 시작249
# 형태소 분석 시작250
# 형태소 분석 시작251
# 형태소 분석 시작252
# 형태소 분석 시작253
# 형태소 분석 시작254
# 형태소 분석 시작255
# 형태소 분석 시작256
# 형태소 분석 시작257
# 형태소 분석 시작258
# 형태소 분석 시작259
# 형태소 분석 시작260
# 형태소 분석 시작261
# 형태소 분석 시작262
# 형태소 분석 시작263
# 형태소 분석 시작264
# 형태소 분석 시작265
# 형태소 분석 시작266
# 형태소 분석 시작267
# 형태소 분석 시작268
# 형태소 분석 시작269
# 형태소 분석 시작270
# 형태소 분석 시작271
# 형태소 분석 시작272
# 형태소 분석 시작273
# 형태소 분석 시작274
# 형태소 분석 시작275
# 형태소 분석 시작276
# 형태소 분석 시작277
# 형태소 분석 시작278
# 형태소 분석 시작279
# 형태소 분석 시작280
# 형태소 분석 시작281
# 형태소 분석 시작282
# 형태소 분석 시작283
# 형태소 분석 시작284
# 형태소 분석 시작285
# 형태소 분석 시작286
# 형태소 분석 시작287
# 형태소 분석 시작288
# 형태소 분석 시작289
# 형태소 분석 시작290
# 형태소 분석 시작291
# 형태소 분석 시작292
# 형태소 분석 시작293
# 형태소 분석 시작294
# 형태소 분석 시작295
# 형태소 분석 시작296
# 형태소 분석 시작297
# 형태소 분석 시작298
# 형태소 분석 시작299
# 형태소 분석 시작300
# 형태소 분석 시작301
# 형태소 분석 시작302
# 형태소 분석 시작303
# 형태소 분석 시작304
# 형태소 분석 시작305
# 형태소 분석 시작306
# 형태소 분석 시작307
# 형태소 분석 시작308
# 형태소 분석 시작309
# 형태소 분석 시작310
# 형태소 분석 시작311
# 형태소 분석 시작312
# 형태소 분석 시작313
# 형태소 분석 시작314
# 형태소 분석 시작315
# 형태소 분석 시작316
# 형태소 분석 시작317
# 형태소 분석 시작318
# 형태소 분석 시작319
# 형태소 분석 시작320
# 형태소 분석 시작321
# 형태소 분석 시작322
# 형태소 분석 시작323
# 형태소 분석 시작324
# 형태소 분석 시작325
# 형태소 분석 시작326
# 형태소 분석 시작327
# 형태소 분석 시작328
# 형태소 분석 시작329
# 형태소 분석 시작330
# 형태소 분석 시작331
# 형태소 분석 시작332
# 형태소 분석 시작333
# 형태소 분석 시작334
# 형태소 분석 시작335
# 형태소 분석 시작336
# 형태소 분석 시작337
# 형태소 분석 시작338
# 형태소 분석 시작339
# 형태소 분석 시작340
# 형태소 분석 시작341
# 형태소 분석 시작342
# 형태소 분석 시작343
# 형태소 분석 시작344
# 형태소 분석 시작345
# 형태소 분석 시작346
# 형태소 분석 시작347
# 형태소 분석 시작348
# 형태소 분석 시작349
# 형태소 분석 시작350
# 형태소 분석 시작351
# 형태소 분석 시작352
# 형태소 분석 시작353
# 형태소 분석 시작354
# 형태소 분석 시작355
# 형태소 분석 시작356
# 형태소 분석 시작357
# 형태소 분석 시작358
# 형태소 분석 시작359
# 형태소 분석 시작360
# 형태소 분석 시작361
# 형태소 분석 시작362
# 형태소 분석 시작363
# 형태소 분석 시작364
# 형태소 분석 시작365
# 형태소 분석 시작366
# 형태소 분석 시작367
# 형태소 분석 시작368
# 형태소 분석 시작369
# 형태소 분석 시작370
# 형태소 분석 시작371
# 형태소 분석 시작372
# 형태소 분석 시작373
# 형태소 분석 시작374
# 형태소 분석 시작375
# 형태소 분석 시작376
# 형태소 분석 시작377
# 형태소 분석 시작378
# 형태소 분석 시작379
# 형태소 분석 시작380
# 형태소 분석 시작381
# 형태소 분석 시작382
# 형태소 분석 시작383
# 형태소 분석 시작384
# 형태소 분석 시작385
# 형태소 분석 시작386
# 형태소 분석 시작387
# 형태소 분석 시작388
# 형태소 분석 시작389
# 형태소 분석 시작390
# 형태소 분석 시작391
# 형태소 분석 시작392
# 형태소 분석 시작393
# 형태소 분석 시작394
# 형태소 분석 시작395
# 형태소 분석 시작396
# 형태소 분석 시작397
# 형태소 분석 시작398
# 형태소 분석 시작399
# 형태소 분석 시작400
# 형태소 분석 시작401
# 형태소 분석 시작402
# 형태소 분석 시작403
# 형태소 분석 시작404
# 형태소 분석 시작405
# 형태소 분석 시작406
# 형태소 분석 시작407
# 형태소 분석 시작408
# 형태소 분석 시작409
# 형태소 분석 시작410
# 형태소 분석 시작411
# 형태소 분석 시작412
# 형태소 분석 시작413
# 형태소 분석 시작414
# 형태소 분석 시작415
# 형태소 분석 시작416
# 형태소 분석 시작417
# 형태소 분석 시작418
# 형태소 분석 시작419
# 형태소 분석 시작420
# 형태소 분석 시작421
# 형태소 분석 시작422
# 형태소 분석 시작423
# 형태소 분석 시작424
# 형태소 분석 시작425
# 형태소 분석 시작426
# 형태소 분석 시작427
# 형태소 분석 시작428
# 형태소 분석 시작429
# 형태소 분석 시작430
# 형태소 분석 시작431
# 형태소 분석 시작432
# 형태소 분석 시작433
# 형태소 분석 시작434
# 형태소 분석 시작435
# 형태소 분석 시작436
# 형태소 분석 시작437

# %%
nounswork2 = []
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120
# 형태소 분석 시작121
# 형태소 분석 시작122
# 형태소 분석 시작123
# 형태소 분석 시작124
# 형태소 분석 시작125
# 형태소 분석 시작126
# 형태소 분석 시작127
# 형태소 분석 시작128
# 형태소 분석 시작129
# 형태소 분석 시작130
# 형태소 분석 시작131
# 형태소 분석 시작132
# 형태소 분석 시작133
# 형태소 분석 시작134
# 형태소 분석 시작135
# 형태소 분석 시작136
# 형태소 분석 시작137
# 형태소 분석 시작138
# 형태소 분석 시작139
# 형태소 분석 시작140
# 형태소 분석 시작141
# 형태소 분석 시작142
# 형태소 분석 시작143
# 형태소 분석 시작144
# 형태소 분석 시작145
# 형태소 분석 시작146
# 형태소 분석 시작147
# 형태소 분석 시작148
# 형태소 분석 시작149
# 형태소 분석 시작150
# 형태소 분석 시작151
# 형태소 분석 시작152
# 형태소 분석 시작153
# 형태소 분석 시작154
# 형태소 분석 시작155
# 형태소 분석 시작156
# 형태소 분석 시작157
# 형태소 분석 시작158
# 형태소 분석 시작159
# 형태소 분석 시작160
# 형태소 분석 시작161
# 형태소 분석 시작162
# 형태소 분석 시작163
# 형태소 분석 시작164
# 형태소 분석 시작165
# 형태소 분석 시작166
# 형태소 분석 시작167
# 형태소 분석 시작168
# 형태소 분석 시작169
# 형태소 분석 시작170
# 형태소 분석 시작171
# 형태소 분석 시작172
# 형태소 분석 시작173
# 형태소 분석 시작174
# 형태소 분석 시작175
# 형태소 분석 시작176
# 형태소 분석 시작177
# 형태소 분석 시작178
# 형태소 분석 시작179
# 형태소 분석 시작180
# 형태소 분석 시작181
# 형태소 분석 시작182
# 형태소 분석 시작183
# 형태소 분석 시작184
# 형태소 분석 시작185
# 형태소 분석 시작186
# 형태소 분석 시작187
# 형태소 분석 시작188
# 형태소 분석 시작189
# 형태소 분석 시작190
# 형태소 분석 시작191
# 형태소 분석 시작192
# 형태소 분석 시작193
# 형태소 분석 시작194
# 형태소 분석 시작195
# 형태소 분석 시작196
# 형태소 분석 시작197
# 형태소 분석 시작198
# 형태소 분석 시작199
# 형태소 분석 시작200
# 형태소 분석 시작201
# 형태소 분석 시작202
# 형태소 분석 시작203
# 형태소 분석 시작204
# 형태소 분석 시작205
# 형태소 분석 시작206
# 형태소 분석 시작207
# 형태소 분석 시작208
# 형태소 분석 시작209
# 형태소 분석 시작210
# 형태소 분석 시작211
# 형태소 분석 시작212
# 형태소 분석 시작213
# 형태소 분석 시작214
# 형태소 분석 시작215
# 형태소 분석 시작216
# 형태소 분석 시작217
# 형태소 분석 시작218
# 형태소 분석 시작219
# 형태소 분석 시작220
# 형태소 분석 시작221
# 형태소 분석 시작222
# 형태소 분석 시작223
# 형태소 분석 시작224
# 형태소 분석 시작225
# 형태소 분석 시작226
# 형태소 분석 시작227
# 형태소 분석 시작228
# 형태소 분석 시작229
# 형태소 분석 시작230
# 형태소 분석 시작231
# 형태소 분석 시작232
# 형태소 분석 시작233
# 형태소 분석 시작234
# 형태소 분석 시작235
# 형태소 분석 시작236
# 형태소 분석 시작237
# 형태소 분석 시작238
# 형태소 분석 시작239
# 형태소 분석 시작240
# 형태소 분석 시작241
# 형태소 분석 시작242
# 형태소 분석 시작243
# 형태소 분석 시작244
# 형태소 분석 시작245
# 형태소 분석 시작246
# 형태소 분석 시작247
# 형태소 분석 시작248
# 형태소 분석 시작249
# 형태소 분석 시작250
# 형태소 분석 시작251
# 형태소 분석 시작252
# 형태소 분석 시작253
# 형태소 분석 시작254
# 형태소 분석 시작255
# 형태소 분석 시작256
# 형태소 분석 시작257
# 형태소 분석 시작258
# 형태소 분석 시작259
# 형태소 분석 시작260
# 형태소 분석 시작261
# 형태소 분석 시작262
# 형태소 분석 시작263
# 형태소 분석 시작264
# 형태소 분석 시작265
# 형태소 분석 시작266
# 형태소 분석 시작267
# 형태소 분석 시작268
# 형태소 분석 시작269
# 형태소 분석 시작270
# 형태소 분석 시작271
# 형태소 분석 시작272
# 형태소 분석 시작273
# 형태소 분석 시작274
# 형태소 분석 시작275
# 형태소 분석 시작276
# 형태소 분석 시작277
# 형태소 분석 시작278
# 형태소 분석 시작279
# 형태소 분석 시작280
# 형태소 분석 시작281
# 형태소 분석 시작282
# 형태소 분석 시작283
# 형태소 분석 시작284
# 형태소 분석 시작285
# 형태소 분석 시작286
# 형태소 분석 시작287
# 형태소 분석 시작288
# 형태소 분석 시작289
# 형태소 분석 시작290
# 형태소 분석 시작291
# 형태소 분석 시작292
# 형태소 분석 시작293
# 형태소 분석 시작294
# 형태소 분석 시작295
# 형태소 분석 시작296
# 형태소 분석 시작297
# 형태소 분석 시작298
# 형태소 분석 시작299
# 형태소 분석 시작300
# 형태소 분석 시작301
# 형태소 분석 시작302
# 형태소 분석 시작303
# 형태소 분석 시작304
# 형태소 분석 시작305
# 형태소 분석 시작306
# 형태소 분석 시작307
# 형태소 분석 시작308
# 형태소 분석 시작309
# 형태소 분석 시작310
# 형태소 분석 시작311
# 형태소 분석 시작312
# 형태소 분석 시작313
# 형태소 분석 시작314
# 형태소 분석 시작315
# 형태소 분석 시작316
# 형태소 분석 시작317
# 형태소 분석 시작318
# 형태소 분석 시작319
# 형태소 분석 시작320
# 형태소 분석 시작321
# 형태소 분석 시작322
# 형태소 분석 시작323
# 형태소 분석 시작324
# 형태소 분석 시작325
# 형태소 분석 시작326
# 형태소 분석 시작327
# 형태소 분석 시작328
# 형태소 분석 시작329
# 형태소 분석 시작330
# 형태소 분석 시작331
# 형태소 분석 시작332
# 형태소 분석 시작333
# 형태소 분석 시작334
# 형태소 분석 시작335
# 형태소 분석 시작336
# 형태소 분석 시작337
# 형태소 분석 시작338
# 형태소 분석 시작339
# 형태소 분석 시작340
# 형태소 분석 시작341
# 형태소 분석 시작342
# 형태소 분석 시작343
# 형태소 분석 시작344
# 형태소 분석 시작345
# 형태소 분석 시작346
# 형태소 분석 시작347
# 형태소 분석 시작348
# 형태소 분석 시작349
# 형태소 분석 시작350
# 형태소 분석 시작351
# 형태소 분석 시작352
# 형태소 분석 시작353
# 형태소 분석 시작354
# 형태소 분석 시작355
# 형태소 분석 시작356
# 형태소 분석 시작357
# 형태소 분석 시작358
# 형태소 분석 시작359
# 형태소 분석 시작360
# 형태소 분석 시작361
# 형태소 분석 시작362
# 형태소 분석 시작363
# 형태소 분석 시작364
# 형태소 분석 시작365
# 형태소 분석 시작366
# 형태소 분석 시작367
# 형태소 분석 시작368
# 형태소 분석 시작369
# 형태소 분석 시작370
# 형태소 분석 시작371
# 형태소 분석 시작372
# 형태소 분석 시작373
# 형태소 분석 시작374
# 형태소 분석 시작375
# 형태소 분석 시작376
# 형태소 분석 시작377
# 형태소 분석 시작378
# 형태소 분석 시작379
# 형태소 분석 시작380
# 형태소 분석 시작381
# 형태소 분석 시작382
# 형태소 분석 시작383
# 형태소 분석 시작384
# 형태소 분석 시작385
# 형태소 분석 시작386
# 형태소 분석 시작387
# 형태소 분석 시작388
# 형태소 분석 시작389
# 형태소 분석 시작390
# 형태소 분석 시작391
# 형태소 분석 시작392
# 형태소 분석 시작393
# 형태소 분석 시작394
# 형태소 분석 시작395
# 형태소 분석 시작396
# 형태소 분석 시작397
# 형태소 분석 시작398
# 형태소 분석 시작399
# 형태소 분석 시작400
# 형태소 분석 시작401
# 형태소 분석 시작402
# 형태소 분석 시작403
# 형태소 분석 시작404
# 형태소 분석 시작405
# 형태소 분석 시작406
# 형태소 분석 시작407
# 형태소 분석 시작408
# 형태소 분석 시작409
# 형태소 분석 시작410
# 형태소 분석 시작411
# 형태소 분석 시작412
# 형태소 분석 시작413
# 형태소 분석 시작414
# 형태소 분석 시작415
# 형태소 분석 시작416
# 형태소 분석 시작417
# 형태소 분석 시작418
# 형태소 분석 시작419
# 형태소 분석 시작420
# 형태소 분석 시작421
# 형태소 분석 시작422
# 형태소 분석 시작423
# 형태소 분석 시작424
# 형태소 분석 시작425
# 형태소 분석 시작426
# 형태소 분석 시작427
# 형태소 분석 시작428
# 형태소 분석 시작429
# 형태소 분석 시작430
# 형태소 분석 시작431
# 형태소 분석 시작432
# 형태소 분석 시작433
# 형태소 분석 시작434
# 형태소 분석 시작435
# 형태소 분석 시작436
# 형태소 분석 시작437
# 형태소 분석 시작438
# 형태소 분석 시작439
# 형태소 분석 시작440
# 형태소 분석 시작441
# 형태소 분석 시작442
# 형태소 분석 시작443
# 형태소 분석 시작444
# 형태소 분석 시작445
# 형태소 분석 시작446
# 형태소 분석 시작447
# 형태소 분석 시작448
# 형태소 분석 시작449
# 형태소 분석 시작450
# 형태소 분석 시작451
# 형태소 분석 시작452
# 형태소 분석 시작453
# 형태소 분석 시작454
# 형태소 분석 시작455
# 형태소 분석 시작456
# 형태소 분석 시작457
# 형태소 분석 시작458
# 형태소 분석 시작459
# 형태소 분석 시작460
# 형태소 분석 시작461
# 형태소 분석 시작462
# 형태소 분석 시작463
# 형태소 분석 시작464
# 형태소 분석 시작465
# 형태소 분석 시작466
# 형태소 분석 시작467
# 형태소 분석 시작468
# 형태소 분석 시작469
# 형태소 분석 시작470
# 형태소 분석 시작471
# 형태소 분석 시작472
# 형태소 분석 시작473
# 형태소 분석 시작474
# 형태소 분석 시작475
# 형태소 분석 시작476
# 형태소 분석 시작477
# 형태소 분석 시작478
# 형태소 분석 시작479
# 형태소 분석 시작480
# 형태소 분석 시작481
# 형태소 분석 시작482
# 형태소 분석 시작483
# 형태소 분석 시작484
# 형태소 분석 시작485
# 형태소 분석 시작486
# 형태소 분석 시작487
# 형태소 분석 시작488
# 형태소 분석 시작489
# 형태소 분석 시작490
# 형태소 분석 시작491
# 형태소 분석 시작492
# 형태소 분석 시작493
# 형태소 분석 시작494
# 형태소 분석 시작495
# 형태소 분석 시작496
# 형태소 분석 시작497
# 형태소 분석 시작498
# 형태소 분석 시작499
# 형태소 분석 시작500
# 형태소 분석 시작501
# 형태소 분석 시작502
# 형태소 분석 시작503
# 형태소 분석 시작504
# 형태소 분석 시작505
# 형태소 분석 시작506
# 형태소 분석 시작507
# 형태소 분석 시작508
# 형태소 분석 시작509
# 형태소 분석 시작510
# 형태소 분석 시작511
# 형태소 분석 시작512
# 형태소 분석 시작513
# 형태소 분석 시작514
# 형태소 분석 시작515
# 형태소 분석 시작516
# 형태소 분석 시작517
# 형태소 분석 시작518
# 형태소 분석 시작519
# 형태소 분석 시작520
# 형태소 분석 시작521
# 형태소 분석 시작522
# 형태소 분석 시작523
# 형태소 분석 시작524
# 형태소 분석 시작525
# 형태소 분석 시작526
# 형태소 분석 시작527
# 형태소 분석 시작528
# 형태소 분석 시작529
# 형태소 분석 시작530
# 형태소 분석 시작531
# 형태소 분석 시작532
# 형태소 분석 시작533
# 형태소 분석 시작534
# 형태소 분석 시작535
# 형태소 분석 시작536
# 형태소 분석 시작537
# 형태소 분석 시작538
# 형태소 분석 시작539
# 형태소 분석 시작540
# 형태소 분석 시작541
# 형태소 분석 시작542
# 형태소 분석 시작543
# 형태소 분석 시작544
# 형태소 분석 시작545
# 형태소 분석 시작546
# 형태소 분석 시작547
# 형태소 분석 시작548
# 형태소 분석 시작549
# 형태소 분석 시작550
# 형태소 분석 시작551
# 형태소 분석 시작552
# 형태소 분석 시작553
# 형태소 분석 시작554
# 형태소 분석 시작555
# 형태소 분석 시작556
# 형태소 분석 시작557
# 형태소 분석 시작558
# 형태소 분석 시작559
# 형태소 분석 시작560
# 형태소 분석 시작561
# 형태소 분석 시작562
# 형태소 분석 시작563
# 형태소 분석 시작564
# 형태소 분석 시작565
# 형태소 분석 시작566
# 형태소 분석 시작567
# 형태소 분석 시작568
# 형태소 분석 시작569
# 형태소 분석 시작570
# 형태소 분석 시작571
# 형태소 분석 시작572
# 형태소 분석 시작573
# 형태소 분석 시작574
# 형태소 분석 시작575
# 형태소 분석 시작576
# 형태소 분석 시작577
# 형태소 분석 시작578
# 형태소 분석 시작579
# 형태소 분석 시작580
# 형태소 분석 시작581
# 형태소 분석 시작582
# 형태소 분석 시작583
# 형태소 분석 시작584
# 형태소 분석 시작585
# 형태소 분석 시작586
# 형태소 분석 시작587
# 형태소 분석 시작588
# 형태소 분석 시작589
# 형태소 분석 시작590
# 형태소 분석 시작591
# 형태소 분석 시작592
# 형태소 분석 시작593
# 형태소 분석 시작594
# 형태소 분석 시작595
# 형태소 분석 시작596
# 형태소 분석 시작597
# 형태소 분석 시작598
# 형태소 분석 시작599
# 형태소 분석 시작600
# 형태소 분석 시작601
# 형태소 분석 시작602
# 형태소 분석 시작603
# 형태소 분석 시작604
# 형태소 분석 시작605
# 형태소 분석 시작606
# 형태소 분석 시작607
# 형태소 분석 시작608
# 형태소 분석 시작609
# 형태소 분석 시작610
# 형태소 분석 시작611
# 형태소 분석 시작612
# 형태소 분석 시작613
# 형태소 분석 시작614
# 형태소 분석 시작615
# 형태소 분석 시작616
# 형태소 분석 시작617
# 형태소 분석 시작618
# 형태소 분석 시작619
# 형태소 분석 시작620
# 형태소 분석 시작621
# 형태소 분석 시작622
# 형태소 분석 시작623
# 형태소 분석 시작624
# 형태소 분석 시작625
# 형태소 분석 시작626
# 형태소 분석 시작627
# 형태소 분석 시작628

# %%
one_words3= []
tow_words1= []
etc_words1= []
for noun in nounswork:
    if len(noun) == 1:
        one_words1.append(noun)
    elif len(noun) == 2:
        tow_words1.append(noun)
    else:
        etc_words1.append(noun)
        
len(one_words3), len(tow_words1), len(etc_words1)
# Out:
# (0, 1602, 2848)

# %%
onework = nltk.Text(one_words1, name = "workone")

# %%
onework.vocab().most_common()
# Out:
# [('것', 13),
#  ('리', 11),
#  ('수', 9),
#  ('그', 6),
#  ('등', 5),
#  ('거', 5),
#  ('바', 5),
#  ('주', 5),
#  ('내', 4),
#  ('저', 4),
#  ('과', 4),
#  ('망', 4),
#  ('폐', 4),
#  ('국', 3),
#  ('물', 3),
#  ('제', 3),
#  ('+', 3),
#  ('전', 2),
#  ('삶', 2),
#  ('위', 2),
#  ('근', 2),
#  ('5', 2),
#  ('개', 2),
#  ('죽', 2),
#  ('뭐', 2),
#  ('안', 2),
#  ('1', 2),
#  ('이', 2),
#  ('죄', 1),
#  ('땅', 1),
#  ('집', 1),
#  ('밑', 1),
#  ('으', 1),
#  ('피', 1),
#  ('외', 1),
#  ('&', 1),
#  ('6', 1),
#  ('중', 1),
#  ('때', 1),
#  ('증', 1),
#  ('구', 1),
#  ('한', 1),
#  ('애', 1),
#  ('도', 1),
#  ('답', 1),
#  ('2', 1),
#  ('속', 1),
#  ('해', 1),
#  ('나', 1),
#  ('됨', 1),
#  ('추', 1),
#  ('부', 1),
#  ('통', 1),
#  ('말', 1),
#  ('합', 1),
#  ('되', 1),
#  ('확', 1),
#  ('책', 1),
#  ('번', 1)]

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님', "최저임금"]
stop_words_work.extend(one_words1)
len(stop_words_work)
# Out:
# 151

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님', "정규직"]
stop_words_work.extend(one_words2)
len(stop_words_work)
# Out:
# 7

# %%
work_nouns = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)
# Out:
# 1350

# %%
work_nouns2 = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)
# Out:
# 1350

# %%
work_nouns2 = nltk.Text(work_nouns2, name = "일자리")
work_noun_common2 = work_nouns2.vocab().most_common()

# %%
work_nouns1 = nltk.Text(work_nouns, name = "일자리")
# fourth_nouns = nltk.Text(fourth_nouns, name = "일자리")

# %%
work_noun_common = work_nouns1.vocab().most_common()
# fourth_noun_common = fourth_nouns.vocab().most_common()

# %%
work_noun_common2
# Out:
# [('최저임금', 691),
#  ('인상', 124),
#  ('최저임금인상', 56),
#  ('전환', 41),
#  ('정책', 39),
#  ('자영업자', 26),
#  ('문제', 25),
#  ('공공기관', 21),
#  ('경제', 19),
#  ('대책', 19),
#  ('해결', 19),
#  ('정규직전환', 19),
#  ('누구', 18),
#  ('적용', 18),
#  ('부작용', 16),
#  ('임금', 15),
#  ('반대', 15),
#  ('최저임금제', 14),
#  ('문제점', 14),
#  ('지원', 14),
#  ('1만원', 14),
#  ('방안', 13),
#  ('외국', 12),
#  ('필요', 12),
#  ('일본', 12),
#  ('상승', 12),
#  ('52시간', 11),
#  ('계약직', 11),
#  ('국민', 10),
#  ('자영업자들', 10),
#  ('마련', 10),
#  ('급격', 10),
#  ('성장', 10),
#  ('근로시간', 10),
#  ('때문', 10),
#  ('고용', 10),
#  ('개선', 10),
#  ('관련', 10),
#  ('시급', 9),
#  ('근로자', 9),
#  ('세금', 9),
#  ('생각', 9),
#  ('노동자', 9),
#  ('공공부문', 9),
#  ('청년', 8),
#  ('처벌', 8),
#  ('서민들', 8),
#  ('해외', 8),
#  ('서민', 8),
#  ('철회', 8),
#  ('최저임금급격인상', 8),
#  ('감소', 8),
#  ('동결', 8),
#  ('소상공', 8),
#  ('최저임금관련', 8),
#  ('지급', 8),
#  ('조정해', 8),
#  ('조정', 8),
#  ('시행', 8),
#  ('폐지', 8),
#  ('공약', 8),
#  ('월급', 8),
#  ('주세요', 8),
#  ('국회의원', 8),
#  ('무기계약직', 8),
#  ('사람', 7),
#  ('방법', 7),
#  ('취업자', 7),
#  ('촉구', 7),
#  ('요구', 7),
#  ('차등', 7),
#  ('포함', 7),
#  ('당신들', 6),
#  ('국민들', 6),
#  ('소득주', 6),
#  ('차등지급', 6),
#  ('꼼수', 6),
#  ('저소득층', 6),
#  ('소상공인', 6),
#  ('제안', 6),
#  ('대안', 6),
#  ('중소기업', 6),
#  ('대통령', 6),
#  ('최저임금위원회', 6),
#  ('모두', 6),
#  ('청와대', 6),
#  ('2020년', 6),
#  ('미국', 6),
#  ('최저임금정책', 6),
#  ('대한민국', 6),
#  ('결정', 6),
#  ('나라다운', 6),
#  ('나라', 6),
#  ('관련하', 6),
#  ('부담', 6),
#  ('경기', 6),
#  ('청년들', 6),
#  ('실질적', 6),
#  ('최저임금법', 6),
#  ('고용주', 6),
#  ('개정', 6),
#  ('파견직', 6),
#  ('기업', 5),
#  ('근로자들', 5),
#  ('소득주도성장', 5),
#  ('채용', 5),
#  ('현실', 5),
#  ('중단', 5),
#  ('대하여', 5),
#  ('의무화', 5),
#  ('대기업', 5),
#  ('보완', 5),
#  ('공무원', 5),
#  ('주52시간', 5),
#  ('거부', 5),
#  ('이상', 5),
#  ('최저임금적용', 5),
#  ('실업자', 5),
#  ('안정', 5),
#  ('격차', 5),
#  ('요청', 5),
#  ('폭등', 4),
#  ('최순실', 4),
#  ('무능', 4),
#  ('노동시간단축', 4),
#  ('그것', 4),
#  ('안녕', 4),
#  ('회사들', 4),
#  ('저출산', 4),
#  ('창출', 4),
#  ('노동착취', 4),
#  ('자율화', 4),
#  ('일자리창출', 4),
#  ('현실화', 4),
#  ('자살', 4),
#  ('제외', 4),
#  ('감면', 4),
#  ('알바들', 4),
#  ('국가', 4),
#  ('최저임금인상때문', 4),
#  ('한번', 4),
#  ('안정자금', 4),
#  ('지원금', 4),
#  ('제도', 4),
#  ('유지', 4),
#  ('무분별한', 4),
#  ('수정', 4),
#  ('인력난등', 4),
#  ('소견', 4),
#  ('입장', 4),
#  ('정책제안', 4),
#  ('영세', 4),
#  ('해결책', 4),
#  ('불법', 4),
#  ('외국노동자', 4),
#  ('현실적', 4),
#  ('추진', 4),
#  ('인상관련', 4),
#  ('내년', 4),
#  ('장애인최저임금', 4),
#  ('적용제외', 4),
#  ('규정', 4),
#  ('삭제', 4),
#  ('1인당', 4),
#  ('시간당', 4),
#  ('한국의', 4),
#  ('차등적용', 4),
#  ('사과', 4),
#  ('경기침체', 4),
#  ('폐업', 4),
#  ('외국인근로자', 4),
#  ('일방적', 4),
#  ('재고', 4),
#  ('부탁', 4),
#  ('청원드', 4),
#  ('정답', 4),
#  ('잘못된', 4),
#  ('최저임금때문', 4),
#  ('제한', 4),
#  ('업종별', 4),
#  ('물가상승', 4),
#  ('주휴수당', 4),
#  ('2019년', 4),
#  ('부동산', 4),
#  ('임대료', 4),
#  ('삭감법', 4),
#  ('운영', 4),
#  ('진행', 4),
#  ('산입범위', 4),
#  ('상생', 4),
#  ('최저임금에관한의견', 4),
#  ('이전', 4),
#  ('최저임금개정안', 4),
#  ('회사', 4),
#  ('행사', 4),
#  ('국회의원님들', 4),
#  ('실직자들', 4),
#  ('선진국', 4),
#  ('공공기업', 4),
#  ('색출', 4),
#  ('시급한', 4),
#  ('이것', 4),
#  ('처우', 4),
#  ('실태', 4),
#  ('법인세', 4),
#  ('근본적', 4),
#  ('장애', 4),
#  ('고발', 4),
#  ('하나', 3),
#  ('대처', 3),
#  ('사업', 3),
#  ('업무', 3),
#  ('실업률', 3),
#  ('고용노동부', 3),
#  ('문대통령님', 3),
#  ('노동법', 3),
#  ('재검토', 3),
#  ('상황', 3),
#  ('실행', 3),
#  ('전면', 3),
#  ('우리', 3),
#  ('진짜', 3),
#  ('직원', 3),
#  ('사태', 3),
#  ('최저시급', 3),
#  ('시간제알바에', 3),
#  ('활성화합', 3),
#  ('개정안', 3),
#  ('안지켜주', 3),
#  ('서울시교육청', 3),
#  ('민간기업', 3),
#  ('증가', 3),
#  ('홍보', 3),
#  ('효율적', 3),
#  ('국민제안', 3),
#  ('청원시리즈', 3),
#  ('저출산대책', 3),
#  ('일자리대책', 3),
#  ('최저임금대책', 3),
#  ('정규직대책', 3),
#  ('현안', 3),
#  ('세트', 3),
#  ('가능', 3),
#  ('조사', 3),
#  ('복지', 3),
#  ('소득별', 3),
#  ('정규직폐지반대', 3),
#  ('대학교', 3),
#  ('50대주부비정규직짤림', 3),
#  ('농협', 3),
#  ('70', 3),
#  ('법안', 3),
#  ('가이드라인', 3),
#  ('학교', 3),
#  ('양산', 3),
#  ('비애', 3),
#  ('기준', 3),
#  ('대리업체', 2),
#  ('경쟁', 2),
#  ('대리비', 2),
#  ('낮아만집니', 2),
#  ('자신', 2),
#  ('탐욕', 2),
#  ('국정농단', 2),
#  ('도탄', 2),
#  ('최저임금폭등', 2),
#  ('경쟁력', 2),
#  ('/제조업최악', 2),
#  ('신기록', 2),
#  ('이미지', 2),
#  ('정치', 2),
#  ('립서비스', 2),
#  ('무능함', 2),
#  ('반성치', 2),
#  ('자리', 2),
#  ('해악', 2),
#  ('조차', 2),
#  ('노동', 2),
#  ('세상', 2),
#  ('20대', 2),
#  ('양심', 2),
#  ('조건', 2),
#  ('불합', 2),
#  ('체계', 2),
#  ('건의드', 2),
#  ('일자리가없는거같아요', 2),
#  ('고민', 2),
#  ('불법체류', 2),
#  ('악덕', 2),
#  ('고용주들', 2),
#  ('최저임금·탈원전', 2),
#  ('자원봉사자', 2),
#  ('한시적', 2),
#  ('최저임금지급', 2),
#  ('적폐세력', 2),
#  ('강성노조', 2),
#  ('눈치보', 2),
#  ('지방', 2),
#  ('자율', 2),
#  ('매년인상', 2),
#  ('세금인상', 2),
#  ('기업체', 2),
#  ('미국좀', 2),
#  ('미국식', 2),
#  ('차상위계층', 2),
#  ('전락', 2),
#  ('지역차등검토', 2),
#  ('못만드', 2),
#  ('애로점', 2),
#  ('개선책', 2),
#  ('근로제', 2),
#  ('법인세인', 2),
#  ('과거', 2),
#  ('세율인상', 2),
#  ('규제확대', 2),
#  ('세금낭비', 2),
#  ('총체적', 2),
#  ('시행중', 2),
#  ('물가잔뜩오르', 2),
#  ('저소득층에겐오히려저주', 2),
#  ('저소득층에겐저주', 2),
#  ('일자리초토화저주가된상황', 2),
#  ('무죄', 2),
#  ('인상속도', 2),
#  ('늦쳐주십시요', 2),
#  ('원상복귀', 2),
#  ('과속', 2),
#  ('딱지값', 2),
#  ('경제악화', 2),
#  ('급경한', 2),
#  ('임금인상', 2),
#  ('차등화대', 2),
#  ('어떨까요', 2),
#  ('저소득층과알바들에겐독이된아이러', 2),
#  ('최저임금실험대상', 2),
#  ('더힘들게만드냐', 2),
#  ('후안무치한', 2),
#  ('최저임금급격인상그나마밥먹던', 2),
#  ('고통속', 2),
#  ('화가', 2),
#  ('아이러니', 2),
#  ('최저임금(꼭', 2),
#  ('사업주들', 2),
#  ('만큼', 2),
#  ('세금감면', 2),
#  ('직장생활', 2),
#  ('13년', 2),
#  ('자영업의길', 2),
#  ('야근', 2),
#  ('지원대책(7조)', 2),
#  ('인상분', 2),
#  ('지급하세요', 2),
#  ('난노동자', 2),
#  ('최저임금철회요망', 2),
#  ('수혜대상', 2),
#  ('아파트사용자', 2),
#  ('근로자(경비원,청소원,최저임금미만서무직원)이', 2),
#  ('진짜뉴스', 2),
#  ('사건', 2),
#  ('한경닷컴', 2),
#  ('보도', 2),
#  ('전말', 2),
#  ('들쑤셔', 2),
#  ('자영자노동자다힘들게하고정권재창출꿈꾸냐', 2),
#  ('최저임금만오르', 2),
#  ('소득이증대되냐', 2),
#  ('단순무지도정도가', 2),
#  ('기업여건', 2),
#  ('쌀값', 2),
#  ('비롯', 2),
#  ('물가가올리솟는거', 2),
#  ('지방공멸화', 2),
#  ('시도', 2),
#  ('부가세', 2),
#  ('소득주도성장정책(최저임금상승율,', 2),
#  ('복지예산지출액증가율', 2),
#  ('주요경제지표(취업율,', 2),
#  ('실업율', 2),
#  ('물가상승율', 2),
#  ('상관분석', 2),
#  ('공개', 2),
#  ('핵문무능', 2),
#  ('암걸리고싶당', 2),
#  ('주52시간,최저임금', 2),
#  ('임기', 2),
#  ('포용적', 2),
#  ('혁신', 2),
#  ('성장,협치', 2),
#  ('청소년일자리', 2),
#  ('보수세력', 2),
#  ('정치공세', 2),
#  ('당당', 2),
#  ('4대강', 2),
#  ('인상에대하', 2),
#  ('막심', 2),
#  ('대우', 2),
#  ('주근무시간', 2),
#  ('정책변경', 2),
#  ('3d업종', 2),
#  ('생계자', 2),
#  ('고용불안', 2),
#  ('경제쇼크', 2),
#  ('직시하시', 2),
#  ('현명', 2),
#  ('처방', 2),
#  ('자영업', 2),
#  ('국민연금문제', 2),
#  ('원인치료를해', 2),
#  ('증세치료', 2),
#  ('ㅉㅉ', 2),
#  ('구직', 2),
#  ('자영업과저소득층', 2),
#  ('어리석은정책', 2),
#  ('5인미만', 2),
#  ('영세사업장', 2),
#  ('민생경제', 2),
#  ('제시', 2),
#  ('스타트업', 2),
#  ('배려', 2),
#  ('자영업자대책', 2),
#  ('건의(일자리', 2),
#  ('건의', 2),
#  ('보조금', 2),
#  ('취업수당', 2),
#  ('변경', 2),
#  ('최저임금산정', 2),
#  ('신중', 2),
#  ('중장년최저임금낮추기제안', 2),
#  ('실질소득', 2),
#  ('고용창출', 2),
#  ('경제성장', 2),
#  ('상처', 2),
#  ('소금뿌리', 2),
#  ('근원적', 2),
#  ('비참', 2),
#  ('역할', 2),
#  ('제도개선', 2),
#  ('대국민', 2),
#  ('서명', 2),
#  ('경제파탄책', 2),
#  ('누가지냐', 2),
#  ('말좀해봐', 2),
#  ('졸속', 2),
#  ('최저임금제●정부', 2),
#  ('취업자간', 2),
#  ('직거래면●해결됩니', 2),
#  ('적극', 2),
#  ('대찬성', 2),
#  ('직거래하', 2),
#  ('찬성', 2),
#  ('최저임금땜', 2),
#  ('잃은사람들', 2),
#  ('힘든자영업자들', 2),
#  ('경제참모들', 2),
#  ('일회용컵', 2),
#  ('불법취업외국인', 2),
#  ('단속', 2),
#  ('차등제', 2),
#  ('실시', 2),
#  ('국가비상사태', 2),
#  ('선포', 2),
#  ('소기업들', 2),
#  ('사항', 2),
#  ('다른정책', 2),
#  ('그만만들고', 2),
#  ('지겨웁다', 2),
#  ('정책실장', 2),
#  ('대통령지지율하락', 2),
#  ('예견', 2),
#  ('ㅋㅋ', 2),
#  ('애로사항', 2),
#  ('모하러최저임금', 2),
#  ('어설프게건드려', 2),
#  ('자영자다힘들게하냐', 2),
#  ('전기누진제', 2),
#  ('참모진들', 2),
#  ('이제른', 2),
#  ('못만들게', 2),
#  ('방해놓', 2),
#  ('어느나라', 2),
#  ('대책안', 2),
#  ('서민경제폭망예상합니', 2),
#  ('대책마련', 2),
#  ('아이디어', 2),
#  ('민주당', 2),
#  ('각성', 2),
#  ('연령별', 2),
#  ('장애별', 2),
#  ('제주난민', 2),
#  ('누진세', 2),
#  ('3프로씩', 2),
#  ('누굴위한', 2),
#  ('최저임금인지', 2),
#  ('확보', 2),
#  ('영업이익', 2),
#  ('할당', 2),
#  ('청년일자리', 2),
#  ('세계교류', 2),
#  ('차등관련', 2),
#  ('차등화', 2),
#  ('6만불', 2),
#  ('3만물', 2),
#  ('10달러', 2),
#  ('단순비교시', 2),
#  ('2분', 2),
#  ('5,000원', 2),
#  ('전후', 2),
#  ('결과', 2),
#  ('물가앙등', 2),
#  ('뿐이닷', 2),
#  ('이땅', 2),
#  ('절규', 2),
#  ('사죄', 2),
#  ('반론', 2),
#  ('경제살릴려', 2),
#  ('우리건물', 2),
#  ('주차원4명', 2),
#  ('무인주차시스템', 2),
#  ('실직', 2),
#  ('큰문제', 2),
#  ('의미', 2),
#  ('수출확대,,(1타5피법', 2),
#  ('국민경제', 2),
#  ('과감', 2),
#  ('20,000원', 2),
#  ('외국인', 2),
#  ('19년', 2),
#  ('무효화', 2),
#  ('다시한번', 2),
#  ('탄력적', 2),
#  ('산정방식', 2),
#  ('불이행', 2),
#  ('쇼크', 2),
#  ('우선', 2),
#  ('해법', 2),
#  ('다같', 2),
#  ('해결합', 2),
#  ('못지켜', 2),
#  ('죄송', 2),
#  ('잘못', 2),
#  ('난민', 2),
#  ('유입', 2),
#  ('한국폭망', 2),
#  ('할증최저임금제도', 2),
#  ('도입', 2),
#  ('소기업', 2),
#  ('준비', 2),
#  ('최저임금에대해', 2),
#  ('조정안', 2),
#  ('최저임금시스템', 2),
#  ('27살', 2),
#  ('느낀점', 2),
#  ('한국인', 2),
#  ('분리', 2),
#  ('사람들', 2),
#  ('마련해', 2),
#  ('국회의원들', 2),
#  ('이건아닙니', 2),
#  ('포상금', 2),
#  ('최소3억', 2),
#  ('부동산폭등', 2),
#  ('최저임금포', 2),
#  ('격년제', 2),
#  ('협상', 2),
#  ('노사임단협', 2),
#  ('취소', 2),
#  ('검토', 2),
#  ('선결', 2),
#  ('과제', 2),
#  ('실현', 2),
#  ('미개', 2),
#  ('청년실업', 2),
#  ('가속화', 2),
#  ('외노자', 2),
#  ('추방해', 2),
#  ('물가', 2),
#  ('최저임금제폐지요청', 2),
#  ('정당', 2),
#  ('고용확대', 2),
#  ('개선방안', 2),
#  ('인상반대', 2),
#  ('부자들', 2),
#  ('잘됫다', 2),
#  ('비용', 2),
#  ('최저', 2),
#  ('8,350원', 2),
#  ('최저임금관련2번째', 2),
#  ('자경업,', 2),
#  ('불황', 2),
#  ('전정권', 2),
#  ('최악', 2),
#  ('정권', 2),
#  ('반성', 2),
#  ('반기업', 2),
#  ('반자영업,', 2),
#  ('반시장경제,', 2),
#  ('반취업', 2),
#  ('부모님', 2),
#  ('말라죽고', 2),
#  ('영세자영업자', 2),
#  ('최고임금', 2),
#  ('위한법인가요', 2),
#  ('중요', 2),
#  ('국비지원', 2),
#  ('교육', 2),
#  ('8350원', 2),
#  ('지듭', 2),
#  ('노동자들', 2),
#  ('1년', 2),
#  ('한번오르', 2),
#  ('국가부도', 2),
#  ('시작', 2),
#  ('인상효과', 2),
#  ('그만올려주', 2),
#  ('의견', 2),
#  ('방향', 2),
#  ('과도한인상', 2),
#  ('더올려주세요', 2),
#  ('행복', 2),
#  ('취업난', 2),
#  ('현실성', 2),
#  ('중지', 2),
#  ('정책안', 2),
#  ('작년', 2),
#  ('동결및', 2),
#  ('차등인상', 2),
#  ('현상', 2),
#  ('누굴', 2),
#  ('역효과', 2),
#  ('소득', 2),
#  ('하향평준화', 2),
#  ('무리한', 2),
#  ('상승안', 2),
#  ('10000원', 2),
#  ('이유', 2),
#  ('증세', 2),
#  ('직종별', 2),
#  ('규모별', 2),
#  ('입법제안', 2),
#  ('적용범위', 2),
#  ('늘릴려', 2),
#  ('근로시간단축및최저임금처음데로해주', 2),
#  ('편법', 2),
#  ('사용', 2),
#  ('사라지고잇습니', 2),
#  ('근로장려금', 2),
#  ('보완책', 2),
#  ('연금', 2),
#  ('건강보험', 2),
#  ('체계적', 2),
#  ('노동시간', 2),
#  ('원래', 2),
#  ('공장들', 2),
#  ('최저임금범위', 2),
#  ('지정', 2),
#  ('개악법', 2),
#  ('급여가산', 2),
#  ('유급휴가', 2),
#  ('65세', 2),
#  ('한계', 2),
#  ('발안', 2),
#  ('억제', 2),
#  ('공시지가', 2),
#  ('단축', 2),
#  ('기본소득', 2),
#  ('최저임금상승', 2),
#  ('완충', 2),
#  ('어떤가요', 2),
#  ('폐기', 2),
#  ('국민건강보험적용', 2),
#  ('차별성', 2),
#  ('오늘', 2),
#  ('국무회의', 2),
#  ('평화', 2),
#  ('후퇴해서', 2),
#  ('피크제', 2),
#  ('처럼', 2),
#  ('나이', 2),
#  ('신축적', 2),
#  ('간단', 2),
#  ('인상해', 2),
#  ('목표', 2),
#  ('차질', 2),
#  ('청년층', 2),
#  ('최저임금문제', 2),
#  ('급증', 2),
#  ('최저임금인상부작용', 2),
#  ('김동연부총리', 2),
#  ('상식', 2),
#  ('왜곡', 2),
#  ('비서실', 2),
#  ('경제망국', 2),
#  ('기업간', 2),
#  ('거짓말', 2),
#  ('인상폭', 2),
#  ('감축', 2),
#  ('최저임금인상반대', 2),
#  ('주휴수당폐', 2),
#  ('당초', 2),
#  ('1만원게획', 2),
#  ('물가안정', 2),
#  ('공장', 2),
#  ('무직자', 2),
#  ('식비', 2),
#  ('저희아버지께서', 2),
#  ('백수', 2),
#  ('근로시간단축', 2),
#  ('이대', 2),
#  ('개악안', 2),
#  ('거부권', 2),
#  ('기타수당', 2),
#  ('고위간부위원분', 2),
#  ('못지켰을시', 2),
#  ('강화', 2),
#  ('법률안거부권', 2),
#  ('최저임금조정', 2),
#  ('상여금등', 2),
#  ('고용인살릴려', 2),
#  ('공약파', 2),
#  ('사과하세요', 2),
#  ('물가인상', 2),
#  ('최저임금좀', 2),
#  ('의결', 2),
#  ('실직자', 2),
#  ('김동연', 2),
#  ('입좀', 2),
#  ('상여금', 2),
#  ('급식비등', 2),
#  ('관여', 2),
#  ('해체', 2),
#  ('안주', 2),
#  ('근로법위반', 2),
#  ('처벌강화', 2),
#  ('소통', 2),
#  ('활성화', 2),
#  ('최저임금법위반', 2),
#  ('외면', 2),
#  ('실질', 2),
#  ('추월', 2),
#  ('중소기업들', 2),
#  ('추방', 2),
#  ('두자', 2),
#  ('근로법', 2),
#  ('기업죽', 2),
#  ('근로자감축', 2),
#  ('지원정책', 2),
#  ('혜택', 2),
#  ('안지키', 2),
#  ('올릴', 2),
#  ('부당대우', 2),
#  ('엄벌해주세요', 2),
#  ('내국인', 2),
#  ('말씀드', 2),
#  ('대체공휴일', 2),
#  ('부정부패', 2),
#  ('근로에대해', 2),
#  ('최저임금다시', 2),
#  ('인하', 2),
#  ('최저임금미', 2),
#  ('지급공고', 2),
#  ('사업자', 2),
#  ('취약', 2),
#  ('사업체', 2),
#  ('지자체', 2),
#  ('노동개혁', 2),
#  ('상승인가요', 2),
#  ('혜택마련', 2),
#  ('짧은소견', 2),
#  ('필요한', 2),
#  ('중견', 2),
#  ('장병', 2),
#  ('가산점', 2),
#  ('학비', 2),
#  ('제언', 2),
#  ('원자재', 2),
#  ('가격', 2),
#  ('안올랐는데', 2),
#  ('물품원', 2),
#  ('중간', 2),
#  ('빼먹', 2),
#  ('유통사', 2),
#  ('재제정책', 2),
#  ('방향전환', 2),
#  ('수혜자', 2),
#  ('웃푼현실', 2),
#  ('논란', 2),
#  ('경제학', 2),
#  ('법인세인상', 2),
#  ('답변', 2),
#  ('조직', 2),
#  ('권한', 2),
#  ('부여', 2),
#  ('상향', 2),
#  ('5천원', 2),
#  ('국가보조', 2),
#  ('26살', 2),
#  ('피해자', 2),
#  ('이멍청아', 2),
#  ('다시내', 2),
#  ('지지율', 2),
#  ('50', 2),
#  ('가상화폐', 2),
#  ('일시적', 2),
#  ('부가가치세', 2),
#  ('분야별', 2),
#  ('못받', 2),
#  ('노예들', 2),
#  ('평창', 2),
#  ('올림픽', 2),
#  ('전문운영인력', 2),
#  ('최저임금꼼수감시를철저히해주', 2),
#  ('유명무실', 2),
#  ('용역업체소속', 2),
#  ('파견근로자', 2),
#  ('불법등', 2),
#  ('체류자', 2),
#  ('오류', 2),
#  ('(평창', 2),
#  ('비자정책', 2),
#  ('누굴위해', 2),
#  ('죽어나네요ㅠ', 2),
#  ('탄핵', 2),
#  ('이번', 2),
#  ('주제', 2),
#  ('군복무', 2),
#  ('전작권환수', 2),
#  ('남북단일팀', 2),
#  ('대북정책', 2),
#  ('사회주의', 2),
#  ('동성애교육', 2),
#  ('종교인과', 2),
#  ('미용', 2),
#  ('요식등', 2),
#  ('전문직', 2),
#  ('인상문제', 2),
#  ('농촌', 2),
#  ('직전', 2),
#  ('감수', 2),
#  ('최저임금보장', 2),
#  ('중소기업육성', 2),
#  ('금융권', 2),
#  ('금리인하', 2),
#  ('주라', 2),
#  ('휴게시간', 2),
#  ('모든문제', 2),
#  ('남편', 2),
#  ('위반', 2),
#  ('일자리안정자금', 2),
#  ('지원요청', 2),
#  ('반박', 2),
#  ('인사', 2),
#  ('머리', 2),
#  ('중소업체', 2),
#  ('대표', 2),
#  ('부작용해소방안', 2),
#  ('직원및', 2),
#  ('아르바이트', 2),
#  ('장사', 2),
#  ('보완및', 2),
#  ('다들', 2),
#  ('경북구미', 2),
#  ('경제정책', 2),
#  ('일관성', 2),
#  ('최선', 2),
#  ('빌미', 2),
#  ('대체', 2),
#  ('청소노동자', 2),
#  ('보호', 2),
#  ('대폭인상', 2),
#  ('줄어들고잇습니다', 2),
#  ('ㅠㅠㅠ', 2),
#  ('2018년', 2),
#  ('쌍방', 2),
#  ('민노총', 2),
#  ('취업', 2),
#  ('최고적폐', 2),
#  ('행정도우미', 2),
#  ('감사', 2),
#  ('근무', 2),
#  ('제정', 2),
#  ('용역직', 2),
#  ('횡포', 2),
#  ('관련한', 2),
#  ('기만', 2),
#  ('과정', 2),
#  ('차별', 2),
#  ('공기업', 2),
#  ('농협은행', 2),
#  ('장애인일자리', 2),
#  ('사전통보', 2),
#  ('현대자동차', 2),
#  ('애환', 2),
#  ('약속', 2),
#  ('생계형', 2),
#  ('자회사', 2),
#  ('강원랜드', 2),
#  ('행태', 2),
#  ('협력업체', 2),
#  ('부당한', 2),
#  ('무엇', 2),
#  ('확대', 2),
#  ('의료계통', 2),
#  ('기술인들도정규직화가필요', 2),
#  ('금지', 2),
#  ('부탁드', 2),
#  ('무기직', 2),
#  ('압박', 1),
#  ('공개채용', 1),
#  ('1.5', 1),
#  ('원천', 1),
#  ('봉쇄', 1),
#  ('해산', 1),
#  ('2년', 1),
#  ('일할', 1),
#  ('행정도우', 1),
#  ('정규직(무계약직)화', 1),
#  ('정규직자리', 1),
#  ('부족', 1),
#  ('시간제', 1),
#  ('현대기아차', 1),
#  ('100%전환하', 1),
#  ('슬픔', 1),
#  ('사학연금빌딩', 1),
#  ('정규직전환꼼수', 1),
#  ('건물매각후', 1),
#  ('계약종료', 1),
#  ('●적폐란', 1),
#  ('다시일어서지', 1),
#  ('친인척채용비', 1),
#  ('권력자', 1),
#  ('임원', 1),
#  ('귀족노조', 1),
#  ('천인척', 1),
#  ('아닌사람은', 1),
#  ('인도카스트계급', 1),
#  ('가짜일자리정부', 1),
#  ('한통속', 1),
#  ('세습', 1),
#  ('정당한', 1),
#  ('방침', 1),
#  ('전국', 1),
#  ('장애인일반형일자리', 1),
#  ('제로화', 1),
#  ('출연(연)', 1),
#  ('임시직', 1),
#  ('자동차', 1),
#  ('대리점', 1),
#  ('영업사원', 1),
#  ('인정', 1),
#  ('덕분', 1),
#  ('직장', 1),
#  ('학교비정규직중', 1),
#  ('통학차량보조원', 1),
#  ('시청', 1),
#  ('평생', 1),
#  ('ㅠㅠㅠ도와주세요', 1),
#  ('절망', 1),
#  ('특수경비정규직전환면접불합격자들에게일자리주', 1),
#  ('출연연기관', 1),
#  ('정규직대상', 1),
#  ('도로공사', 1),
#  ('환갑', 1),
#  ('한국도로공사', 1),
#  ('강압', 1),
#  ('비정규직정규직철회요청합니', 1),
#  ('전산직', 1),
#  ('용역', 1),
#  ('이해', 1),
#  ('가질않습니', 1),
#  ('전수조사', 1),
#  ('수습', 1),
#  ('ㅡㅡ', 1),
#  ('부당해고', 1),
#  ('취준생', 1),
#  ('정규직전환때문', 1),
#  ('아웃소싱제', 1),
#  ('정규직수습', 1),
#  ('제안건', 1),
#  ('임기제공무원', 1),
#  ('분류', 1),
#  ('비율', 1),
#  ('20-30시간', 1),
#  ('무지계약직', 1),
#  ('무분별', 1),
#  ('해주시길', 1),
#  ('수백만', 1),
#  ('취업전쟁', 1),
#  ('20년학교비정규직', 1),
#  ('방학때', 1),
#  ('기업은행', 1),
#  ('가족', 1),
#  ('한국수자원공사', 1),
#  ('공문', 1),
#  ('확인', 1),
#  ('전산유지보수', 1),
#  ('요청드', 1),
#  ('현대모비스', 1),
#  ('정규직일자리', 1),
#  ('많이만들어주세요', 1),
#  ('특수교사', 1),
#  ...]

# %%
dfw_reg = pd.DataFrame(work_noun_common2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-c0ae0d1a4e41> in <module>()
# ----> 1 dfw_reg = pd.DataFrame(work_noun_common2)
#
# C:\Python\Anaconda3-52\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
len(df42)
# Out:
# 162

# %%
plt.figure(figsize=(10,4))
work_nouns1.plot(30)
plt.show()

# %%
work_nouns1.collocations(window_size=3)
# Out:
# 거짓말 최저임금에관한의견; 외국노동자 계약직; 장애인최저임금 적용제외; 당신들 최순실; 일방적 나라다운; 최저임금인상 서민들

# %%
ww = dict(work_noun_common)

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww)

# %%
# ?WordCloud

# %%
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
plt.figure(figsize=(10,4))
work_nouns2.plot(30)
plt.show()

# %%
work_nouns2.collocations(window_size=3)
# Out:
# 거짓말 최저임금에관한의견; 장애인최저임금 적용제외; 당신들 최순실; 국민제안 저출산대책; 국민제안 청원시리즈; 서울시교육청
# 민간기업; 안지켜주 민간기업; 안지켜주 서울시교육청; 일자리대책 정규직대책; 일자리대책 최저임금대책; 저출산대책 일자리대책;
# 저출산대책 최저임금대책; 청원시리즈 일자리대책; 청원시리즈 저출산대책; 최저시급 시간제알바에; 최저임금대책 정규직대책;
# 민간기업 공공기업; 서울시교육청 공공기업; 정규직대책 시급한; 최저임금대책 시급한

# %%
ww2 = dict(work_noun_common2)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww2)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
