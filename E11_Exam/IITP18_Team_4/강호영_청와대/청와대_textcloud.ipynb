# %%
import nltk
from konlpy.tag import Hannanum
import pandas as pd
from time import sleep
import datetime

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook

# %%
df1 = pd.read_csv("./4th2.csv", encoding = "utf-8")

# %%
df2 = pd.read_csv("./work2.csv", encoding = "utf-8")

# %%
len(df2), 120*100
# Out:
# (11890, 12000)

# %%
len(df2)//100
# Out:
# 118

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', '날짜', '제목', '주소', '청원인', '본문'], dtype='object')

# %%
title4th = []
for i in range(10):
    start = 0 + 100*i
    end = 100 + 100*i
    text = df1["제목"][start:end]
    textfull = ". ".join(text)
    title4th.append(textfull)

# %%
titlework = []
for i in range(120):
    start = 0 + 100*i
    end = 100 + 100*i
    text = df2["제목"][start:end]
    textfull = ". ".join(text)
    titlework.append(textfull)

# %%
han = Hannanum()

# %%
nouns4th = []
a = 0

for i in title4th:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nouns4th.extend(nountemp)

# with open("w3.txt", "w", encoding="utf-8") as fp:
#     fp.write(nouns2)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10

# %%
nouns4th2 = ", ".join(nouns4th)

# %%
nounswork = []
a = 0

for i in titlework:
    a +=1
    print("형태소 분석 시작{}".format(a))
    nountemp = han.nouns(i)
    nounswork.extend(nountemp)

nouns2 = ", ".join(nounswork)
# Out:
# 형태소 분석 시작1
# 형태소 분석 시작2
# 형태소 분석 시작3
# 형태소 분석 시작4
# 형태소 분석 시작5
# 형태소 분석 시작6
# 형태소 분석 시작7
# 형태소 분석 시작8
# 형태소 분석 시작9
# 형태소 분석 시작10
# 형태소 분석 시작11
# 형태소 분석 시작12
# 형태소 분석 시작13
# 형태소 분석 시작14
# 형태소 분석 시작15
# 형태소 분석 시작16
# 형태소 분석 시작17
# 형태소 분석 시작18
# 형태소 분석 시작19
# 형태소 분석 시작20
# 형태소 분석 시작21
# 형태소 분석 시작22
# 형태소 분석 시작23
# 형태소 분석 시작24
# 형태소 분석 시작25
# 형태소 분석 시작26
# 형태소 분석 시작27
# 형태소 분석 시작28
# 형태소 분석 시작29
# 형태소 분석 시작30
# 형태소 분석 시작31
# 형태소 분석 시작32
# 형태소 분석 시작33
# 형태소 분석 시작34
# 형태소 분석 시작35
# 형태소 분석 시작36
# 형태소 분석 시작37
# 형태소 분석 시작38
# 형태소 분석 시작39
# 형태소 분석 시작40
# 형태소 분석 시작41
# 형태소 분석 시작42
# 형태소 분석 시작43
# 형태소 분석 시작44
# 형태소 분석 시작45
# 형태소 분석 시작46
# 형태소 분석 시작47
# 형태소 분석 시작48
# 형태소 분석 시작49
# 형태소 분석 시작50
# 형태소 분석 시작51
# 형태소 분석 시작52
# 형태소 분석 시작53
# 형태소 분석 시작54
# 형태소 분석 시작55
# 형태소 분석 시작56
# 형태소 분석 시작57
# 형태소 분석 시작58
# 형태소 분석 시작59
# 형태소 분석 시작60
# 형태소 분석 시작61
# 형태소 분석 시작62
# 형태소 분석 시작63
# 형태소 분석 시작64
# 형태소 분석 시작65
# 형태소 분석 시작66
# 형태소 분석 시작67
# 형태소 분석 시작68
# 형태소 분석 시작69
# 형태소 분석 시작70
# 형태소 분석 시작71
# 형태소 분석 시작72
# 형태소 분석 시작73
# 형태소 분석 시작74
# 형태소 분석 시작75
# 형태소 분석 시작76
# 형태소 분석 시작77
# 형태소 분석 시작78
# 형태소 분석 시작79
# 형태소 분석 시작80
# 형태소 분석 시작81
# 형태소 분석 시작82
# 형태소 분석 시작83
# 형태소 분석 시작84
# 형태소 분석 시작85
# 형태소 분석 시작86
# 형태소 분석 시작87
# 형태소 분석 시작88
# 형태소 분석 시작89
# 형태소 분석 시작90
# 형태소 분석 시작91
# 형태소 분석 시작92
# 형태소 분석 시작93
# 형태소 분석 시작94
# 형태소 분석 시작95
# 형태소 분석 시작96
# 형태소 분석 시작97
# 형태소 분석 시작98
# 형태소 분석 시작99
# 형태소 분석 시작100
# 형태소 분석 시작101
# 형태소 분석 시작102
# 형태소 분석 시작103
# 형태소 분석 시작104
# 형태소 분석 시작105
# 형태소 분석 시작106
# 형태소 분석 시작107
# 형태소 분석 시작108
# 형태소 분석 시작109
# 형태소 분석 시작110
# 형태소 분석 시작111
# 형태소 분석 시작112
# 형태소 분석 시작113
# 형태소 분석 시작114
# 형태소 분석 시작115
# 형태소 분석 시작116
# 형태소 분석 시작117
# 형태소 분석 시작118
# 형태소 분석 시작119
# 형태소 분석 시작120

# %%
one_words1 = []
tow_words1= []
etc_words1= []
for noun in nounswork:
    if len(noun) == 1:
        one_words1.append(noun)
    elif len(noun) == 2:
        tow_words1.append(noun)
    else:
        etc_words1.append(noun)
        
len(one_words1), len(tow_words1), len(etc_words1)
# Out:
# (4197, 20180, 26546)

# %%
one_words2 = []
tow_words2 = []
etc_words2 = []
for noun in nouns4th:
    if len(noun) == 1:
        one_words2.append(noun)
    elif len(noun) == 2:
        tow_words2.append(noun)
    else:
        etc_words2.append(noun)
        
len(one_words2), len(tow_words2), len(etc_words2)
# Out:
# (398, 2192, 2398)

# %%
onework = nltk.Text(one_words1, name = "한글자")

# %%
onework.vocab().most_common()
# Out:
# [('것', 365),
#  ('수', 326),
#  ('폐', 256),
#  ('리', 128),
#  ('일', 112),
#  ('법', 89),
#  ('개', 89),
#  ('등', 88),
#  ('제', 80),
#  ('나', 79),
#  ('이', 78),
#  ('저', 75),
#  ('전', 71),
#  ('주', 65),
#  ('국', 58),
#  ('말', 56),
#  ('체', 52),
#  ('그', 51),
#  ('들', 50),
#  ('축', 48),
#  ('자', 42),
#  ('내', 41),
#  ('줄', 39),
#  ('삶', 37),
#  ('시', 35),
#  ('건', 34),
#  ('돈', 34),
#  ('중', 32),
#  ('죽', 32),
#  ('망', 31),
#  ('물', 30),
#  ('해', 30),
#  ('투', 28),
#  ('집', 27),
#  ('글', 27),
#  ('한', 26),
#  ('때', 25),
#  ('대', 25),
#  ('위', 24),
#  ('비', 23),
#  ('답', 23),
#  ('과', 23),
#  ('후', 23),
#  ('뭐', 22),
#  ('지', 21),
#  ('책', 21),
#  ('바', 20),
#  ('부', 20),
#  ('적', 20),
#  ('힘', 19),
#  ('데', 19),
#  ('길', 18),
#  ('앞', 18),
#  ('거', 18),
#  ('번', 17),
#  ('의', 16),
#  ('1', 15),
#  ('진', 15),
#  ('을', 14),
#  ('곳', 14),
#  ('군', 14),
#  ('통', 13),
#  ('■', 13),
#  ('끝', 13),
#  ('동', 13),
#  ('꿈', 13),
#  ('뿐', 13),
#  ('추', 12),
#  ('증', 12),
#  ('신', 11),
#  ('애', 11),
#  ('근', 11),
#  ('만', 11),
#  ('★', 11),
#  ('를', 11),
#  ('+', 11),
#  ('5', 10),
#  ('2', 10),
#  ('짓', 10),
#  ('듯', 10),
#  ('농', 10),
#  ('안', 10),
#  ('차', 10),
#  ('죄', 9),
#  ('분', 9),
#  ('식', 9),
#  ('으', 9),
#  ('핵', 9),
#  ('현', 9),
#  ('배', 9),
#  ('두', 9),
#  ('반', 9),
#  ('방', 8),
#  ('&', 8),
#  ('불', 8),
#  ('3', 8),
#  ('라', 8),
#  ('밥', 7),
#  ('막', 7),
#  ('조', 7),
#  ('외', 7),
#  ('파', 7),
#  ('원', 7),
#  ('월', 7),
#  ('값', 7),
#  ('피', 7),
#  ('감', 7),
#  ('명', 7),
#  ('성', 6),
#  ('술', 6),
#  ('도', 6),
#  ('놈', 6),
#  ('4', 6),
#  ('발', 6),
#  ('빚', 6),
#  ('뒤', 6),
#  ('문', 6),
#  ('척', 6),
#  ('칼', 6),
#  ('질', 6),
#  ('소', 6),
#  ('갑', 6),
#  ('살', 6),
#  ('로', 6),
#  ('남', 6),
#  ('날', 6),
#  ('무', 6),
#  ('장', 6),
#  ('뜻', 6),
#  ('유', 6),
#  ('기', 6),
#  ('판', 5),
#  ('백', 5),
#  ('님', 5),
#  ('정', 5),
#  ('몇', 5),
#  ('년', 5),
#  ('손', 5),
#  ('초', 5),
#  ('화', 5),
#  ('미', 5),
#  ('→', 5),
#  ('당', 5),
#  ('눈', 5),
#  ('독', 5),
#  ('밖', 4),
#  ('철', 4),
#  ('땅', 4),
#  ('강', 4),
#  ('속', 4),
#  ('상', 4),
#  ('달', 4),
#  ('귀', 4),
#  ('터', 4),
#  ('북', 4),
#  ('구', 4),
#  ('숨', 4),
#  ('되', 4),
#  ('ㆍ', 4),
#  ('합', 4),
#  ('욕', 3),
#  ('세', 3),
#  ('고', 3),
#  ('밑', 3),
#  ('치', 3),
#  ('격', 3),
#  ('관', 3),
#  ('채', 3),
#  ('꼴', 3),
#  ('●', 3),
#  ('첫', 3),
#  ('#', 3),
#  ('별', 3),
#  ('입', 3),
#  ('탓', 3),
#  ('청', 3),
#  ('벌', 3),
#  ('작', 3),
#  ('혼', 3),
#  ('쇼', 3),
#  ('은', 3),
#  ('표', 3),
#  ('7', 3),
#  ('페', 3),
#  ('편', 3),
#  ('최', 3),
#  ('팀', 3),
#  ('쪽', 3),
#  ('팔', 3),
#  ('件', 3),
#  ('평', 2),
#  ('약', 2),
#  ('완', 2),
#  ('폭', 2),
#  ('얘', 2),
#  ('딸', 2),
#  ('공', 2),
#  ('닭', 2),
#  ('허', 2),
#  ('▣', 2),
#  ('※', 2),
#  ('◆', 2),
#  ('겸', 2),
#  ('폼', 2),
#  ('여', 2),
#  ('취', 2),
#  ('쥐', 2),
#  ('우', 2),
#  ('교', 2),
#  ('쌀', 2),
#  ('빛', 2),
#  ('혹', 2),
#  ('목', 2),
#  ('못', 2),
#  ('형', 2),
#  ('짝', 2),
#  ('ᆢ', 2),
#  ('사', 2),
#  ('보', 2),
#  ('급', 2),
#  ('노', 2),
#  ('모', 2),
#  ('재', 2),
#  ('잠', 2),
#  ('퇴', 2),
#  ('확', 2),
#  ('봉', 2),
#  ('낮', 2),
#  ('0', 2),
#  ('찿', 2),
#  ('코', 2),
#  ('맘', 1),
#  (')', 1),
#  ('앱', 1),
#  ('턱', 1),
#  ('산', 1),
#  ('칡', 1),
#  ('(', 1),
#  ('흑', 1),
#  ('▒', 1),
#  ('홍', 1),
#  ('선', 1),
#  ('떡', 1),
#  ('씨', 1),
#  ('용', 1),
#  ('욱', 1),
#  ('◀', 1),
#  ('갭', 1),
#  ('맛', 1),
#  ('승', 1),
#  ('석', 1),
#  ('겉', 1),
#  ('恨', 1),
#  ('쒼', 1),
#  ('9', 1),
#  ('맟', 1),
#  ('6', 1),
#  ('솜', 1),
#  ('계', 1),
#  ('땀', 1),
#  ('옆', 1),
#  ('너', 1),
#  ('삥', 1),
#  ('☆', 1),
#  ('족', 1),
#  ('ㅋ', 1),
#  ('득', 1),
#  ('금', 1),
#  ('네', 1),
#  ('쟁', 1),
#  ('者', 1),
#  ('견', 1),
#  ('순', 1),
#  ('內', 1),
#  ('출', 1),
#  ('뭔', 1),
#  ('끼', 1),
#  ('탈', 1),
#  ('☎', 1),
#  ('실', 1),
#  ('올', 1),
#  ('효', 1),
#  ('궁', 1),
#  ('꽃', 1),
#  ('점', 1),
#  ('○', 1),
#  ('행', 1),
#  ('송', 1),
#  ('잡', 1),
#  ('회', 1),
#  ('음', 1),
#  ('단', 1),
#  ('몸', 1),
#  ('흥', 1),
#  ('병', 1),
#  ('면', 1),
#  ('숲', 1),
#  ('포', 1),
#  ('콩', 1),
#  ('쉐', 1),
#  ('측', 1),
#  ('ㅡ', 1),
#  ('요', 1),
#  ('룰', 1),
#  ('양', 1),
#  ('연', 1),
#  ('쉬', 1),
#  ('벽', 1),
#  ('文', 1),
#  ('예', 1),
#  ('티', 1),
#  ('먹', 1),
#  ('암', 1)]

# %%
one4th = nltk.Text(one_words2, name = "한글자")

# %%
one4th.vocab().most_common()
# Out:
# [('수', 55),
#  ('폐', 32),
#  ('것', 29),
#  ('개', 11),
#  ('말', 11),
#  ('전', 10),
#  ('법', 9),
#  ('일', 9),
#  ('꿈', 7),
#  ('리', 7),
#  ('등', 6),
#  ('나', 6),
#  ('건', 6),
#  ('이', 6),
#  ('투', 5),
#  ('제', 5),
#  ('중', 5),
#  ('신', 4),
#  ('삶', 4),
#  ('→', 4),
#  ('국', 4),
#  ('앱', 3),
#  ('죽', 3),
#  ('그', 3),
#  ('★', 3),
#  ('시', 3),
#  ('남', 3),
#  ('저', 3),
#  ('정', 3),
#  ('초', 3),
#  ('책', 3),
#  ('앞', 3),
#  ('외', 3),
#  ('속', 3),
#  ('들', 3),
#  ('바', 3),
#  ('내', 3),
#  ('주', 3),
#  ('해', 3),
#  ('거', 3),
#  ('적', 3),
#  ('코', 3),
#  ('으', 2),
#  ('대', 2),
#  ('뇌', 2),
#  ('부', 2),
#  ('자', 2),
#  ('지', 2),
#  ('군', 2),
#  ('팔', 2),
#  ('추', 2),
#  ('답', 2),
#  ('님', 2),
#  ('성', 2),
#  ('막', 2),
#  ('기', 2),
#  ('때', 2),
#  ('&', 2),
#  ('동', 2),
#  ('축', 2),
#  ('글', 2),
#  ('망', 2),
#  ('한', 2),
#  ('탓', 2),
#  ('방', 1),
#  ('체', 1),
#  ('쇼', 1),
#  ('질', 1),
#  ('미', 1),
#  ('홍', 1),
#  ('듯', 1),
#  ('ㅡ', 1),
#  ('☞', 1),
#  ('뭐', 1),
#  ('점', 1),
#  ('강', 1),
#  ('칼', 1),
#  ('식', 1),
#  ('교', 1),
#  ('논', 1),
#  ('를', 1),
#  ('눈', 1),
#  ('귀', 1),
#  ('원', 1),
#  ('진', 1),
#  ('쟁', 1),
#  ('줄', 1),
#  ('불', 1),
#  ('힘', 1),
#  ('피', 1),
#  ('데', 1),
#  ('후', 1),
#  ('행', 1),
#  ('번', 1),
#  ('승', 1),
#  ('득', 1),
#  ('단', 1),
#  ('심', 1),
#  ('흥', 1),
#  ('도', 1),
#  ('_', 1),
#  ('무', 1),
#  ('다', 1),
#  ('內', 1),
#  ('북', 1),
#  ('몰', 1),
#  ('학', 1),
#  ('장', 1),
#  ('의', 1),
#  ('걍', 1),
#  ('과', 1),
#  ('밑', 1),
#  ('욕', 1),
#  ('상', 1),
#  ('몇', 1),
#  ('년', 1),
#  ('뒤', 1),
#  ('우', 1),
#  ('길', 1),
#  ('3', 1)]

# %%
stop_words_work = ["일자리", '청원','정부','한국','문재','대통령님']
stop_words_work.extend(one_words1)
len(stop_words_work)
# Out:
# 4203

# %%
stop_words_4th = ['청원','정부','한국','문재','대통령님']
stop_words_4th.extend(one_words2)
len(stop_words_4th)
# Out:
# 404

# %%
work_nouns = [word for word in nounswork if word not in stop_words_work]
len(work_nouns)
# Out:
# 43785

# %%
fourth_nouns = [word for word in nouns4th if word not in stop_words_4th]
len(fourth_nouns)
# Out:
# 4346

# %%
work_nouns1 = nltk.Text(work_nouns, name = "일자리")
fourth_nouns = nltk.Text(fourth_nouns, name = "일자리")

# %%
work_noun_common = work_nouns1.vocab().most_common()
fourth_noun_common = fourth_nouns.vocab().most_common()

# %%
fourth_noun_common
# Out:
# [('규제', 54),
#  ('반대', 40),
#  ('대한민국', 38),
#  ('일자리', 32),
#  ('암호화폐', 31),
#  ('정책', 30),
#  ('개선', 29),
#  ('항공기', 26),
#  ('4차', 25),
#  ('국제선', 25),
#  ('계류장', 25),
#  ('여름', 24),
#  ('항공기소음', 23),
#  ('매연', 23),
#  ('인간', 23),
#  ('거래소', 23),
#  ('4차산업', 22),
#  ('국민', 22),
#  ('교육', 22),
#  ('기본적', 22),
#  ('생활권', 21),
#  ('미래', 19),
#  ('필요', 19),
#  ('요청', 19),
#  ('블록체', 19),
#  ('경제', 17),
#  ('제안', 16),
#  ('4차산업혁명', 16),
#  ('산업혁명', 15),
#  ('산업', 15),
#  ('관련', 14),
#  ('도입', 13),
#  ('발전', 13),
#  ('폐쇄', 13),
#  ('요구', 12),
#  ('촉구', 12),
#  ('기업', 12),
#  ('생각', 12),
#  ('찬성', 12),
#  ('김포공항', 11),
#  ('개발', 10),
#  ('원전', 10),
#  ('대책', 10),
#  ('문제', 10),
#  ('창출', 10),
#  ('시행', 10),
#  ('방안', 10),
#  ('화폐', 10),
#  ('허용', 9),
#  ('추진', 9),
#  ('활성화', 9),
#  ('교육부', 9),
#  ('육성', 9),
#  ('지원', 9),
#  ('시스템', 9),
#  ('기술', 9),
#  ('비트코', 9),
#  ('전환', 8),
#  ('투자', 8),
#  ('최저임금', 8),
#  ('청년', 8),
#  ('개혁', 8),
#  ('김상조', 8),
#  ('시장', 8),
#  ('중소기업', 7),
#  ('사람', 7),
#  ('우리', 7),
#  ('청년실업', 7),
#  ('공공기관', 7),
#  ('국민들', 7),
#  ('강화', 7),
#  ('철회', 7),
#  ('이유', 7),
#  ('우리나라', 7),
#  ('도박', 7),
#  ('국가', 7),
#  ('폐지', 7),
#  ('국내', 7),
#  ('블록체인', 7),
#  ('가상화폐거래소', 7),
#  ('가상', 7),
#  ('해결', 6),
#  ('성장', 6),
#  ('나라', 6),
#  ('포함', 6),
#  ('확대', 6),
#  ('장관', 6),
#  ('군대', 6),
#  ('수능', 6),
#  ('대통령', 6),
#  ('해임', 6),
#  ('교육제도', 6),
#  ('실시', 6),
#  ('공무원', 6),
#  ('설립', 6),
#  ('변경', 6),
#  ('진실', 6),
#  ('카풀', 5),
#  ('처벌', 5),
#  ('가능', 5),
#  ('무능', 5),
#  ('결정', 5),
#  ('합법화', 5),
#  ('사용', 5),
#  ('완화', 5),
#  ('수학', 5),
#  ('강력', 5),
#  ('한국의', 5),
#  ('변화', 5),
#  ('부동산', 5),
#  ('검토', 5),
#  ('적극', 5),
#  ('실패', 5),
#  ('대비', 5),
#  ('삼성', 5),
#  ('인터넷', 5),
#  ('학생들', 5),
#  ('정시', 5),
#  ('시대', 5),
#  ('모병', 5),
#  ('비트코인', 5),
#  ('아이디어', 4),
#  ('자가용', 4),
#  ('기반', 4),
#  ('내용', 4),
#  ('경제정책', 4),
#  ('신설', 4),
#  ('정권', 4),
#  ('대응', 4),
#  ('전국', 4),
#  ('저출산', 4),
#  ('때문', 4),
#  ('학생', 4),
#  ('운영', 4),
#  ('정치', 4),
#  ('법무부', 4),
#  ('아파트', 4),
#  ('개편', 4),
#  ('소득주도성장', 4),
#  ('국회', 4),
#  ('공약', 4),
#  ('대학', 4),
#  ('설치', 4),
#  ('기하', 4),
#  ('벡터', 4),
#  ('건설', 4),
#  ('문재인', 4),
#  ('문정부', 4),
#  ('답변', 4),
#  ('혁명', 4),
#  ('제외', 4),
#  ('시작', 4),
#  ('수시', 4),
#  ('조사', 4),
#  ('공정거래위원장', 4),
#  ('경기', 4),
#  ('피해자', 4),
#  ('미국', 4),
#  ('판사', 4),
#  ('교체', 4),
#  ('불법', 4),
#  ('문재인정부', 3),
#  ('방지', 3),
#  ('여성', 3),
#  ('근원적', 3),
#  ('카카오', 3),
#  ('원자력', 3),
#  ('청와대', 3),
#  ('국민투표', 3),
#  ('인공지능', 3),
#  ('채용', 3),
#  ('50', 3),
#  ('정당', 3),
#  ('차단', 3),
#  ('인력', 3),
#  ('정보', 3),
#  ('전문가들', 3),
#  ('전기차', 3),
#  ('시민들', 3),
#  ('반출', 3),
#  ('건립', 3),
#  ('서비스', 3),
#  ('교사', 3),
#  ('적극적', 3),
#  ('정상화', 3),
#  ('이전', 3),
#  ('사업', 3),
#  ('북한', 3),
#  ('고등학교', 3),
#  ('비판', 3),
#  ('모두', 3),
#  ('청구', 3),
#  ('장관님', 3),
#  ('절실', 3),
#  ('도시', 3),
#  ('핵심', 3),
#  ('추천', 3),
#  ('최저시급', 3),
#  ('심각', 3),
#  ('한번', 3),
#  ('체계', 3),
#  ('마련', 3),
#  ('사장', 3),
#  ('해결책', 3),
#  ('어디', 3),
#  ('자동차', 3),
#  ('관계자들', 3),
#  ('국민연금', 3),
#  ('사퇴', 3),
#  ('하루', 3),
#  ('근본적', 3),
#  ('중요', 3),
#  ('딥페이크', 3),
#  ('영상', 3),
#  ('제작자및', 3),
#  ('유포자', 3),
#  ('이용', 3),
#  ('기회', 3),
#  ('정부지원', 3),
#  ('드론', 3),
#  ('수립', 3),
#  ('정책추진', 3),
#  ('암호화화폐', 3),
#  ('대입', 3),
#  ('시험', 3),
#  ('규제개혁', 3),
#  ('평가', 3),
#  ('학생부종합전형', 3),
#  ('대입제도', 3),
#  ('금지', 3),
#  ('인증', 3),
#  ('증원', 3),
#  ('방법', 3),
#  ('부탁', 3),
#  ('학교', 3),
#  ('공개', 3),
#  ('한국GM', 3),
#  ('행복', 3),
#  ('교복', 3),
#  ('기능', 3),
#  ('발급', 3),
#  ('현정부', 3),
#  ('합리적', 3),
#  ('기관', 3),
#  ('서민', 3),
#  ('10년', 3),
#  ('토론', 3),
#  ('관료들', 3),
#  ('지지율', 3),
#  ('금융위원장', 3),
#  ('사망선고', 3),
#  ('규제반대', 3),
#  ('상실', 3),
#  ('대기업', 2),
#  ('세계최고', 2),
#  ('로봇', 2),
#  ('구체적', 2),
#  ('권력', 2),
#  ('해법', 2),
#  ('미래산업', 2),
#  ('복지', 2),
#  ('패러다임', 2),
#  ('실업문제', 2),
#  ('세상', 2),
#  ('예상', 2),
#  ('발전소', 2),
#  ('논란', 2),
#  ('2차', 2),
#  ('피해', 2),
#  ('조치', 2),
#  ('구축', 2),
#  ('누구', 2),
#  ('연구', 2),
#  ('발상', 2),
#  ('공유경제', 2),
#  ('두마리', 2),
#  ('조국', 2),
#  ('민정', 2),
#  ('홈페이지', 2),
#  ('관리자', 2),
#  ('차별', 2),
#  ('언제', 2),
#  ('불안', 2),
#  ('마음', 2),
#  ('저작권', 2),
#  ('공공시설', 2),
#  ('주시길', 2),
#  ('부산시', 2),
#  ('카풀서비스', 2),
#  ('창당', 2),
#  ('보충', 2),
#  ('말좀들으세요', 2),
#  ('드론자격증', 2),
#  ('실기시험', 2),
#  ('불만', 2),
#  ('경제난', 2),
#  ('제한', 2),
#  ('수소차', 2),
#  ('자율주행차', 2),
#  ('전략', 2),
#  ('구글', 2),
#  ('선진국', 2),
#  ('집중', 2),
#  ('손해', 2),
#  ('전면', 2),
#  ('건의', 2),
#  ('거부', 2),
#  ('제도화', 2),
#  ('실현', 2),
#  ('모바', 2),
#  ('주식', 2),
#  ('공급', 2),
#  ('감사', 2),
#  ('안정화', 2),
#  ('희토류', 2),
#  ('서울', 2),
#  ('연장', 2),
#  ('관련하', 2),
#  ('제도개선', 2),
#  ('월급', 2),
#  ('대안', 2),
#  ('복지정책', 2),
#  ('세계', 2),
#  ('공간', 2),
#  ('미세먼지', 2),
#  ('교육과정', 2),
#  ('의무화', 2),
#  ('보험금', 2),
#  ('예방', 2),
#  ('유은혜', 2),
#  ('교육개혁', 2),
#  ('바보', 2),
#  ('의무', 2),
#  ('성공', 2),
#  ('여당', 2),
#  ('출산장려', 2),
#  ('상품', 2),
#  ('대표', 2),
#  ('황당', 2),
#  ('해외', 2),
#  ('학원', 2),
#  ('조속', 2),
#  ('입시', 2),
#  ('시급', 2),
#  ('기업들', 2),
#  ('의료', 2),
#  ('문제점', 2),
#  ('유치원', 2),
#  ('초등', 2),
#  ('과목', 2),
#  ('과세', 2),
#  ('초등학교', 2),
#  ('일자리정책', 2),
#  ('도움', 2),
#  ('정직', 2),
#  ('개설', 2),
#  ('반영', 2),
#  ('공기업', 2),
#  ('관리', 2),
#  ('법제화', 2),
#  ('세금', 2),
#  ('사건', 2),
#  ('야간자율학습', 2),
#  ('인상', 2),
#  ('광복절', 2),
#  ('연설', 2),
#  ('최소한', 2),
#  ('가정', 2),
#  ('김상곤', 2),
#  ('연금', 2),
#  ('제보', 2),
#  ('지속', 2),
#  ('위협', 2),
#  ('다문화폐', 2),
#  ('방향', 2),
#  ('과정', 2),
#  ('수준', 2),
#  ('드론규제', 2),
#  ('계획', 2),
#  ('리얼돌', 2),
#  ('24시간', 2),
#  ('허구', 2),
#  ('국가주도', 2),
#  ('미래먹거리', 2),
#  ('법안', 2),
#  ('발생', 2),
#  ('경마', 2),
#  ('철폐', 2),
#  ('위원회', 2),
#  ('책임자', 2),
#  ('규탄', 2),
#  ('원전정책', 2),
#  ('쓰레기', 2),
#  ('소리', 2),
#  ('통합', 2),
#  ('지방자치제', 2),
#  ('발언', 2),
#  ('진행', 2),
#  ('수수료', 2),
#  ('현실', 2),
#  ('교과과정', 2),
#  ('농업', 2),
#  ('희망', 2),
#  ('기준', 2),
#  ('청원드', 2),
#  ('부당한', 2),
#  ('탄원', 2),
#  ('청년실업문제의얽힌', 2),
#  ('실타래', 2),
#  ('느낀점', 2),
#  ('어린이집', 2),
#  ('유아', 2),
#  ('교육정책', 2),
#  ('게임', 2),
#  ('난민반대', 2),
#  ('교과서', 2),
#  ('입시제도', 2),
#  ('채굴회사', 2),
#  ('대체에너지', 2),
#  ('권고', 2),
#  ('제정해', 2),
#  ('암호화페', 2),
#  ('제도적', 2),
#  ('기본소득제', 2),
#  ('난민옹호', 2),
#  ('주택', 2),
#  ('제공', 2),
#  ('1일', 2),
#  ('행정', 2),
#  ('국민모두', 2),
#  ('공론화', 2),
#  ('수능제도', 2),
#  ('사회', 2),
#  ('한국경제', 2),
#  ('문화', 2),
#  ('카이스트', 2),
#  ('난민법폐지~불체', 2),
#  ('추방', 2),
#  ('범죄자', 2),
#  ('국회의원', 2),
#  ('기록', 2),
#  ('자유학년제', 2),
#  ('택시업계', 2),
#  ('강원랜드', 2),
#  ('핵심기술', 2),
#  ('공정위원장', 2),
#  ('제도', 2),
#  ('직장', 2),
#  ('투표', 2),
#  ('비전', 2),
#  ('무인화', 2),
#  ('인재들', 2),
#  ('반도체', 2),
#  ('일베·워마드법', 2),
#  ('비용', 2),
#  ('1석3조', 2),
#  ('정책자금', 2),
#  ('스타트업', 2),
#  ('대상', 2),
#  ('공무원들', 2),
#  ('온라인', 2),
#  ('신청', 2),
#  ('지역', 2),
#  ('노인', 2),
#  ('해소', 2),
#  ('선택', 2),
#  ('공정', 2),
#  ('주도권', 2),
#  ('초고속', 2),
#  ('무책임', 2),
#  ('취소', 2),
#  ('가상증표', 2),
#  ('서버', 2),
#  ('지금', 2),
#  ('파산', 2),
#  ('사랑', 2),
#  ('우유급식', 2),
#  ('유지', 2),
#  ('우체국', 2),
#  ('연구소', 2),
#  ('전자화폐', 2),
#  ('신규', 2),
#  ('개헌안', 2),
#  ('야당', 2),
#  ('광양', 2),
#  ('업자', 2),
#  ('회사', 2),
#  ('세대', 2),
#  ('역차별', 2),
#  ('국제', 2),
#  ('위험한', 2),
#  ('운동', 2),
#  ('보안프로그램', 2),
#  ('의료기', 2),
#  ('식약처', 2),
#  ('제조업', 2),
#  ('경질', 2),
#  ('폐섬유화', 2),
#  ('천식', 2),
#  ('4단계', 2),
#  ('도박사이트', 2),
#  ('명칭', 2),
#  ('엉터리시스템', 2),
#  ('반칙', 2),
#  ('근무', 2),
#  ('전세계', 2),
#  ('분야', 2),
#  ('응용', 2),
#  ('청년일자리', 2),
#  ('양적완화', 2),
#  ('치기공사', 2),
#  ('졸업생', 2),
#  ('1명', 2),
#  ('취업', 2),
#  ('쇼통령', 2),
#  ('자유', 2),
#  ('공매', 2),
#  ('회복', 2),
#  ('지름길', 2),
#  ('대답', 2),
#  ('선점', 2),
#  ('사회적', 2),
#  ('블록체인(암호화폐)', 2),
#  ('사기극', 2),
#  ('바로알고', 2),
#  ('안녕', 2),
#  ('장관들', 2),
#  ('과도한', 2),
#  ('분석', 2),
#  ('군복무', 2),
#  ('차량공유', 2),
#  ('빙자', 2),
#  ('택시영업', 2),
#  ('불가능', 2),
#  ('김동연', 2),
#  ('경제부총리', 2),
#  ('박상기', 2),
#  ('법무부장관', 2),
#  ('금감원장', 2),
#  ('당신', 2),
#  ('300', 2),
#  ('법무장관', 2),
#  ('징계', 2),
#  ('역행', 2),
#  ('유시민', 2),
#  ('에너지', 2),
#  ('가상화폐관련', 2),
#  ('가상화페', 2),
#  ('폐지반대', 2),
#  ('손해배상', 2),
#  ('피해자들', 2),
#  ('신중한', 2),
#  ('장려정책', 2),
#  ('쪽박차', 2),
#  ('최종구', 2),
#  ('확정', 2),
#  ('가상화폐거래', 2),
#  ('★★★★★', 2),
#  ('투기꾼들', 2),
#  ('기술적모순', 2),
#  ('한계', 2),
#  ('발표', 2),
#  ('세계원천기술', 1),
#  ('개발해서', 1),
#  ('되주세요', 1),
#  ("'양**'", 1),
#  ('군사용', 1),
#  ('드론관련', 1),
#  ('시험권', 1),
#  ('전문교육원', 1),
#  ('이관', 1),
#  ('개정', 1),
#  ('울산', 1),
#  ('대선공약', 1),
#  ('제1호', 1),
#  ('조선해양플랜트연구원', 1),
#  ('울산유치', 1),
#  ('경찰', 1),
#  ('민영화', 1),
#  ('암호코인', 1),
#  ('폰지사', 1),
#  ('존경', 1),
#  ('알리옵니', 1),
#  ('항거', 1),
#  ('아부', 1),
#  ('복지산업(어려운', 1),
#  ('교육사업', 1),
#  ('복지문제', 1),
#  ('창조경제', 1),
#  ('성공모델', 1),
#  ('문정권', 1),
#  ('자율형', 1),
#  ('연구학교', 1),
#  ('힘찬대한민국', 1),
#  ('위헝하', 1),
#  ('현대차부진', 1),
#  ('돕지마', 1),
#  ('아마추어', 1),
#  ('재창출', 1),
#  ('가능한', 1),
#  ('핵융합', 1),
#  ('★.', 1),
#  ('노동자', 1),
#  ('부당해고', 1),
#  ('1차피해,', 1),
#  ('3차', 1),
#  ('북한경제', 1),
#  ('과잉공급', 1),
#  ('개인택시기사', 1),
#  ('카카오카풀', 1),
#  ('전업할때', 1),
#  ('우선권', 1),
#  ('신경망', 1),
#  ('내일', 1),
#  ('50만명', 1),
#  ('개인택시', 1),
#  ('4차산업이란', 1),
#  ('토끼잡기', 1),
#  ('자기애성', 1),
#  ('인격장애', 1),
#  ('정신병원', 1),
#  ('입원', 1),
#  ('기초연구자들', 1),
#  ('글삭제', 1),
#  ('경제활성화', 1),
#  ('언제쯤', 1),
#  ('저작자', 1),
#  ('청년해외진출', 1),
#  ('은행', 1),
#  ('채용시스템', 1),
#  ('선진화', 1),
#  ('방식', 1),
#  ('군단위', 1),
#  ('위탁사업', 1),
#  ('채용비', 1),
#  ('추천인사제도', 1),
#  ('전수조사', 1),
#  ('남구', 1),
#  ('용호동', 1),
#  ('메트로시티', 1),
#  ('건물군', 1),
#  ('도로명', 1),
#  ('스마트', 1),
#  ('전자신분증', 1),
#  ('송유근', 1),
#  ('원천적', 1),
#  ('과학재능', 1),
#  ('강서구', 1),
#  ('살인사건', 1),
#  ('현실파악', 1),
#  ('분노', 1),
#  ('흑우궁민들', 1),
#  ('중장년ㆍ젊은층', 1),
#  ('3D직업', 1),
#  ('취업시', 1),
#  ('지원요', 1),
#  ('실천', 1),
#  ('연소득', 1),
#  ('8만달러', 1),
#  ('세계1위', 1),
#  ('룩셈브르크', 1),
#  ('평범', 1),
#  ('카카오카풀등', 1),
#  ('유상운송행위', 1),
#  ('원천', 1),
#  ('간호사', 1),
#  ('임금', 1),
#  ('향상및', 1),
#  ('뿌리산업', 1),
#  ('대기기간', 1),
#  ('너무길어', 1),
#  ('수험생', 1),
#  ('고조', 1),
#  ('실업난', 1),
#  ('인재', 1),
#  ('발견', 1),
#  ('출생신고', 1),
#  ('인명용', 1),
#  ('부모', 1),
#  ('이름', 1),
#  ('서울-부산', 1),
#  ('해운대역', 1),
#  ('개통', 1),
#  ('과학기술', 1),
#  ('인프', 1),
#  ('성장엔진', 1),
#  ('범죄', 1),
#  ('시험시간', 1),
#  ('전자계산기', 1),
#  ('실용적', 1),
#  ('농어촌', 1),
#  ('럭비공', 1),
#  ('트럼프', 1),
#  ('전술^^*', 1),
#  ('자유민주주', 1),
#  ('대한민국정부', 1),
#  ('이대로두고봐야하나요', 1),
#  ('관계자', 1),
#  ('국가경쟁력', 1),
#  ('제2공용어정채', 1),
#  ('입안', 1),
#  ('허가', 1),
#  ('금융위원회', 1),
#  ('공모주', 1),
#  ('개인배정', 1),
#  ("축소(폐지)건'", 1),
#  ('고용문제', 1),
#  ('안되요', 1),
#  ('직업', 1),
#  ('종류자체', 1),
#  ('절반수준', 1),
#  ('신중함', 1),
#  ('결정장애', 1),
#  ('경제살리', 1),
#  ('혁신성장', 1),
#  ('신도시', 1),
#  ('판타지', 1),
#  ('랜드', 1),
#  ('통일도', 1),
#  ('여성단체', 1),
#  ('단체', 1),
#  ('핵심산업', 1),
#  ('무산', 1),
#  ('임용시험법', 1),
#  ('개정해서', 1),
#  ('박사학위', 1),
#  ('보유자', 1),
#  ('채용금지', 1),
#  ('시켜주시길', 1),
#  ('혁신', 1),
#  ('도전', 1),
#  ('재활용품', 1),
#  ('수매제', 1),
#  ('청라국제도시', 1),
#  ('구글과LG유치', 1),
#  ('정신못차리', 1),
#  ('정책책임자들', 1),
#  ('공무원행정처리', 1),
#  ('인공지능화', 1),
#  ('37', 1),
#  ('뭔가요', 1),
#  ('성취', 1),
#  ('현행', 1),
#  ('공교육', 1),
#  ('문제인', 1),
#  ('모르쇠', 1),
#  ('셧다운제', 1),
#  ('예비군', 1),
#  ('생활권임', 1),
#  ('유태인', 1),
#  ('가능한데', 1),
#  ('스마트카', 1),
#  ('기술과제', 1),
#  ('12개사', 1),
#  ('얼토당토', 1),
#  ('상장폐지', 1),
#  ('개미투자자', 1),
#  ('가족', 1),
#  ('20만명', 1),
#  ('문재인대통령님', 1),
#  ('개미투자들', 1),
#  ('20', 1),
#  ('개미투자자들', 1),
#  ('제사', 1),
#  ('추석', 1),
#  ('명절', 1),
#  ('반포', 1),
#  ('고속터미널', 1),
#  ('해당부', 1),
#  ('임대주택', 1),
#  ('검토요청', 1),
#  ('*국민이참여하는-국민시민당', 1),
#  ('특구', 1),
#  ('지정', 1),
#  ('간곡', 1),
#  ('페러다임', 1),
#  ('택시감차', 1),
#  ('순수', 1),
#  ('일반', 1),
#  ('입문', 1),
#  ('암호화폐거래환경', 1),
#  ('강화해주세요(뉴욕주', 1),
#  ('조사한', 1),
#  ('리포터첨부', 1),
#  ('북측', 1),
#  ('성의', 1),
#  ('환대', 1),
#  ('민족', 1),
#  ('대학안', 1),
#  ('월300이상', 1),
#  ('제언드', 1),
#  ('우리들', 1),
#  ('정제회사', 1),
#  ('전략자원', 1),
#  ('##03', 1),
#  ('[#]', 1),
#  ('02', 1),
#  ('서울도심', 1),
#  ('층고높', 1),
#  ('10평영구임대주택', 1),
#  ('건설촉구', 1),
#  ('성장산업도시', 1),
#  ('평택', 1),
#  ('지제역', 1),
#  ('수도권광역교통망', 1),
#  ('지방행정', 1),
#  ('민원사무처리', 1),
#  ('일원화', 1),
#  ('3학년', 1),
#  ('경제해법입니', 1),
#  ('혁신도시', 1),
#  ('메갈로폴리스전략-', 1),
#  ('차등의결권', 1),
#  ('불필요한', 1),
#  ('지배구조', 1),
#  ('자금', 1),
#  ('투입', 1),
#  ('성장산업', 1),
#  ('발굴', 1),
#  ('세수', 1),
#  ('확보', 1),
#  ('부동산대책', 1),
#  ('용산미군부지', 1),
#  ('건축사적', 1),
#  ('재탄생', 1),
#  ('평양', 1),
#  ('2032월드컵', 1),
#  ('개인회생', 1),
#  ('포용국가\xa0청와대', 1),
#  ('대통령비서실\xa02018.', 1),
#  ('09.', 1),
#  ('06', 1),
#  ('카카오택시', 1),
#  ('서해', 1),
#  ('대형', 1),
#  ('풍력', 1),
#  ('발전기', 1),
#  ('여러개', 1),
#  ('설치해서', 1),
#  ('에너지확보', 1),
#  ('원전문제', 1),
#  ('무더위', 1),
#  ('해소하자', 1),
#  ('정략적', 1),
#  ('작품', 1),
#  ('운동권', 1),
#  ('유리한', 1),
#  ('창출할건데요', 1),
#  ('합법적', 1),
#  ('우버', 1),
#  ('모델', 1),
#  ('억울', 1),
#  ('법(형법)', 1),
#  ('소개', 1),
#  ('법률', 1),
#  ('강연', 1),
#  ('전자건강보험증', 1),
#  ('도입해주세요-메르스', 1),
#  ('전염병', 1),
#  ('지명', 1),
#  ('출발', 1),
#  ('부동산투기꾼', 1),
#  ('관련지들', 1),
#  ('다짤라라~', 1),
#  ('기술개발', 1),
#  ('대로', 1),
#  ('일해', 1),
#  ('실패한', 1),
#  ('경제정책주도자', 1),
#  ('장하성', 1),
#  ('교육비', 1),
#  ('지원책', 1),
#  ('나무의사', 1),
#  ('드론교육비', 1),
#  ('재생', 1),
#  ('뉴딜', 1),
#  ('요약본', 1),
#  ('포용국', 1),
#  ('선언', 1),
#  ('하길', 1),
#  ('4%성장', 1),
#  ('부동산투기', 1),
#  ('전쟁', 1),
#  ('서울부동산', 1),
#  ('단번', 1),
#  ('무력', 1),
#  ('고려', 1),
#  ('지방이전', 1),
#  ('10가지', 1),
#  ('질문', 1),
#  ('피부', 1),
#  ('와닿', 1),
#  ('보건복지사업', 1),
#  ('의료시스템(원격진료시스템,', 1),
#  ('의료인', 1),
#  ('의료기관', 1),
#  ('활동', 1),
#  ('규제완화', 1),
#  ('청년희망드림', 1),
#  ('같이간', 1),
#  ('직원', 1),
#  ('신용조회', 1),
#  ('3만명', 1),
#  ('산림기술자들', 1),
#  ('생존', 1),
#  ('상수', 1),
#  ('수원지', 1),
#  ('진출', 1),
#  ('말씀', 1),
#  ('올림니', 1),
#  ('임대사업자', 1),
#  ('가장한', 1),
#  ('다주택자', 1),
#  ('투기근절', 1),
#  ('국토부', 1),
#  ('고양시', 1),
#  ('공공택지', 1),
#  ('자족도시', 1),
#  ('기업도시', 1),
#  ('내일배움카드', 1),
#  ('사전배정제(쿼터제)', 1),
#  ('못가', 1),
#  ('쓰질못하는데', 1),
#  ('국민전체', 1),
#  ('교육문제', 1),
#  ('문대통령께', 1),
#  ('상기', 1),
#  ('제조업을살려주세요', 1),
#  ('조사들어가주세요', 1),
#  ('악용', 1),
#  ('삼성역', 1),
#  ('현대차', 1),
#  ('글로벌비즈니스센터(GBC)', 1),
#  ('착공', 1),
#  ('요청드', 1),
#  ('초등교육', 1),
#  ('단계적', 1),
#  ('어떨까요', 1),
#  ('불법체류외국인취업', 1),
#  ('손자병법', 1),
#  ('정독', 1),
#  ('몽골티베트', 1),
#  ('꼴납니', 1),
#  ('마을', 1),
#  ('공동실습장', 1),
#  ('당당', 1),
#  ('법적제도적', 1),
#  ('장치마련', 1),
#  ('판검사', 1),
#  ('변호사업무제한', 1),
#  ('변호사', 1),
#  ('정년도입', 1),
#  ('직업교육', 1),
#  ('시설', 1),
#  ('현실화', 1),
#  ('불평등사회', 1),
#  ('구조', 1),
#  ('깨트려야', 1),
#  ('누리교육', 1),
#  ('누리교육과정', 1),
#  ('금지해', 1),
#  ('것들', 1),
#  ('홍보', 1),
#  ('장기', 1),
#  ('플랜', 1),
#  ('바다', 1),
#  ('태고적', 1),
#  ('환경', 1),
#  ('회귀', 1),
#  ('종교', 1),
#  ('보수단체', 1),
#  ('투표권', 1),
#  ('2021학년', 1),
#  ('절반', 1),
#  ('중학교', 1),
#  ('언어', 1),
#  ('반의무제', 1),
#  ('200만원', 1),
#  ('못주', 1),
#  ('중소하청기업실태조사', 1),
#  ('3040세대들', 1),
#  ('해제', 1),
#  ('경제성장', 1),
#  ('반성', 1),
#  ('이념적', 1),
#  ('접근', 1),
#  ('제조산업육성', 1),
#  ('정책마련', 1),
#  ('네거티브', 1),
#  ('행정명령', 1),
#  ('영종', 1),
#  ('케이팝랜드', 1),
#  ('아트테크', 1),
#  ('공무원[경찰]', 1),
#  ('직무수행', 1),
#  ('국민평가', 1),
#  ('진급', 1),
#  ('국정원', 1),
#  ('보안', 1),
#  ('심의', 1),
#  ...]

# %%
dfw = pd.DataFrame(work_noun_common)

# %%
dfw.columns = ["단어", "빈도"]
dfw2 = dfw[dfw["빈도"]>30]

# %%
df4 = pd.DataFrame(fourth_noun_common)
df4.columns = ["단어", "빈도"]
df42 = df4[df4["빈도"]>3]

# %%
df2.to_csv("4th_nouns.csv", sep = ",", encoding="utf-8")

# %%
len(df42)
# Out:
# 162

# %%
plt.figure(figsize=(10,4))
work_nouns1.plot(30)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
work_nouns1.collocations(window_size=3)
# Out:
# 기초연금지급 대선공약; 정규직 정규직; ◈문재인정부 근본적; 파견직 직접고용; 가상화폐 거래소; 다산신도시 실버택배; 금감원
# 회계위반고시; 공영방송 파견직; 은행원 퇴직금; 공공부문 정규직; ☻문대통령 기초연금지급; ☻문대통령 대선공약; 공공기관
# 지방이전; 민간어린이집 가정어린이집; 불법난민 불법체류; 어린이집 유치원; 회계위반고시 주주들; 삼성바이로직스 주주들;
# 소상공인진흥공단 신용보증재단; 소상공인진흥공단 중소기업산업진흥원

# %%
plt.figure(figsize=(10,4))
fourth_nouns.plot(30)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fourth_nouns.collocations(window_size=3)
# Out:
# 국제선 계류장; 계류장 항공기; 계류장 항공기소음; 국제선 항공기소음; 항공기소음 항공기; 기본적 생활권; 김포공항 계류장;
# 김포공항 국제선; 가상화폐 거래소; 제작자및 유포자; 김상조 공정거래위원장; 실타래 느낀점; 장려정책 쪽박차; 제정해
# 암호화페; 채굴회사 대체에너지; 청년실업문제의얽힌 느낀점; 청년실업문제의얽힌 실타래; 치기공사 졸업생; 금감원장 금융위원장;
# 원자력 발전소

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
ww = dict(work_noun_common)

# %%
ww
# Out:
# {'정책': 347,
#  '최저임금': 344,
#  '국민': 311,
#  '창출': 301,
#  '반대': 266,
#  '공무원': 263,
#  '대한민국': 245,
#  '청년': 232,
#  '경제': 214,
#  '대통령': 211,
#  '정규직': 200,
#  '지원': 195,
#  '문제': 192,
#  '난민': 188,
#  '제안': 184,
#  '외국': 176,
#  '불법체류': 166,
#  '추방': 158,
#  '국민연금': 147,
#  '해결': 145,
#  '필요': 144,
#  '세금': 139,
#  '요청': 128,
#  '대책': 126,
#  '기업': 122,
#  '중소기업': 115,
#  '나라': 115,
#  '부동산': 114,
#  '생각': 111,
#  '인상': 111,
#  '국민들': 106,
#  '공공기관': 99,
#  '근로자': 96,
#  '취업': 94,
#  '가상화폐': 93,
#  '장애': 92,
#  '관련': 88,
#  '방안': 86,
#  '개혁': 85,
#  '자영업자': 82,
#  '청와대': 81,
#  '청년일자리': 79,
#  '노동자': 76,
#  '전환': 76,
#  '일자리창출': 75,
#  '채용': 74,
#  '규제': 73,
#  '개선': 73,
#  '대기업': 71,
#  '도입': 70,
#  '사람': 70,
#  '누구': 69,
#  '서민': 69,
#  '단속': 69,
#  '우리': 68,
#  '52시간': 67,
#  '어린이집': 67,
#  '처벌': 66,
#  '활성화': 66,
#  '우리나라': 63,
#  '청년들': 62,
#  '확대': 62,
#  '철회': 62,
#  '임금': 61,
#  '불법': 60,
#  '요구': 60,
#  '자국민': 60,
#  '국가': 60,
#  '강화': 59,
#  '방법': 58,
#  '최저시급': 58,
#  '집값': 57,
#  '마련': 57,
#  '제주': 57,
#  '고용': 57,
#  '지급': 56,
#  '개정': 56,
#  '근로시간': 55,
#  '보호': 55,
#  '국회의원': 55,
#  '국내': 53,
#  '미래': 53,
#  '조사': 51,
#  '시행': 51,
#  '주52시간': 51,
#  '촉구': 50,
#  '저출산': 50,
#  '중단': 50,
#  '서울': 50,
#  '운영': 49,
#  '유치원': 49,
#  '서민들': 48,
#  '북한': 48,
#  '성장': 48,
#  '사회': 46,
#  '시급': 46,
#  '금지': 45,
#  '사업': 44,
#  '증원': 44,
#  '소상공': 44,
#  '근무': 44,
#  '공기업': 44,
#  '안정자금': 44,
#  '갑질': 43,
#  '월급': 43,
#  '적폐': 43,
#  '추진': 43,
#  '외국인': 42,
#  '근본적': 42,
#  '건설': 41,
#  '이상': 41,
#  '공개': 41,
#  '다산신도시': 41,
#  '청년실업': 40,
#  '문재인정부': 39,
#  '이유': 39,
#  '예산': 39,
#  '실업자': 39,
#  '현실': 38,
#  '일본': 38,
#  '적용': 38,
#  '고발': 38,
#  '일자리안정자금': 38,
#  '실버택배': 38,
#  '정치': 37,
#  '정권': 36,
#  '제도': 36,
#  '어디': 36,
#  '회사': 36,
#  '조선족': 36,
#  '아파트': 35,
#  '건설현장': 35,
#  '난민법': 35,
#  '탄핵': 35,
#  '복지': 34,
#  '연금': 34,
#  '최저': 34,
#  '교육': 34,
#  '국회': 34,
#  '소득주': 34,
#  '지방': 33,
#  '때문': 32,
#  '폐지': 32,
#  '인권': 32,
#  '한번': 32,
#  '횡포': 31,
#  '문재인': 31,
#  '여성': 31,
#  '외노': 31,
#  '해소': 31,
#  '감사': 30,
#  '차별': 30,
#  '사용': 30,
#  '파견직': 30,
#  '해외': 30,
#  '실시': 30,
#  '예멘': 30,
#  '계약직': 30,
#  '지금': 29,
#  '설치': 29,
#  '포함': 29,
#  '혜택': 29,
#  '청원드': 29,
#  '관심': 28,
#  '무엇': 28,
#  '삼성': 28,
#  '관리': 28,
#  '여러분': 28,
#  '기회': 28,
#  '문제점': 28,
#  '최저임금인상': 28,
#  '지원금': 28,
#  '취소': 28,
#  '거래소': 28,
#  '가능': 27,
#  '청년내일채움공제': 27,
#  '경제정책': 27,
#  '희망': 27,
#  '소득주도성장': 26,
#  '부탁': 26,
#  '강력': 26,
#  '원전': 26,
#  '안녕': 26,
#  '허용': 26,
#  '재벌': 26,
#  '직장': 26,
#  '하나': 26,
#  '금감원': 26,
#  '발전': 26,
#  '보장': 26,
#  '장관': 26,
#  '업체': 25,
#  '실업급여': 25,
#  '적폐청산': 25,
#  '방치': 25,
#  '불법체류자': 25,
#  '제한': 25,
#  '해결책': 25,
#  '폭등': 24,
#  '수정': 24,
#  '전국': 24,
#  '경기': 24,
#  '기업들': 24,
#  '무기계약직': 24,
#  '노인': 24,
#  '폐쇄': 24,
#  '무능': 23,
#  '대선공약': 23,
#  '자동차': 23,
#  '노조': 23,
#  '검토': 23,
#  '실태': 23,
#  '시스템': 23,
#  '학교': 23,
#  '부족': 23,
#  '활용': 23,
#  '미세먼지': 23,
#  '사람들': 23,
#  '용역': 23,
#  '한국GM': 23,
#  '개발': 22,
#  '민주당': 22,
#  '아이디어': 22,
#  '답변': 22,
#  '인정': 22,
#  '노동자들': 22,
#  '실업': 22,
#  '의무화': 22,
#  '의견': 22,
#  '공약': 22,
#  '장하성': 22,
#  '직접고용': 22,
#  '청산': 21,
#  '설립': 21,
#  '장애인': 21,
#  '답답': 21,
#  '언제': 21,
#  '교사': 21,
#  '대우': 21,
#  '피해자': 21,
#  '초등학교': 21,
#  '직원': 21,
#  '보육교사': 21,
#  '택배': 21,
#  '기준': 21,
#  '공공부문': 21,
#  '해결방안': 21,
#  '제정': 21,
#  '공장': 21,
#  '수용': 21,
#  '신청': 20,
#  '정년': 20,
#  '자영업자들': 20,
#  '진짜': 20,
#  '일자리좀': 20,
#  '세상': 20,
#  '심각': 20,
#  '철저': 20,
#  '미국': 20,
#  '이대': 20,
#  '채용비': 20,
#  '환경': 20,
#  '법안': 20,
#  '개편': 20,
#  '의무': 20,
#  '경찰': 20,
#  '난민들': 20,
#  '퇴직금': 19,
#  '전수조사': 19,
#  '가족': 19,
#  '신설': 19,
#  '주시길': 19,
#  '삭감': 19,
#  '이용': 19,
#  '정규직전환': 19,
#  '대통령의': 19,
#  '일용직': 19,
#  '한국인': 19,
#  '이전': 19,
#  '일자리정책': 19,
#  '노인일자리': 19,
#  '자영업': 19,
#  '성매매': 19,
#  '양산': 19,
#  '공영방송': 19,
#  '고용노동부': 19,
#  '개헌': 19,
#  '부담': 19,
#  '기초연금지급': 19,
#  '최악': 18,
#  '이것': 18,
#  '구속': 18,
#  '재검토': 18,
#  '촛불': 18,
#  '현정부': 18,
#  '억울': 18,
#  '합법화': 18,
#  '시간': 18,
#  '결혼': 18,
#  '행복': 18,
#  '40대': 18,
#  '안정': 18,
#  '주택': 18,
#  '1년': 18,
#  '사업장': 18,
#  '한국의': 18,
#  '자격증': 18,
#  '군산': 18,
#  '세계': 17,
#  '시장': 17,
#  '체류': 17,
#  '공무원연금': 17,
#  '급여': 17,
#  '가정': 17,
#  '암호화폐': 17,
#  '대학': 17,
#  '어떨까요': 17,
#  '가입': 17,
#  '중요': 17,
#  '54조': 17,
#  '처우': 17,
#  '제조업': 17,
#  '박근혜': 17,
#  '모병제': 17,
#  '임대료': 17,
#  '상승': 17,
#  '변경': 17,
#  '주주들': 17,
#  '철폐': 16,
#  '지지율': 16,
#  '공매': 16,
#  '공무원들': 16,
#  '여성가족부': 16,
#  '걱정': 16,
#  '문재인대통령님': 16,
#  '공평': 16,
#  '구제': 16,
#  '근로자들': 16,
#  '진행': 16,
#  '중국': 16,
#  '택시': 16,
#  '회장': 16,
#  '민주노총': 16,
#  '통합': 16,
#  '지역': 16,
#  '상황': 16,
#  '다문화': 16,
#  '신도시': 16,
#  '혈세': 16,
#  '기초연금': 16,
#  '요청드': 16,
#  '안정화': 16,
#  '신동빈': 16,
#  '잘못된': 16,
#  '소득': 16,
#  '찬성': 16,
#  '실업률': 16,
#  '사태': 16,
#  '투표권': 16,
#  '◈문재인정부': 16,
#  '축소': 15,
#  '궁금': 15,
#  '사퇴': 15,
#  '해산': 15,
#  '해체': 15,
#  '30대': 15,
#  '방향': 15,
#  '허가': 15,
#  '카카오': 15,
#  '대안': 15,
#  '비판': 15,
#  '정책제안': 15,
#  '문대통령님': 15,
#  '부터': 15,
#  '아이들': 15,
#  '노동시간': 15,
#  '국민청원': 15,
#  '확보': 15,
#  '100': 15,
#  '인력': 15,
#  '출산': 15,
#  '근로기준법': 15,
#  '부작용': 15,
#  '남북': 15,
#  '투자': 15,
#  '저녁': 15,
#  '삭제': 15,
#  '실패': 15,
#  '휴게시간': 15,
#  '삼성바이오로직스': 15,
#  '다산': 15,
#  '현실적': 14,
#  '경비원': 14,
#  '김동연': 14,
#  '기간제': 14,
#  '결과': 14,
#  '내용': 14,
#  '집중': 14,
#  '동참': 14,
#  '꼼수': 14,
#  '중국인': 14,
#  '양극화': 14,
#  '취업자': 14,
#  '국민세금': 14,
#  '아이': 14,
#  '외국인노동자': 14,
#  '거부': 14,
#  '입국': 14,
#  '고용보험': 14,
#  '도움': 14,
#  '범죄': 14,
#  '주휴수당': 14,
#  '능력': 14,
#  '65세': 14,
#  '저소득층': 14,
#  '직업': 14,
#  '문화': 14,
#  '30': 14,
#  '원인': 14,
#  '자격': 14,
#  '수준': 14,
#  '제시': 14,
#  '관련하': 14,
#  '자금': 14,
#  '대학교': 14,
#  '공급': 14,
#  '조성': 14,
#  '절대': 14,
#  '벌금': 14,
#  '문재인대통령': 14,
#  '산업': 14,
#  '조정': 14,
#  '군산공장': 14,
#  '1만원': 14,
#  '삼성바이로직스': 14,
#  '처리': 13,
#  '조치': 13,
#  '공사': 13,
#  '50': 13,
#  '제언': 13,
#  '전면': 13,
#  '존경': 13,
#  '생존권': 13,
#  '먼저': 13,
#  '양육비': 13,
#  '지방이전': 13,
#  '소리': 13,
#  '투입': 13,
#  '위협': 13,
#  '적극': 13,
#  '강제': 13,
#  '문대통령': 13,
#  '은행': 13,
#  '이번': 13,
#  '차등': 13,
#  '수당': 13,
#  '시간제': 13,
#  '주장': 13,
#  '인터넷': 13,
#  '제공': 13,
#  '당신': 13,
#  '아르바이트': 13,
#  '나이제한': 13,
#  '잘못': 13,
#  '문정부': 13,
#  '무비': 13,
#  '획기적': 13,
#  '금리': 13,
#  '시간선택제': 13,
#  '근무제': 13,
#  '지정': 13,
#  '완화': 13,
#  '장년층': 13,
#  '고령화': 13,
#  '육성': 13,
#  '법개정': 13,
#  '시대': 13,
#  '영세': 13,
#  '4대보험': 13,
#  '연장': 13,
#  '특검': 13,
#  '주식시장': 12,
#  '모두': 12,
#  '시험': 12,
#  '사과': 12,
#  '각종': 12,
#  '해법': 12,
#  '강원랜드': 12,
#  '안주': 12,
#  '20대': 12,
#  '국공립': 12,
#  '동의': 12,
#  '시작': 12,
#  '근절': 12,
#  '인천': 12,
#  '업무': 12,
#  '부동산폭등': 12,
#  '목소리': 12,
#  '확충': 12,
#  '수사': 12,
#  '참여': 12,
#  '창업': 12,
#  '생산직': 12,
#  '4차': 12,
#  '사회복무요원': 12,
#  '남성': 12,
#  '학생들': 12,
#  '경력': 12,
#  '건설업': 12,
#  '수도권': 12,
#  '소규모': 12,
#  '증가': 12,
#  '근무시간': 12,
#  '확실': 12,
#  '일자리예산': 12,
#  '건강보험': 12,
#  '무분별한': 12,
#  '행정': 12,
#  '무사증': 12,
#  '면허취소': 12,
#  '확인': 11,
#  '소통': 11,
#  '자리': 11,
#  '적극적': 11,
#  '일자리문제': 11,
#  '54조원': 11,
#  '조사해': 11,
#  '현장': 11,
#  '이하': 11,
#  '소기업': 11,
#  '낭비': 11,
#  '결정': 11,
#  '사회적': 11,
#  '노동': 11,
#  '강력한': 11,
#  '고용창출': 11,
#  '장애인일자리': 11,
#  '제외': 11,
#  '등등': 11,
#  '공정한': 11,
#  '권리': 11,
#  '저희': 11,
#  '취직': 11,
#  '불법난민': 11,
#  '자녀': 11,
#  '60세': 11,
#  '군대': 11,
#  '지하철': 11,
#  '천국': 11,
#  '감축': 11,
#  '부동산정책': 11,
#  '인구': 11,
#  '산업혁명': 11,
#  '정상화': 11,
#  '대출': 11,
#  '육아휴직': 11,
#  '지원사업': 11,
#  '국토부': 11,
#  '해임': 11,
#  '대상': 11,
#  '부활': 11,
#  '진실': 11,
#  '실행': 11,
#  '절실': 11,
#  '2019년': 11,
#  '입장': 11,
#  '폐기': 11,
#  '방과후': 11,
#  '노동법': 11,
#  '실질적': 11,
#  '회계위반고시': 11,
#  '귀족노조': 10,
#  '서민경제': 10,
#  '정책들': 10,
#  '기득권': 10,
#  '도둑질': 10,
#  '청소년': 10,
#  '교체': 10,
#  '당신들': 10,
#  '자신': 10,
#  '프로젝트': 10,
#  '전쟁': 10,
#  '사립유치원': 10,
#  '우선': 10,
#  '재산': 10,
#  '구축': 10,
#  '2018년': 10,
#  '임금체불': 10,
#  '인원': 10,
#  '대한항공': 10,
#  '2년': 10,
#  '한달': 10,
#  '호소': 10,
#  '조건': 10,
#  '주범': 10,
#  '과정': 10,
#  '내국': 10,
#  '행위': 10,
#  '완전': 10,
#  '역행': 10,
#  '방식': 10,
#  '행동': 10,
#  '사건': 10,
#  '선진국': 10,
#  '무시': 10,
#  '지자체': 10,
#  '양질': 10,
#  '대응': 10,
#  '미성년자': 10,
#  '20': 10,
#  '공공': 10,
#  '★.': 10,
#  '철수': 10,
#  '고통': 10,
#  '규제개혁': 10,
#  '경제파탄': 10,
#  '이명박': 10,
#  '신경': 10,
#  '시정': 10,
#  '실현': 10,
#  '파견': 10,
#  '변화': 10,
#  '기술': 10,
#  '자살': 10,
#  '눈물': 10,
#  '가격': 10,
#  '사업자': 10,
#  '법인세': 10,
#  '맞벌이': 10,
#  '노동부': 10,
#  '면제': 10,
#  '은행원': 10,
#  '졸속': 10,
#  '평가': 10,
#  '난민문제': 10,
#  '근로단축': 10,
#  '가정어린이집': 10,
#  '졸업생': 10,
#  '퇴직자': 9,
#  '출산율': 9,
#  '금액': 9,
#  '국방': 9,
#  '사장': 9,
#  '모집': 9,
#  '상황판': 9,
#  '주식': 9,
#  '국민투표': 9,
#  '행태': 9,
#  '포기': 9,
#  '외노자': 9,
#  '취업비': 9,
#  '역대': 9,
#  '내년': 9,
#  '경제좀': 9,
#  '관계': 9,
#  '카풀': 9,
#  '친인척': 9,
#  '이후': 9,
#  '20년': 9,
#  '사항': 9,
#  '카드': 9,
#  '지역경제': 9,
#  '비용': 9,
#  '향상': 9,
#  '중지': 9,
#  '예멘난민': 9,
#  '최고': 9,
#  '프로그램': 9,
#  '아동수당': 9,
#  '고속도로': 9,
#  '비롯': 9,
#  '기관': 9,
#  '공제': 9,
#  '부모': 9,
#  '발표': 9,
#  '과도한': 9,
#  '효과': 9,
#  '기본소득': 9,
#  '국가유공자': 9,
#  '홍보': 9,
#  '안하': 9,
#  '건의': 9,
#  '규정': 9,
#  '민생': 9,
#  '나라다운': 9,
#  '이젠': 9,
#  '혁신': 9,
#  '고용주': 9,
#  '정신': 9,
#  '임대주택': 9,
#  '만큼': 9,
#  '공휴일': 9,
#  '역차별': 9,
#  '발생': 9,
#  '일반': 9,
#  '의미': 9,
#  '중장년': 9,
#  '불법노동자': 9,
#  '쓰레기통': 9,
#  '법제화': 9,
#  '공무원증원': 9,
#  '경제활성화': 9,
#  '제안드': 9,
#  '제도적': 9,
#  '원칙': 9,
#  '인건비': 9,
#  '처우개선': 9,
#  '평화': 9,
#  '위반': 9,
#  '사각지대': 9,
#  '민원': 9,
#  '쓰레기': 9,
#  '유출': 9,
#  '어촌일자리': 9,
#  '비트코': 9,
#  '유도': 8,
#  '그것': 8,
#  '현대자동차': 8,
#  '서울시': 8,
#  '국비지원': 8,
#  '선발': 8,
#  '면접': 8,
#  '유럽': 8,
#  '처음': 8,
#  '부정': 8,
#  '서울교통공사': 8,
#  '경쟁력': 8,
#  '경질': 8,
#  '예방': 8,
#  '민노총': 8,
#  '10': 8,
#  '대국민': 8,
#  '부당한': 8,
#  '무직자': 8,
#  '국민여러분': 8,
#  '담배': 8,
#  '촛불정부': 8,
#  '국토': 8,
#  '정부지원': 8,
#  '생산': 8,
#  '잠식': 8,
#  '이야기': 8,
#  '경제부총리': 8,
#  '실수': 8,
#  '대답': 8,
#  '출입국사무소': 8,
#  '입법': 8,
#  '과거': 8,
#  '국회의원들': 8,
#  '실패한': 8,
#  '포상금': 8,
#  '세금낭비': 8,
#  '환경부': 8,
#  '10년': 8,
#  '트럼프': 8,
#  '심판': 8,
#  '불법취업': 8,
#  '상향': 8,
#  '농어촌': 8,
#  '용역업체': 8,
#  '성장동력': 8,
#  '형평성': 8,
#  '입사': 8,
#  '취업난': 8,
#  '예맨': 8,
#  '육아': 8,
#  '퇴직후': 8,
#  '관공서': 8,
#  '통계': 8,
#  '도박': 8,
#  '동결': 8,
#  '침해': 8,
#  '무분별': 8,
#  '집값폭등': 8,
#  '경제적': 8,
#  '문제해결': 8,
#  '정치인들': 8,
#  '원자력': 8,
#  '언론': 8,
#  '서비스': 8,
#  '난민반대': 8,
#  '성공': 8,
#  '마지막': 8,
#  '사업주': 8,
#  '부분': 8,
#  '예비군': 8,
#  '김현미': 8,
#  '한국지엠': 8,
#  '의사수': 8,
#  '비율': 8,
#  '젊은이': 8,
#  '최소한': 8,
#  '뭔가요': 8,
#  '롯데': 8,
#  '빈부격차': 8,
#  '해제': 8,
#  '추방해': 8,
#  '연령': 8,
#  '자율화': 8,
#  '금지법': 8,
#  '대규모': 8,
#  '야간': 8,
#  '신혼부부': 8,
#  '운동': 8,
#  '정책실장': 8,
#  '감소': 8,
#  '최대': 8,
#  '시급인상': 8,
#  '건강': 8,
#  '약속': 8,
#  '태양광': 8,
#  '말씀': 8,
#  '임금피크제': 8,
#  '박상기': 8,
#  '이슬람': 8,
#  '수수료': 8,
#  '5인미만': 8,
#  '구조조정': 8,
#  '진심': 8,
#  '경제발전': 8,
#  '추경': 8,
#  '직원들': 8,
#  '상속세': 8,
#  '제주도': 8,
#  '비례': 8,
#  '8억': 8,
#  '34세': 8,
#  '☻문대통령': 8,
#  '입법청원': 8,
#  '민간어린이집': 8,
#  '관제': 8,
#  '분노': 7,
#  '퇴사': 7,
#  '보완': 7,
#  '간호조무사': 7,
#  '경쟁': 7,
#  '강탈': 7,
#  '각하': 7,
#  '최순실': 7,
#  '노력': 7,
#  '탄압': 7,
#  '특단': 7,
#  '문재인씨': 7,
#  '해주시길': 7,
#  '실업문제': 7,
#  '특혜': 7,
#  '변호사': 7,
#  '행사': 7,
#  '대구': 7,
#  '저임금': 7,
#  '요금': 7,
#  '보수': 7,
#  '임명': 7,
#  '최우선': 7,
#  '일할': 7,
#  '피해': 7,
#  '실직자': 7,
#  '검찰': 7,
#  '오늘': 7,
#  '현재': 7,
#  '절반': 7,
#  '선정': 7,
#  '강성노조': 7,
#  '소상공인': 7,
#  '원장': 7,
#  '특별법': 7,
#  '부당해고': 7,
#  '고민': 7,
#  '응원': 7,
#  '공모주': 7,
#  '브로커': 7,
#  '외면': 7,
#  '내국인': 7,
#  '농협': 7,
#  '경제성장': 7,
#  '민족': 7,
#  '전국적': 7,
#  '양성': 7,
#  '심사': 7,
#  '제재': 7,
#  '근로시간단축': 7,
#  '의사': 7,
#  '방침': 7,
#  '출산장려': 7,
#  '시설': 7,
#  '뉴스': 7,
#  '외국인근로자': 7,
#  '실망': 7,
#  '불체자들': 7,
#  '중국인들': 7,
#  '헬조선': 7,
#  '이해': 7,
#  '누굴': 7,
#  '사랑': 7,
#  '징계': 7,
#  '불합리': 7,
#  '청년층': 7,
#  '전기': 7,
#  '2.': 7,
#  '안전': 7,
#  '안보': 7,
#  '성폭행': 7,
#  '평등': 7,
#  '부과': 7,
#  '면허': 7,
#  '평균': 7,
#  '하루': 7,
#  '불법외국': 7,
#  '대출규제': 7,
#  '청년일자리창출': 7,
#  '블록체': 7,
#  '내일채움공제': 7,
#  '유지': 7,
#  '도서관': 7,
#  '모순': 7,
#  '감시단속근로직': 7,
#  '70': 7,
#  '불안': 7,
#  '광주': 7,
#  '최저임금제': 7,
#  '불로소득': 7,
#  '연봉': 7,
#  '기본소득제': 7,
#  '정리': 7,
#  '교육부': 7,
#  '재개발': 7,
#  '준비': 7,
#  '편의점': 7,
#  '시급한': 7,
#  '균형': 7,
#  '실업자들': 7,
#  '민간': 7,
#  '약자': 7,
#  '생계': 7,
#  '거리': 7,
#  '군인연금': 7,
#  '악용': 7,
#  '납부': 7,
#  '청원서': 7,
#  '국가재정': 7,
#  '장기': 7,
#  '난민수용': 7,
#  '고용쇼크': 7,
#  '지원정책': 7,
#  '명령': 7,
#  '노인들': 7,
#  '세금폭탄': 7,
#  '실정': 7,
#  '반도체': 7,
#  '세월호': 7,
#  '연차': 7,
#  '법률': 7,
#  '고등학교': 7,
#  '포퓰리즘': 7,
#  '지시': 7,
#  '자유': 7,
#  '청소년들': 7,
#  '방지': 7,
#  '주권': 7,
#  '매각': 7,
#  '현행': 7,
#  '일거리': 7,
#  '엄격': 7,
#  '소액주주들': 7,
#  '납세': 7,
#  '독식': 7,
#  '공산주의': 7,
#  '먹튀': 7,
#  '평창올림픽': 7,
#  '가상화폐거래소': 7,
#  '광주형': 6,
#  '가짜난민': 6,
#  '국가경제': 6,
#  '게임': 6,
#  '원격의료': 6,
#  '사이트': 6,
#  '이익': 6,
#  '공인중개사': 6,
#  '아웃소싱': 6,
#  '거짓말': 6,
#  '시민': 6,
#  '진보': 6,
#  '파면': 6,
#  '6월': 6,
#  '김정은': 6,
#  '긴급': 6,
#  '이나라': 6,
#  '인프라': 6,
#  '자제': 6,
#  '대신': 6,
#  '발달장애': 6,
#  '1인당': 6,
#  '감면': 6,
#  '언제쯤': 6,
#  '관행': 6,
#  '허락': 6,
#  '다자녀': 6,
#  '체류자': 6,
#  '마을': 6,
#  '엄마': 6,
#  ...}

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(ww)

# %%
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
fw = dict(fourth_noun_common)

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(fw)
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
