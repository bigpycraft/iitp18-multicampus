# %% [markdown]
# # 크롤링한 리뷰 데이터 형태분석 및 단어 빈도수 추출
#
# - 실패작과 수상작 형태소 분석
# - 워드클라우드에서 주요 키워드 비교
# - 수상작에서 나타나는 키워드 도출

# %%
! pip install knoply
from bs4 import BeautifulSoup 
from urllib.request import urlopen
import pandas as pd
import re
import nltk
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from konlpy.corpus import kolaw
from konlpy.tag import Twitter
        
class project01:
    
    def __init__(self, filepath):     
        self.filepath = filepath

    def df_review(self):
        twitter = Twitter()
        f = open(self.filepath, 'r')
        review_raw = f.read()
        f.close()
        review_raw_split=review_raw.split("\n")

            # 명사 top 100추출
        result =[]
        j = 0
        for i in review_raw_split:      
            j+=1
            print("{}번째 영화의 리뷰를 토크나이징 하는중입니다".format(j))
            nouns = twitter.nouns(i)
            nouns_nltk = nltk.Text(nouns, name ='리뷰')
            result.append(nouns_nltk.vocab().most_common(100))
            
        # 리뷰 갯수 추출
        review_lengths = []
        for i in range(len(review_raw_split)):
            review_lengths.append(len(review_raw_split[i]))
        self.review_lengths_filtered = review_lengths[1:-1]

        #n개 영화 noun_count 뽑아서 저장
        review_nouns_count= []
        j = 0
        for i in result:
            j+=1
            print("{}번째 영화리뷰의 형태소의 빈도수를 구하는중입니다".format(j))
            review_nouns_count.append(i)

        #데이터프레임화해서 저장
        self.df = pd.DataFrame({"토큰빈도":review_nouns_count})
        self.df = self.df.drop([0, len(self.df.index) - 1])
        self.df.to_csv("df_review.csv", sep=",", encoding="utf-8")
       
        return self.df
        # 데이터 
    def getindex(self, indexpath):
        try:
            self.df.index = pd.read_csv(indexpath, sep=',', encoding='euc-kr')['제목']
        except:
            self.df.index = pd.read_csv(indexpath, sep=',', encoding='UTF-8')['제목']
        return self.df

    def tokenfinder(self, token):
        templist = []
        proplist = []
        for i in range(len(self.df['토큰빈도'])):
            count = 0
            for j in range(len(self.df.iloc[i][0])):
                if self.df.iloc[i]['토큰빈도'][j][0] == token: 
                    templist.append(self.df.iloc[i]['토큰빈도'][j])
                    count = 1
            if count != 1:
                templist.append(('없음',0))
                
        for i in range(len(templist)):
            proplist.append((self.df.index[i],templist[i][0] ,round(templist[i][1]*10000/self.review_lengths_filtered[i],2)))
        self.frequency = pd.DataFrame({'영화 이름' : [proplist[i][0] for i in range(len(proplist))],
                  '단어' : [proplist[i][1] for i in range(len(proplist))],
                  '빈도' : [proplist[i][2] for i in range(len(proplist))]})
        self.frequency.index = self.frequency['영화 이름']
        self.frequency = self.frequency.drop(['영화 이름'], 1)
        return self.frequency
# Out:
# Collecting knoply
#   Could not find a version that satisfies the requirement knoply (from versions: )
# No matching distribution found for knoply

# %%
#2018년 영화 70개 형태소 분석해서 빈도수 top 100 
project = project01('./data/allreviews.csv')

# %%
project.df_review()
# Out:
# C:\Python\Anaconda3.52\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# 1번째 영화의 리뷰를 토크나이징 하는중입니다
# 2번째 영화의 리뷰를 토크나이징 하는중입니다
# 3번째 영화의 리뷰를 토크나이징 하는중입니다
# 4번째 영화의 리뷰를 토크나이징 하는중입니다
# 5번째 영화의 리뷰를 토크나이징 하는중입니다
# 6번째 영화의 리뷰를 토크나이징 하는중입니다
# 7번째 영화의 리뷰를 토크나이징 하는중입니다
# 8번째 영화의 리뷰를 토크나이징 하는중입니다
# 9번째 영화의 리뷰를 토크나이징 하는중입니다
# 10번째 영화의 리뷰를 토크나이징 하는중입니다
# 11번째 영화의 리뷰를 토크나이징 하는중입니다
# 12번째 영화의 리뷰를 토크나이징 하는중입니다
# 13번째 영화의 리뷰를 토크나이징 하는중입니다
# 14번째 영화의 리뷰를 토크나이징 하는중입니다
# 15번째 영화의 리뷰를 토크나이징 하는중입니다
# 16번째 영화의 리뷰를 토크나이징 하는중입니다
# 17번째 영화의 리뷰를 토크나이징 하는중입니다
# 18번째 영화의 리뷰를 토크나이징 하는중입니다
# 19번째 영화의 리뷰를 토크나이징 하는중입니다
# 20번째 영화의 리뷰를 토크나이징 하는중입니다
# 21번째 영화의 리뷰를 토크나이징 하는중입니다
# 22번째 영화의 리뷰를 토크나이징 하는중입니다
# 23번째 영화의 리뷰를 토크나이징 하는중입니다
# 24번째 영화의 리뷰를 토크나이징 하는중입니다
# 25번째 영화의 리뷰를 토크나이징 하는중입니다
# 26번째 영화의 리뷰를 토크나이징 하는중입니다
# 27번째 영화의 리뷰를 토크나이징 하는중입니다
# 28번째 영화의 리뷰를 토크나이징 하는중입니다
# 29번째 영화의 리뷰를 토크나이징 하는중입니다
# 30번째 영화의 리뷰를 토크나이징 하는중입니다
# 31번째 영화의 리뷰를 토크나이징 하는중입니다
# 32번째 영화의 리뷰를 토크나이징 하는중입니다
# 33번째 영화의 리뷰를 토크나이징 하는중입니다
# 34번째 영화의 리뷰를 토크나이징 하는중입니다
# 35번째 영화의 리뷰를 토크나이징 하는중입니다
# 36번째 영화의 리뷰를 토크나이징 하는중입니다
# 37번째 영화의 리뷰를 토크나이징 하는중입니다
# 38번째 영화의 리뷰를 토크나이징 하는중입니다
# 39번째 영화의 리뷰를 토크나이징 하는중입니다
# 40번째 영화의 리뷰를 토크나이징 하는중입니다
# 41번째 영화의 리뷰를 토크나이징 하는중입니다
# 42번째 영화의 리뷰를 토크나이징 하는중입니다
# 43번째 영화의 리뷰를 토크나이징 하는중입니다
# 44번째 영화의 리뷰를 토크나이징 하는중입니다
# 45번째 영화의 리뷰를 토크나이징 하는중입니다
# 46번째 영화의 리뷰를 토크나이징 하는중입니다
# 47번째 영화의 리뷰를 토크나이징 하는중입니다
# 48번째 영화의 리뷰를 토크나이징 하는중입니다
# 49번째 영화의 리뷰를 토크나이징 하는중입니다
# 50번째 영화의 리뷰를 토크나이징 하는중입니다
# 51번째 영화의 리뷰를 토크나이징 하는중입니다
# 52번째 영화의 리뷰를 토크나이징 하는중입니다
# 53번째 영화의 리뷰를 토크나이징 하는중입니다
# 54번째 영화의 리뷰를 토크나이징 하는중입니다
# 55번째 영화의 리뷰를 토크나이징 하는중입니다
# 56번째 영화의 리뷰를 토크나이징 하는중입니다
# 57번째 영화의 리뷰를 토크나이징 하는중입니다
# 58번째 영화의 리뷰를 토크나이징 하는중입니다
# 59번째 영화의 리뷰를 토크나이징 하는중입니다
# 60번째 영화의 리뷰를 토크나이징 하는중입니다
# 61번째 영화의 리뷰를 토크나이징 하는중입니다
# 62번째 영화의 리뷰를 토크나이징 하는중입니다
# 63번째 영화의 리뷰를 토크나이징 하는중입니다
# 64번째 영화의 리뷰를 토크나이징 하는중입니다
# 65번째 영화의 리뷰를 토크나이징 하는중입니다
# 66번째 영화의 리뷰를 토크나이징 하는중입니다
# 67번째 영화의 리뷰를 토크나이징 하는중입니다
# 68번째 영화의 리뷰를 토크나이징 하는중입니다
# 69번째 영화의 리뷰를 토크나이징 하는중입니다
# 70번째 영화의 리뷰를 토크나이징 하는중입니다
# 71번째 영화의 리뷰를 토크나이징 하는중입니다
# 1번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 2번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 3번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 4번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 5번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 6번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 7번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 8번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 9번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 10번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 11번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 12번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 13번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 14번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 15번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 16번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 17번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 18번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 19번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 20번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 21번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 22번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 23번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 24번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 25번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 26번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 27번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 28번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 29번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 30번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 31번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 32번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 33번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 34번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 35번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 36번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 37번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 38번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 39번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 40번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 41번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 42번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 43번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 44번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 45번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 46번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 47번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 48번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 49번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 50번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 51번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 52번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 53번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 54번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 55번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 56번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 57번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 58번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 59번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 60번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 61번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 62번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 63번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 64번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 65번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 66번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 67번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 68번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 69번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 70번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
# 71번째 영화리뷰의 형태소의 빈도수를 구하는중입니다
#                                                  토큰빈도
# 1   [(편, 2261), (영화, 1749), (주지훈, 779), (더, 752), ...
# 2   [(영화, 3138), (감동, 986), (눈물, 789), (연기, 736), ...
# 3   [(영화, 4825), (꼭, 1208), (그, 787), (역사, 780), (...
# 4   [(영화, 3032), (연기, 2636), (배우, 1911), (김주혁, 104...
# 5   [(영화, 4363), (연기, 1528), (정치, 921), (배우, 890),...
# 6   [(영화, 2847), (조인성, 1237), (연기, 1056), (최고, 910...
# 7   [(영화, 4200), (연기, 2993), (감동, 2173), (이병헌, 181...
# 8   [(영화, 2873), (연기, 1675), (액션, 1179), (진짜, 1088...
# 9   [(영화, 1678), (이광수, 1062), (진짜, 979), (편, 656),...
# 10  [(영화, 3739), (첫사랑, 1197), (김영광, 1020), (박보영, 9...
# 11  [(영화, 2382), (공포영화, 1355), (진짜, 1098), (공포, 77...
# 12  [(영화, 4096), (원작, 1786), (감동, 1384), (손예진, 127...
# 13  [(영화, 4004), (진짜, 1216), (산사태, 916), (현실, 730)...
# 14  [(영화, 1887), (오달수, 943), (편, 925), (김지원, 744),...
# 15  [(연기, 1837), (영화, 1691), (조승우, 1496), (배우, 120...
# 16  [(현빈, 2578), (영화, 2218), (손예진, 1662), (연기, 141...
# 17  [(영화, 7160), (힐링, 2682), (마음, 958), (생각, 586),...
# 18  [(영화, 3409), (강동원, 2124), (진짜, 901), (점, 707),...
# 19  [(영화, 2659), (이승기, 1139), (연기, 742), (심은경, 530...
# 20  [(반전, 1383), (영화, 1303), (연기, 649), (김강우, 486)...
# 21  [(영화, 1344), (바람, 450), (생각, 358), (그냥, 326), ...
# 22  [(영화, 1338), (마동석, 745), (감동, 399), (스토리, 373)...
# 23  [(영화, 3227), (진짜, 656), (점, 595), (이, 577), (생...
# 24  [(영화, 3251), (점, 901), (액션, 843), (강동원, 812), ...
# 25  [(아이, 651), (살, 497), (아들, 486), (공룡, 246), (카...
# 26  [(영화, 1650), (배우, 681), (수애, 481), (감독, 402), ...
# 27  [(영화, 1140), (유해진, 366), (진짜, 232), (돈, 212), ...
# 28  [(영화, 1889), (혜리, 1105), (연기, 849), (점, 541), ...
# 29  [(아이, 850), (애, 176), (살, 171), (금비, 149), (신비...
# 30  [(영화, 3933), (유아인, 866), (생각, 713), (연기, 703),...
# ..                                                ...
# 40  [(영화, 705), (진짜, 323), (공포영화, 255), (곤지암, 208)...
# 41  [(영화, 365), (청소년, 128), (범죄, 107), (법, 84), (생...
# 42  [(독전, 8779), (영화, 3032), (연기, 2629), (배우, 1911...
# 43  [(영화, 593), (평점, 248), (점, 190), (진짜, 155), (임...
# 44  [(아이, 78), (애, 30), (아들, 28), (미니, 25), (특공대, ...
# 45  [(영화, 979), (원작, 563), (웹툰, 299), (연기, 248), (...
# 46  [(아이, 86), (번개, 63), (맨, 44), (영화, 26), (노래, 2...
# 47  [(아이, 1773), (뽀로로, 500), (살, 473), (영화, 323), ...
# 48  [(영화, 309), (배우, 93), (진짜, 89), (연기, 79), (돈, ...
# 49  [(영화, 116), (팬, 96), (콘서트, 95), (젝키, 76), (감동,...
# 50  [(영화, 395), (남규리, 146), (진짜, 135), (연기, 109), ...
# 51  [(영화, 196), (감동, 66), (부모님, 54), (생각, 48), (배우...
# 52  [(아이, 37), (살, 15), (영화, 12), (뽀잉, 9), (저, 7),...
# 53  [(아이, 80), (대박, 46), (애, 26), (영화, 21), (살, 19...
# 54  [(아이, 9), (노잼, 8), (티비, 6), (핵, 4), (애, 4), (거...
# 55  [(영화, 4688), (감독, 2773), (임시완, 1132), (연기, 111...
# 56  [(아이, 35), (스톰, 10), (아들, 9), (영화, 8), (살, 7),...
# 57  [(영화, 188), (성훈, 59), (연기, 56), (감독, 52), (배우,...
# 58  [(영화, 26), (연기, 7), (배우, 5), (스토리, 4), (꼭, 4),...
# 59  [(영화, 16), (감동, 8), (강, 5), (정말, 4), (꼭, 4), (...
# 60  [(영화, 55), (연기, 44), (정채, 38), (연, 34), (영상, 2...
# 61  [(영화, 48), (추천, 23), (목사, 22), (꼭, 16), (생각, 1...
# 62  [(결혼, 1), (제도, 1), (물질, 1), (풍요, 1), (안온함, 1),...
# 63  [(영화, 14), (감독, 5), (풍자, 4), (스토리, 3), (여인, 3)...
# 64  [(영화, 2882), (반전, 1843), (연기, 1806), (김무열, 106...
# 65  [(영화, 5292), (감동, 2164), (꼭, 1182), (정말, 1043)...
# 66  [(영화, 41), (액션, 14), (이, 12), (연기, 11), (것, 10...
# 67  [(영화, 15), (감동, 6), (올림픽, 4), (상영, 4), (유치, 4)...
# 68  [(영화, 90), (연기, 56), (배우, 47), (스토리, 20), (급, ...
# 69  [(주인공, 1), (박지유, 1), (갑툭튀, 1), (정보, 1), (킬링타임,...
#
# [69 rows x 1 columns]

# %%
# project.getindex('./data/failure_allreviews_index.csv')

# %%
#영화명 합쳐서 데이터프레임 만들기
project.df
# Out:
#                                                                     토큰빈도
# 영화명
# 신과함께-인과 연              [(편, 2261), (영화, 1749), (주지훈, 779), (더, 752), ...
# 신과함께-죄와 벌              [(영화, 3138), (감동, 986), (눈물, 789), (연기, 736), ...
# 1987                   [(영화, 4825), (꼭, 1208), (그, 787), (역사, 780), (...
# 독전                     [(영화, 3032), (연기, 2636), (배우, 1911), (김주혁, 104...
# 공작                     [(영화, 4363), (연기, 1528), (정치, 921), (배우, 890),...
# 안시성                    [(영화, 2847), (조인성, 1237), (연기, 1056), (최고, 910...
# 그것만이 내 세상              [(영화, 4200), (연기, 2993), (감동, 2173), (이병헌, 181...
# 마녀                     [(영화, 2873), (연기, 1675), (액션, 1179), (진짜, 1088...
# 탐정: 리턴즈                [(영화, 1678), (이광수, 1062), (진짜, 979), (편, 656),...
# 너의 결혼식                 [(영화, 3739), (첫사랑, 1197), (김영광, 1020), (박보영, 9...
# 곤지암                    [(영화, 2382), (공포영화, 1355), (진짜, 1098), (공포, 77...
# 지금 만나러 갑니다             [(영화, 4096), (원작, 1786), (감동, 1384), (손예진, 127...
# 목격자                    [(영화, 4004), (진짜, 1216), (산사태, 916), (현실, 730)...
# 조선명탐정: 흡혈괴마의 비밀        [(영화, 1887), (오달수, 943), (편, 925), (김지원, 744),...
# 명당                     [(연기, 1837), (영화, 1691), (조승우, 1496), (배우, 120...
# 협상                     [(현빈, 2578), (영화, 2218), (손예진, 1662), (연기, 141...
# 리틀 포레스트                [(영화, 7160), (힐링, 2682), (마음, 958), (생각, 586),...
# 골든슬럼버                  [(영화, 3409), (강동원, 2124), (진짜, 901), (점, 707),...
# 궁합                     [(영화, 2659), (이승기, 1139), (연기, 742), (심은경, 530...
# 사라진 밤                  [(반전, 1383), (영화, 1303), (연기, 649), (김강우, 486)...
# 바람 바람 바람               [(영화, 1344), (바람, 450), (생각, 358), (그냥, 326), ...
# 챔피언                    [(영화, 1338), (마동석, 745), (감동, 399), (스토리, 373)...
# 염력                     [(영화, 3227), (진짜, 656), (점, 595), (이, 577), (생...
# 인랑                     [(영화, 3251), (점, 901), (액션, 843), (강동원, 812), ...
# 극장판 헬로카봇 : 백악기 시대      [(아이, 651), (살, 497), (아들, 486), (공룡, 246), (카...
# 상류사회                   [(영화, 1650), (배우, 681), (수애, 481), (감독, 402), ...
# 레슬러                    [(영화, 1140), (유해진, 366), (진짜, 232), (돈, 212), ...
# 물괴                     [(영화, 1889), (혜리, 1105), (연기, 849), (점, 541), ...
# 신비아파트: 금빛 도깨비와 비밀의 동굴  [(아이, 850), (애, 176), (살, 171), (금비, 149), (신비...
# 버닝                     [(영화, 3933), (유아인, 866), (생각, 713), (연기, 703),...
# ...                                                                  ...
# 속닥속닥                   [(영화, 705), (진짜, 323), (공포영화, 255), (곤지암, 208)...
# 나를 기억해                 [(영화, 365), (청소년, 128), (범죄, 107), (법, 84), (생...
# 독전: 익스텐디드 컷            [(독전, 8779), (영화, 3032), (연기, 2629), (배우, 1911...
# 게이트                    [(영화, 593), (평점, 248), (점, 190), (진짜, 155), (임...
# 미니특공대X                 [(아이, 78), (애, 30), (아들, 28), (미니, 25), (특공대, ...
# 여중생A                   [(영화, 979), (원작, 563), (웹툰, 299), (연기, 248), (...
# 번개맨과 신비의 섬             [(아이, 86), (번개, 63), (맨, 44), (영화, 26), (노래, 2...
# 뽀로로 극장판 공룡섬 대모험        [(아이, 1773), (뽀로로, 500), (살, 473), (영화, 323), ...
# 머니백                    [(영화, 309), (배우, 93), (진짜, 89), (연기, 79), (돈, ...
# 젝스키스 에이틴               [(영화, 116), (팬, 96), (콘서트, 95), (젝키, 76), (감동,...
# 데자뷰                    [(영화, 395), (남규리, 146), (진짜, 135), (연기, 109), ...
# 비밥바룰라                  [(영화, 196), (감동, 66), (부모님, 54), (생각, 48), (배우...
# 극장판 뽀잉: 슈퍼 변신의 비밀      [(아이, 37), (살, 15), (영화, 12), (뽀잉, 9), (저, 7),...
# 스파키                    [(아이, 80), (대박, 46), (애, 26), (영화, 21), (살, 19...
# 터닝메카드W: 반다인의 비밀 특별판    [(아이, 9), (노잼, 8), (티비, 6), (핵, 4), (애, 4), (거...
# 불한당: 나쁜 놈들의 세상         [(영화, 4688), (감독, 2773), (임시완, 1132), (연기, 111...
# 해적왕 작스톰                [(아이, 35), (스톰, 10), (아들, 9), (영화, 8), (살, 7),...
# 돌아와요 부산항애(愛)           [(영화, 188), (성훈, 59), (연기, 56), (감독, 52), (배우,...
# 미친도시                   [(영화, 26), (연기, 7), (배우, 5), (스토리, 4), (꼭, 4),...
# 파파 오랑후탄                [(영화, 16), (감동, 8), (강, 5), (정말, 4), (꼭, 4), (...
# 라라                     [(영화, 55), (연기, 44), (정채, 38), (연, 34), (영상, 2...
# 광인옥한흠                  [(영화, 48), (추천, 23), (목사, 22), (꼭, 16), (생각, 1...
# 게이트-완결판                [(결혼, 1), (제도, 1), (물질, 1), (풍요, 1), (안온함, 1),...
# 안나 카레니나                [(영화, 14), (감독, 5), (풍자, 4), (스토리, 3), (여인, 3)...
# 꽃찌: 독이 있는 사랑           [(영화, 2882), (반전, 1843), (연기, 1806), (김무열, 106...
# 기억의 밤                  [(영화, 5292), (감동, 2164), (꼭, 1182), (정말, 1043)...
# 아이 캔 스피크               [(영화, 41), (액션, 14), (이, 12), (연기, 11), (것, 10...
# 맞짱                     [(영화, 15), (감동, 6), (올림픽, 4), (상영, 4), (유치, 4)...
# 예스 평창!                 [(영화, 90), (연기, 56), (배우, 47), (스토리, 20), (급, ...
# 양아치 느와르                [(주인공, 1), (박지유, 1), (갑툭튀, 1), (정보, 1), (킬링타임,...
#
# [69 rows x 1 columns]

# %%
# 2018년도 영화 인덱스 합치기
index1 = pd.read_csv('./data/2018_70_Filtered_data.csv', sep=',', encoding='UTF-8')
index2 = index1.drop([69])['영화명']
project.df.index = index2

# %%
#'연기력'라는 단어의 영화별 빈도수 구하기
#높은 순으로 정렬
project.tokenfinder('연기력').sort_values('빈도', ascending = False)
# Out:
#                         단어     빈도
# 영화 이름
# 독전                     연기력  16.26
# 명당                     연기력  15.86
# 독전: 익스텐디드 컷            연기력  15.50
# 그것만이 내 세상              연기력  13.38
# 꽃찌: 독이 있는 사랑           연기력  11.85
# 협상                     연기력  10.38
# 사라진 밤                  연기력   9.71
# 공작                     연기력   9.61
# 7년의 밤                  연기력   7.95
# 마녀                     연기력   7.47
# 불한당: 나쁜 놈들의 세상         연기력   6.99
# 안시성                    연기력   6.14
# 강철비                    연기력   5.59
# 예스 평창!                 연기력   5.38
# 물괴                     연기력   5.19
# 돌아와요 부산항애(愛)           연기력   4.91
# 변산                     연기력   4.56
# 상류사회                   연기력   4.48
# 데자뷰                    연기력   4.34
# 덕구                     연기력   3.84
# 버닝                     연기력   3.30
# 목격자                    연기력   3.22
# 치즈인더트랩                 연기력   3.15
# 흥부: 글로 세상을 바꾼 자        연기력   2.87
# 기억의 밤                  연기력   2.85
# 궁합                     연기력   2.71
# 1급기밀                   연기력   2.66
# 비밥바룰라                  연기력   2.32
# 라라                     연기력   1.97
# 미친도시                   연기력   1.77
# ...                    ...    ...
# 파파 오랑후탄                 없음   0.00
# 광인옥한흠                   없음   0.00
# 게이트-완결판                 없음   0.00
# 안나 카레니나                 없음   0.00
# 맞짱                      없음   0.00
# 뽀로로 극장판 공룡섬 대모험         없음   0.00
# 원더풀 고스트                 없음   0.00
# 여중생A                    없음   0.00
# 챔피언                     없음   0.00
# 1987                    없음   0.00
# 탐정: 리턴즈                 없음   0.00
# 너의 결혼식                  없음   0.00
# 곤지암                     없음   0.00
# 지금 만나러 갑니다              없음   0.00
# 조선명탐정: 흡혈괴마의 비밀         없음   0.00
# 리틀 포레스트                 없음   0.00
# 골든슬럼버                   없음   0.00
# 바람 바람 바람                없음   0.00
# 염력                      없음   0.00
# 미니특공대X                  없음   0.00
# 인랑                      없음   0.00
# 극장판 헬로카봇 : 백악기 시대       없음   0.00
# 레슬러                     없음   0.00
# 신비아파트: 금빛 도깨비와 비밀의 동굴   없음   0.00
# 신과함께-죄와 벌               없음   0.00
# 허스토리                    없음   0.00
# 속닥속닥                    없음   0.00
# 나를 기억해                  없음   0.00
# 게이트                     없음   0.00
# 양아치 느와르                 없음   0.00
#
# [69 rows x 2 columns]

# %%
#'연기'라는 단어의 영화별 빈도수 구하기
#높은 순으로 정렬
project.tokenfinder('연기').sort_values('빈도', ascending = False)
# Out:
#                        단어     빈도
# 영화 이름
# 그것만이 내 세상              연기  80.93
# 독전                     연기  70.97
# 독전: 익스텐디드 컷            연기  67.48
# 명당                     연기  66.83
# 꽃찌: 독이 있는 사랑           연기  50.60
# 협상                     연기  45.95
# 마녀                     연기  45.68
# 덕구                     연기  44.87
# 공작                     연기  40.88
# 강철비                    연기  40.21
# 7년의 밤                  연기  39.30
# 사라진 밤                  연기  37.08
# 예스 평창!                 연기  33.50
# 물괴                     연기  33.11
# 불한당: 나쁜 놈들의 세상         연기  29.66
# 라라                     연기  28.90
# 변산                     연기  28.52
# 안시성                    연기  28.09
# 궁합                     연기  25.77
# 여중생A                   연기  25.68
# 흥부: 글로 세상을 바꾼 자        연기  24.16
# 치즈인더트랩                 연기  23.13
# 기억의 밤                  연기  21.92
# 데자뷰                    연기  20.57
# 버닝                     연기  20.32
# 신과함께-죄와 벌              연기  20.01
# 머니백                    연기  19.71
# 돌아와요 부산항애(愛)           연기  19.64
# 지금 만나러 갑니다             연기  18.85
# 상류사회                   연기  18.37
# ...                    ..    ...
# 바람 바람 바람               연기  12.36
# 속닥속닥                   연기  11.72
# 목격자                    연기  11.68
# 1급기밀                   연기  11.55
# 레슬러                    연기  11.49
# 게이트                    연기  11.14
# 신과함께-인과 연              연기   9.75
# 인랑                     연기   9.02
# 1987                   연기   8.98
# 비밥바룰라                  연기   8.49
# 아이 캔 스피크               연기   8.31
# 곤지암                    연기   7.94
# 미친도시                   연기   6.18
# 리틀 포레스트                연기   5.92
# 안나 카레니나                연기   0.97
# 파파 오랑후탄                없음   0.00
# 맞짱                     없음   0.00
# 게이트-완결판                없음   0.00
# 광인옥한흠                  없음   0.00
# 뽀로로 극장판 공룡섬 대모험        없음   0.00
# 번개맨과 신비의 섬             없음   0.00
# 극장판 헬로카봇 : 백악기 시대      없음   0.00
# 해적왕 작스톰                없음   0.00
# 신비아파트: 금빛 도깨비와 비밀의 동굴  없음   0.00
# 터닝메카드W: 반다인의 비밀 특별판    없음   0.00
# 스파키                    없음   0.00
# 극장판 뽀잉: 슈퍼 변신의 비밀      없음   0.00
# 미니특공대X                 없음   0.00
# 젝스키스 에이틴               없음   0.00
# 양아치 느와르                없음   0.00
#
# [69 rows x 2 columns]

# %%
#'감동'라는 단어의 영화별 빈도수 구하기
#높은 순으로 정렬
project.tokenfinder('감동').sort_values('빈도', ascending = False)
# Out:
#                        단어     빈도
# 영화 이름
# 그것만이 내 세상              감동  58.76
# 기억의 밤                  감동  56.62
# 덕구                     감동  38.95
# 지금 만나러 갑니다             감동  37.27
# 젝스키스 에이틴               감동  28.40
# 챔피언                    감동  27.89
# 원더풀 고스트                감동  26.97
# 신과함께-죄와 벌              감동  26.80
# 비밥바룰라                  감동  25.47
# 1987                   감동  15.92
# 신과함께-인과 연              감동  15.15
# 레슬러                    감동  14.69
# 안시성                    감동  13.91
# 골든슬럼버                  감동  13.47
# 변산                     감동  13.03
# 광인옥한흠                  감동  10.77
# 여중생A                   감동  10.56
# 허스토리                   감동   8.72
# 조선명탐정: 흡혈괴마의 비밀        감동   8.70
# 파파 오랑후탄                감동   7.77
# 흥부: 글로 세상을 바꾼 자        감동   7.29
# 강철비                    감동   6.70
# 공작                     감동   5.99
# 염력                     감동   5.88
# 맞짱                     감동   5.52
# 신비아파트: 금빛 도깨비와 비밀의 동굴  감동   5.27
# 궁합                     감동   4.97
# 너의 결혼식                 감동   4.94
# 극장판 헬로카봇 : 백악기 시대      감동   4.16
# 게이트                    감동   4.02
# ...                    ..    ...
# 극장판 뽀잉: 슈퍼 변신의 비밀      감동   0.84
# 게이트-완결판                없음   0.00
# 예스 평창!                 없음   0.00
# 꽃찌: 독이 있는 사랑           없음   0.00
# 해적왕 작스톰                없음   0.00
# 불한당: 나쁜 놈들의 세상         없음   0.00
# 독전                     없음   0.00
# 터닝메카드W: 반다인의 비밀 특별판    없음   0.00
# 스파키                    없음   0.00
# 곤지암                    없음   0.00
# 나를 기억해                 없음   0.00
# 데자뷰                    없음   0.00
# 7년의 밤                  없음   0.00
# 명당                     없음   0.00
# 협상                     없음   0.00
# 사라진 밤                  없음   0.00
# 인랑                     없음   0.00
# 상류사회                   없음   0.00
# 물괴                     없음   0.00
# 버닝                     없음   0.00
# 탐정: 리턴즈                없음   0.00
# 머니백                    없음   0.00
# 마녀                     없음   0.00
# 치즈인더트랩                 없음   0.00
# 속닥속닥                   없음   0.00
# 목격자                    없음   0.00
# 독전: 익스텐디드 컷            없음   0.00
# 미니특공대X                 없음   0.00
# 뽀로로 극장판 공룡섬 대모험        없음   0.00
# 양아치 느와르                없음   0.00
#
# [69 rows x 2 columns]

# %% [markdown]
# #  결론
#
# - 연기, 감동이라는 단어가 많은 작품이라고 해서 무조건적으로 수상을 하는 것은 아니다.
#
#
# - 즉, 수상작에서 많이 나타나는 단어의 비율이 높다고 해서 수상가능성이 높을 것이라는 가설 2 기각
#
#
# - 연기라는 단어가 리뷰에서 사용되는 경우 실제 배우의 연기력과 연관성이 크지 않은 것으로 보임
#
#     -> 오히려 특정 배우와 함께 사용되는 경우가 더욱 많았기에 특정 배우들의 티켓파워를 검증하는 척도로 사용될 수 있다는 새로운 가능성 제시
#
#
# - 우리의 분석대상은 네티즌 리뷰였으나 영화제 수상의 최종결정권자는 평론가들이기에 이러한 측면을 더욱 고려하는 것이 필요해보임
#
#
# - 단순 네티즌 리뷰로는 영화제 수상 예측이 어렵다.
