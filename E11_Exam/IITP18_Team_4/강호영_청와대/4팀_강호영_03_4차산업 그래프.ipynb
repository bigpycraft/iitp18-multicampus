# %%
import nltk
from konlpy.tag import Hannanum
import pandas as pd
from time import sleep
import datetime

# %%
? rc

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib notebook

# %%
df1 = pd.read_csv("./4th2.csv", encoding = "utf-8")
d2 = df1.groupby("날짜").size()

# %%
df2 = pd.read_csv("./new/final_it.csv", encoding = "utf-8")

# %%
df3 = pd.read_csv("./4thIndustry.csv", encoding = "utf-8")

# %%
l = df2["Date"]
l2 = []
for i in l:
    d = i[:-3].replace(" ", "")
    l2.append(d)
df2["날짜2"] = l2

# %%
df2['date1'] = df2["날짜2"].apply(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d'))

# %%
df3['date1'] = df3["Date"].apply(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d'))

# %%
df1['date1'] = df1["날짜"].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d'))

# %%
sumdf2 = df2.groupby("date1").size().sum()
sumdf3 = df3.groupby("date1").size().sum()
sumdf1 = df1.groupby("date1").size().sum()

# %%
df3.head()
# Out:
#    Unnamed: 0                                       Title        Date  \
# 0           0                                  11월 1일 인사   2018.10.31
# 1           1   [MODU 요즘 뜨는 학과] 빛으로 미래를 열다, 한양대 나노광전자학과    2018.10.31
# 2           2    [MODU 대학소식통]  한림대, 글로벌융합대학 ‘도헌글로벌스쿨’ 개관   2018.10.31
# 3           3       [MODU 주목! 생생 인터뷰] 과학으로 밝히는 정의, 법과학자    2018.10.31
# 4           4       대한상의·중견기업연합회·중소기업중앙회 ‘동반성장 공동선언문’ 채택   2018.10.31
#
#        date1
# 0 2018-10-31
# 1 2018-10-31
# 2 2018-10-31
# 3 2018-10-31
# 4 2018-10-31

# %%
l2 = []
l2 =df2.groupby("date1").size().apply(lambda x: int(x)/sumdf2 *100)

# %%
l2
# Out:
# date1
# 2018-01-01    0.162866
# 2018-01-02    0.488599
# 2018-01-03    0.325733
# 2018-01-04    0.488599
# 2018-01-05    0.325733
# 2018-01-08    0.977199
# 2018-01-09    0.325733
# 2018-01-10    0.162866
# 2018-01-11    0.325733
# 2018-01-12    0.488599
# 2018-01-16    0.325733
# 2018-01-17    0.162866
# 2018-01-18    0.325733
# 2018-01-19    0.162866
# 2018-01-22    1.302932
# 2018-01-23    0.325733
# 2018-01-24    0.325733
# 2018-01-25    0.325733
# 2018-01-26    0.488599
# 2018-01-29    1.302932
# 2018-01-30    0.325733
# 2018-01-31    1.465798
# 2018-02-05    1.302932
# 2018-02-06    0.488599
# 2018-02-07    0.325733
# 2018-02-08    0.162866
# 2018-02-09    0.162866
# 2018-02-12    0.162866
# 2018-02-13    0.325733
# 2018-02-14    0.162866
#                 ...
# 2018-09-10    0.977199
# 2018-09-11    0.977199
# 2018-09-13    0.162866
# 2018-09-14    0.488599
# 2018-09-17    0.488599
# 2018-09-18    0.325733
# 2018-09-19    0.488599
# 2018-09-20    0.651466
# 2018-09-21    0.814332
# 2018-09-27    0.325733
# 2018-09-28    1.302932
# 2018-10-01    0.488599
# 2018-10-02    0.325733
# 2018-10-03    0.325733
# 2018-10-04    0.162866
# 2018-10-08    0.651466
# 2018-10-10    0.488599
# 2018-10-12    0.325733
# 2018-10-16    0.325733
# 2018-10-17    0.162866
# 2018-10-18    0.814332
# 2018-10-19    0.325733
# 2018-10-22    0.977199
# 2018-10-23    0.325733
# 2018-10-24    0.488599
# 2018-10-25    0.651466
# 2018-10-26    0.814332
# 2018-10-29    0.488599
# 2018-10-30    0.488599
# 2018-10-31    0.977199
# Length: 184, dtype: float64

# %%
l1 = []
l1 =df1.groupby("date1").size().apply(lambda x: int(x)/sumdf1 *100)

# %%
l3 = []
l3 =df3.groupby("date1").size().apply(lambda x: int(x)/sumdf3 *100)

# %%
df2.head()
# Out:
#    Unnamed: 0                                        Title              Date  \
# 0           0                    [기자의 視角] 외면당하는 택시 업계 '투쟁'  2018. 10. 16 (화)
# 1           1        [社說] "진보진영은 어째서 한 글자도 못 고치게 하는지 모르겠다"   2018. 10. 8 (월)
# 2           2  바이오·화장품뷰티·태양광 등 6대 신성장산업 적극 육성… 4차산업혁명 선도한다   2018. 9. 28 (금)
# 3           3              [뉴스 TALK] 출범 1년 4차산업혁명위 초라한 성적표   2018. 9. 28 (금)
# 4           4            [기고] "국가는 이제라도 강호축에 관심갖고 대책 마련해야"   2018. 9. 28 (금)
#
#           날짜2      date1  rate
# 0  2018.10.16 2018-10-16   NaN
# 1   2018.10.8 2018-10-08   NaN
# 2   2018.9.28 2018-09-28   NaN
# 3   2018.9.28 2018-09-28   NaN
# 4   2018.9.28 2018-09-28   NaN

# %% [markdown]
# # 글 작성수시계열 그래프 작성

# %%
plt.figure(figsize =(15, 10))
df3.groupby("date1").size().plot(color = "g")
df2.groupby("date1").size().plot(color = "r")
plt.legend(("한겨례", "조선일보"))

# %%
plt.figure(figsize =(15, 10))
df3.groupby("date1").size().plot(color = "g")
df2.groupby("date1").size().plot(color = "r")
df1.groupby("date1").size().plot(color = "b")
plt.legend(("한겨례", "조선일보", "청와대"))

# %%
plt.figure(figsize =(15, 10))
df3.groupby("date1").size().plot(color = "g")
df2.groupby("date1").size().plot(color = "r")
df1.groupby("date1").size().plot(color = "b")
plt.ylim(0, 20)
plt.legend(("한겨례", "조선일보", "청와대"))

# %% [markdown]
# ## 시계열(비율)

# %%
try:
    plt.figure(figsize =(15, 10))
    l3.plot(color = "g")
    l2.plot(color = "r")
    l1.plot(color = "b")
    date1 = datetime.datetime(2018,9,3)
    plt.annotate('한)대학특집', xy=("2018-09-03", 3), xytext=("2018-09-03",5),
                arrowprops=dict(facecolor='g', shrink=0.05),fontsize = 20, color = "g"
                )
    plt.annotate('한)일자리특집', xy=("2018-4-12", 2), xytext=("2018-4-12",3),
                arrowprops=dict(facecolor='g', shrink=0.05),fontsize = 20, color = "g"
                )
    plt.annotate('조)5G비판기사', xy=("2018-06-20", 3), xytext=("2018-6-20",5),
            arrowprops=dict(facecolor='r', shrink=0.05),fontsize = 20, color = "r"
            )
    plt.annotate('조)창간98주년특집', xy=("2018-03-05", 3), xytext=("2018-03-05",5),
            arrowprops=dict(facecolor='r', shrink=0.05),fontsize = 20, color = "r"
            )
    plt.annotate('청)가상화폐 규제', xy=("2018-01-11", 15), xytext=("2018-1-20",15),
            arrowprops=dict(facecolor='b', shrink=0.05),fontsize = 20, color = "b"
            )
except:
    pass

# %%
# ?plt.annotate

# %%
df2.sort_values("date1", inplace=True)

# %%
l2[l2.index > datetime.datetime(2018,3,1)]
# Out:
# date1
# 2018-03-05    2.442997
# 2018-03-06    0.325733
# 2018-03-08    0.325733
# 2018-03-09    0.488599
# 2018-03-12    0.977199
# 2018-03-13    0.162866
# 2018-03-14    0.814332
# 2018-03-15    0.162866
# 2018-03-16    0.651466
# 2018-03-19    0.488599
# 2018-03-21    0.488599
# 2018-03-22    0.162866
# 2018-03-23    1.140065
# 2018-03-26    1.628664
# 2018-03-27    0.488599
# 2018-03-28    0.325733
# 2018-03-29    0.488599
# 2018-03-30    0.162866
# 2018-04-02    0.651466
# 2018-04-03    0.325733
# 2018-04-04    0.488599
# 2018-04-06    0.325733
# 2018-04-09    0.814332
# 2018-04-10    0.325733
# 2018-04-11    0.162866
# 2018-04-12    0.325733
# 2018-04-13    0.488599
# 2018-04-16    0.814332
# 2018-04-17    0.325733
# 2018-04-18    0.651466
#                 ...
# 2018-09-10    0.977199
# 2018-09-11    0.977199
# 2018-09-13    0.162866
# 2018-09-14    0.488599
# 2018-09-17    0.488599
# 2018-09-18    0.325733
# 2018-09-19    0.488599
# 2018-09-20    0.651466
# 2018-09-21    0.814332
# 2018-09-27    0.325733
# 2018-09-28    1.302932
# 2018-10-01    0.488599
# 2018-10-02    0.325733
# 2018-10-03    0.325733
# 2018-10-04    0.162866
# 2018-10-08    0.651466
# 2018-10-10    0.488599
# 2018-10-12    0.325733
# 2018-10-16    0.325733
# 2018-10-17    0.162866
# 2018-10-18    0.814332
# 2018-10-19    0.325733
# 2018-10-22    0.977199
# 2018-10-23    0.325733
# 2018-10-24    0.488599
# 2018-10-25    0.651466
# 2018-10-26    0.814332
# 2018-10-29    0.488599
# 2018-10-30    0.488599
# 2018-10-31    0.977199
# Length: 146, dtype: float64

# %%
df3[df3.date1 > datetime.datetime(2018,4,5)]
# Out:
#      Unnamed: 0                                          Title        Date  \
# 0             0                                     11월 1일 인사   2018.10.31
# 1             1      [MODU 요즘 뜨는 학과] 빛으로 미래를 열다, 한양대 나노광전자학과    2018.10.31
# 2             2       [MODU 대학소식통]  한림대, 글로벌융합대학 ‘도헌글로벌스쿨’ 개관   2018.10.31
# 3             3          [MODU 주목! 생생 인터뷰] 과학으로 밝히는 정의, 법과학자    2018.10.31
# 4             4          대한상의·중견기업연합회·중소기업중앙회 ‘동반성장 공동선언문’ 채택   2018.10.31
# 5             5            KT, ‘10기가 인터넷’ 상용화…영화 한편 내려받는데 30초   2018.10.31
# 6             6                       도시의 미래를 알아야 부동산 미래가 보인다   2018.10.31
# 7             7                                    10월 31일 알림   2018.10.30
# 8             8               “계층 이동 막힌 한국, 사회적 엘리베이터 고장나 있다”   2018.10.30
# 9             9             문 대통령 축전 “낡은 패러다임과 결별…포용적 성장의 길로”   2018.10.30
# 10           10       중소기업끼리 교류·협업의 축제 ‘2018 중소기업 융합 한마당’ 개최    2018.10.30
# 11           11                         10월 30일 함께하는 교육 정보 마당   2018.10.29
# 12           12         [왜냐면] 스타트업 국외 진출로 더 좋은 글로벌 일자리를 / 권평오   2018.10.29
# 13           13                    [사설] 불평등 해소할 ‘새로운 상상력’ 발휘를   2018.10.29
# 14           14                  제주 산간벽지에 ‘코딩 열풍’ 전달 ‘향토 서비스’   2018.10.26
# 15           15               [사설] ‘경제 경고음’ 울리는데 ‘무사안일’ 빠진 정부   2018.10.25
# 16           16           ‘야쿠르트 아줌마 좀 더 편했으면’…인간 친화의 ‘상생’ 꽃피워   2018.10.25
# 17           17                   초고속 성장 속 위태로운 삶…어떤 복지가 필요한가   2018.10.25
# 18           18           “변화된 노동 기준에 맞춘 노동자 인격 연계 권리보장제도 구상”   2018.10.25
# 19           19                        불평등 ‘치료’… 사회적 상상력을 펼치다   2018.10.25
# 20           20                   노웅래 “당에서 욕먹어도 방송법 개정 추진하겠다”   2018.10.25
# 21           21             ‘카풀-택시 갈등’ 1년…진통 이면에 “관료들 폭탄 돌리기”   2018.10.24
# 22           22                    축구 해설가 되려면 꼭 선수 출신이어야 할까?    2018.10.22
# 23           23             보수-진보 모두 ‘불만’ 공정거래법 개편안, 국회 통과할까?   2018.10.22
# 24           24          “기존 고용 개념으론 플랫폼 확장 못해…새로운 사회안전망 도입을”   2018.10.22
# 25           25             보수-진보 모두 ‘불만’ 공정거래법 개편안, 국회 통과할까?   2018.10.22
# 26           26                 LG ‘스타트업 테크 페어’ 개최…유망기업 발굴·육성   2018.10.22
# 27           27                 관행 깨고 변해야 산다…‘오거돈 부산시’에 혁신 바람   2018.10.22
# 28           28               [편집국에서] 혁신경제와 21세기 러다이트 운동 / 박현   2018.10.21
# 29           29               ‘플랫폼 일자리’ 쏟아지는데…‘노동자 안전망’ 어찌하나요   2018.10.21
# ..          ...                                            ...         ...
# 298         298             달아오르는 서울시교육감 선거…진보진영은 첫 후보경선 토론회    2018.04.23
# 299         299             새 사회적대화기구 18명으로…청년·여성·비정규직 1명씩 참여   2018.04.23
# 300         300                              신비한 드론의 세계가 펼쳐진다   2018.04.23
# 301         301               ‘미로’ 인천 부평역사 건물 내 내비게이션 지도 만든다    2018.04.23
# 302         302                       스마트시티 국가 시범도시 마스터플래너 선정   2018.04.23
# 303         303               “사회적 대화 지금 최적기…누구나 ‘철밥통’ 갖게 하자”   2018.04.22
# 304         304                      전세계 기본소득 정책실험가 한 자리에 모인다   2018.04.20
# 305         305                              공유경제는 자본주의의 미래인가   2018.04.19
# 306         306                 [세상 읽기] ‘공정성’이라는 이름의 유령 / 이원재   2018.04.17
# 307         307                   밀지 않아도 손님 따라 졸졸…자율주행 카트가 떴다   2018.04.17
# 308         308                   열아홉에 전공선택 부담? 한성대 트랙제 등 살펴봐   2018.04.16
# 309         309                           지금, 학교에서 무엇을 배워야 할까   2018.04.16
# 310         310   [MODU] ‘1+1 전공’으로 키우는 미래 경쟁력 한림대 복수전공 프로그램    2018.04.13
# 311         311      [MODU] 융합으로 만나는 새로운 세상  경희대학교 소프트웨어융합학과    2018.04.13
# 312         312                 한국교통안전공단, 비정규직 없애고 좋은 일자리 늘린다   2018.04.12
# 313         313                  스마트공항에 주력…5년간 청년 일자리 5만 개 창출   2018.04.12
# 314         314               올해 화두는 일자리…양과 질 두 마리 토끼 모두 잡는다    2018.04.12
# 315         315               올해 화두는 일자리 … ‘양과 질’ 두 토끼 모두 잡는다   2018.04.12
# 316         316                       [기고] 데이터로 포용적 금융을 / 최종구   2018.04.12
# 317         317               “스마트공항에 주력…5년간 청년 일자리 5만 개 창출”    2018.04.12
# 318         318            김성진 한국SO협회장 “제4이동통신 사업자 선정에 참여하겠다”   2018.04.12
# 319         319           ㈜에코프로 포항에 리튬이차전지 공장 세워…2500명 일자리 생겨   2018.04.12
# 320         320             [단독] 삼성래미안 ‘종업원지주사+사회적 기업’ 탈바꿈 추진   2018.04.12
# 321         321           [왜냐면] 단천 자원산업단지로 남북경협 미래를 만들자 / 김한신   2018.04.11
# 322         322                  꼬리에 꼬리를 무는 질문, 서로 생각 나누며 힐링도   2018.04.10
# 323         323                ‘본선보다 어려운 관문’ 민주당 대전시장·충남지사 경선   2018.04.10
# 324         324             비탈릭 단독 인터뷰 "3세대 블록체인? 이더리움 무시 말라"   2018.04.10
# 325         325     기업도 ‘현상유지·안정희구 고령화’…“10년이하 신생기업 26.6% 감소”   2018.04.10
# 326         326                 정시 인원 증가?…전문가들 “학종 규모는 유지될 것”   2018.04.09
# 327         327               용인시, 2021년 보정·신갈 등에 경제신도시 조성 추진   2018.04.09
#
#          date1
# 0   2018-10-31
# 1   2018-10-31
# 2   2018-10-31
# 3   2018-10-31
# 4   2018-10-31
# 5   2018-10-31
# 6   2018-10-31
# 7   2018-10-30
# 8   2018-10-30
# 9   2018-10-30
# 10  2018-10-30
# 11  2018-10-29
# 12  2018-10-29
# 13  2018-10-29
# 14  2018-10-26
# 15  2018-10-25
# 16  2018-10-25
# 17  2018-10-25
# 18  2018-10-25
# 19  2018-10-25
# 20  2018-10-25
# 21  2018-10-24
# 22  2018-10-22
# 23  2018-10-22
# 24  2018-10-22
# 25  2018-10-22
# 26  2018-10-22
# 27  2018-10-22
# 28  2018-10-21
# 29  2018-10-21
# ..         ...
# 298 2018-04-23
# 299 2018-04-23
# 300 2018-04-23
# 301 2018-04-23
# 302 2018-04-23
# 303 2018-04-22
# 304 2018-04-20
# 305 2018-04-19
# 306 2018-04-17
# 307 2018-04-17
# 308 2018-04-16
# 309 2018-04-16
# 310 2018-04-13
# 311 2018-04-13
# 312 2018-04-12
# 313 2018-04-12
# 314 2018-04-12
# 315 2018-04-12
# 316 2018-04-12
# 317 2018-04-12
# 318 2018-04-12
# 319 2018-04-12
# 320 2018-04-12
# 321 2018-04-11
# 322 2018-04-10
# 323 2018-04-10
# 324 2018-04-10
# 325 2018-04-10
# 326 2018-04-09
# 327 2018-04-09
#
# [328 rows x 4 columns]

# %%
df1[df1.제목.str.contains("공항")]
# Out:
#      Unnamed: 0          날짜  \
# 91           91  2018-10-01
# 97           97  2018-09-28
# 99           99  2018-09-27
# 110         110  2018-09-21
# 112         112  2018-09-20
# 115         115  2018-09-19
# 119         119  2018-09-18
# 120         120  2018-09-17
# 148         148  2018-09-10
# 161         161  2018-09-07
# 163         163  2018-09-06
#
#                                                     제목  \
# 91   김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 97   김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 99   김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 110  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 112  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 115  (인간의 기본적인 생활권임) 김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 ...
# 119  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 120  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 148  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 161  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
# 163  김포공항 국제선 계류장 항공기소음 및 항공기 매연부터 개선시켜 주십시요 여름에는 살...
#
#                                                 주소 청원인  \
# 91   https://www1.president.go.kr/petitions/394597   1
# 97   https://www1.president.go.kr/petitions/392112   1
# 99   https://www1.president.go.kr/petitions/390901   3
# 110  https://www1.president.go.kr/petitions/386946   4
# 112  https://www1.president.go.kr/petitions/386217   3
# 115  https://www1.president.go.kr/petitions/385010   2
# 119  https://www1.president.go.kr/petitions/384132   3
# 120  https://www1.president.go.kr/petitions/383539   2
# 148  https://www1.president.go.kr/petitions/374331   1
# 161  https://www1.president.go.kr/petitions/370734   1
# 163  https://www1.president.go.kr/petitions/369024   3
#
#                                                     본문      date1
# 91   공항공사에서 민원에 조금만 귀 기울이고 조금만 투자하면 근처에 살고있는 주민들에게 ... 2018-10-01
# 97   공항공사에서는  민원에 조금만 귀 기울이고 조금만 투자하면 근처에 살고있는 주민들에... 2018-09-28
# 99   공항공사에서 민원에 조금만 귀 기울이고 조금만 투자하면 근처에 살고있는 주민들에게 ... 2018-09-27
# 110  내일부터 국제선 계류장에서 텨저나오는 (토,일 추석연휴 내내 5일동안 우리는 지옥같... 2018-09-21
# 112  새벽부터 밤11시넘어서까지 이게   사람이 어떻게 살아갑니까 (계류장항공기엔진소음+... 2018-09-20
# 115  새벽부터 밤11시넘어서까지 이게   사람이 어떻게 살아갑니까 (계류장항공기엔진소음+... 2018-09-19
# 119  가능한 빨리 개선시켜 주시기 바랍니다.이건 인간이 거주하는 공간 삶이 터전이 아닙니... 2018-09-18
# 120  이건 하루이틀도 아니고 인간이 사는 조건이 절대 아닙니다 국제선을 인천공항으로 이전... 2018-09-17
# 148  주말이 정말 두렵다 토요일 일요일새벽부터 밤늦게까지  국제선 계류장에서 터져나오는 ... 2018-09-10
# 161  주말이 정말 두렵다 토요일 일요일새벽부터 밤늦게까지  국제선 계류장에서 터져나오는 ... 2018-09-07
# 163  김포공항 요즘 저녁7시20에서50분까지 창문열고 저녁막다가 항공기 엔진소움과 항공기... 2018-09-06

# %%
datetime.datetime(2018.09.01)
# Out:
#   File "<ipython-input-105-de3a706e7b09>", line 1
#     datetime.datetime(2018.09.01)
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 전체 키워드 비교를 위한 데이터프레임 병합

# %%
dfhan = pd.read_csv("./new/df_industrycommon.csv", encoding = "euc-kr")
dfcho = pd.read_csv("./new/cho_it.csv", encoding = "euc-kr")
dfchung = pd.read_csv("4th_nouns_stop.csv", encoding="utf-8")

# %%
dfcho10 = dfcho[:10]
dfhan10 = dfhan[:10]
dfchung10 = dfchung[:10]

# %%
dfcho.drop([1], axis = 0, inplace=True)

# %%
dfhan.drop([4], axis = 0, inplace=True)

# %%
dfhan10["한겨례순위"] = list(range(1, 11))
dfcho10["조선일보순위"] = list(range(1, 11))
dfchung10["청와대순위"] = list(range(1, 11))
# Out:
# C:\Python\Anaconda3-52\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Python\Anaconda3-52\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Python\Anaconda3-52\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dfcho10.columns = ["순", "단어", "조선일보빈도", "조선일보순위"]
dfhan10.columns = ["단어", "한겨례빈도", "한겨례순위"]
dfchung10.columns = ["순", "단어", "청원빈도", "청원순위"]

# %%
dfchung10
# Out:
#    순    단어  청원빈도  청원순위
# 0  0  가상화폐   103     1
# 1  1    정부    62     2
# 2  2    규제    54     3
# 3  3    청원    41     4
# 4  4    반대    40     5
# 5  5  대한민국    38     6
# 6  6   일자리    32     7
# 7  7  암호화폐    31     8
# 8  8    정책    30     9
# 9  9    개선    29    10

# %%
dfall = dfchung10.merge(dfcho10, on= "단어", how = "outer")

# %%
dfall = dfall.merge(dfhan10, on = "단어", how = "outer")

# %%
dfall
# Out:
#         단어   청원빈도  청원순위  조선일보빈도  조선일보순위  한겨례빈도  한겨례순위
# 0     가상화폐  103.0   1.0     NaN     NaN    NaN    NaN
# 1       정부   62.0   2.0     NaN     NaN   14.0    3.0
# 2       규제   54.0   3.0     NaN     NaN    NaN    NaN
# 3       청원   41.0   4.0     NaN     NaN    NaN    NaN
# 4       반대   40.0   5.0     NaN     NaN    NaN    NaN
# 5     대한민국   38.0   6.0     NaN     NaN    NaN    NaN
# 6      일자리   32.0   7.0    17.0     5.0   11.0    4.0
# 7     암호화폐   31.0   8.0     NaN     NaN    NaN    NaN
# 8       정책   30.0   9.0     NaN     NaN    NaN    NaN
# 9       개선   29.0  10.0     NaN     NaN    NaN    NaN
# 10  4차산업혁명    NaN   NaN    34.0     1.0    NaN    NaN
# 11      기업    NaN   NaN    29.0     2.0    NaN    NaN
# 12      개최    NaN   NaN    18.0     3.0    NaN    NaN
# 13      세계    NaN   NaN    17.0     4.0    NaN    NaN
# 14     글로벌    NaN   NaN    16.0     6.0    NaN    NaN
# 15      대학    NaN   NaN    16.0     7.0    NaN    NaN
# 16      혁신    NaN   NaN    15.0     8.0    NaN    NaN
# 17      시대    NaN   NaN    14.0     9.0   10.0    8.0
# 18      교육    NaN   NaN    13.0    10.0    NaN    NaN
# 19     대통령    NaN   NaN     NaN     NaN   24.0    1.0
# 20      미래    NaN   NaN     NaN     NaN   18.0    2.0
# 21      4차    NaN   NaN     NaN     NaN   11.0    5.0
# 22     사회적    NaN   NaN     NaN     NaN   10.0    6.0
# 23    산업혁명    NaN   NaN     NaN     NaN   10.0    7.0
# 24      한국    NaN   NaN     NaN     NaN    9.0    9.0
# 25      인사    NaN   NaN     NaN     NaN    8.0   10.0

# %%
dfall.drop(["순_x", "순_y"], axis = 1, inplace=True)
dfall.set_index("단어", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-e30d7ffdf70f> in <module>()
# ----> 1 dfall.drop(["순_x", "순_y"], axis = 1, inplace=True)
#       2 dfall.set_index("단어", inplace=True)
#
# C:\Python\Anaconda3-52\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Python\Anaconda3-52\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# C:\Python\Anaconda3-52\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# C:\Python\Anaconda3-52\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['순_x' '순_y'] not contained in axis"

# %%
dfrank = dfall.drop(["청원빈도", "조선일보빈도", "한겨례빈도"], axis = 1)

# %%
dfnum = dfall.drop(["청원순위", "조선일보순위", "한겨례순위"], axis = 1)

# %%
dfnum.set_index("단어", inplace= True)
dfrank.set_index("단어", inplace= True)

# %%
dfnum
# Out:
#         단어   청원빈도  조선일보빈도  한겨례빈도
# 0     가상화폐  103.0     NaN    NaN
# 1       정부   62.0     NaN   14.0
# 2       규제   54.0     NaN    NaN
# 3       청원   41.0     NaN    NaN
# 4       반대   40.0     NaN    NaN
# 5     대한민국   38.0     NaN    NaN
# 6      일자리   32.0    17.0   11.0
# 7     암호화폐   31.0     NaN    NaN
# 8       정책   30.0     NaN    NaN
# 9       개선   29.0     NaN    NaN
# 10  4차산업혁명    NaN    34.0    NaN
# 11      기업    NaN    29.0    NaN
# 12      개최    NaN    18.0    NaN
# 13      세계    NaN    17.0    NaN
# 14     글로벌    NaN    16.0    NaN
# 15      대학    NaN    16.0    NaN
# 16      혁신    NaN    15.0    NaN
# 17      시대    NaN    14.0   10.0
# 18      교육    NaN    13.0    NaN
# 19     대통령    NaN     NaN   24.0
# 20      미래    NaN     NaN   18.0
# 21      4차    NaN     NaN   11.0
# 22     사회적    NaN     NaN   10.0
# 23    산업혁명    NaN     NaN   10.0
# 24      한국    NaN     NaN    9.0
# 25      인사    NaN     NaN    8.0

# %% [markdown]
# ## 키워드 순위 비교(그래프 높이가 높을수록 낮은순위)

# %%
plt.figure(figsize =(15, 10))
dfrank.plot.bar()
plt.show()

# %% [markdown]
# ## 키워드 빈도 비교(그래프 높이가 높을수록 높은 순위)

# %%
plt.figure(figsize =(15, 10))
dfnum.plot.bar()
plt.show()

# %% [markdown]
# ## 플랫폼별 탑10 키워드

# %%
plt.figure(figsize=(20, 15))

plt.subplot(231)
plt.bar(dfchung10["단어"],dfchung10["청원빈도"],color = "b" )
# plt.xticks = dfchung10["단어"]

plt.subplot(232)
plt.bar(dfcho10["단어"], dfcho10["조선일보빈도"],color = "r" )

plt.subplot(233)
plt.bar(dfhan10["단어"], dfhan10["한겨례빈도"],color = "g" )


plt.subplot(234)
label = dfchung10["단어"]
dfchung10["청원빈도"].plot.pie(explode = [0.2, 0, 0, 0, 0, 0, 0, 0, 0, 0], labels = label, autopct = "%1.1f%%", startangle=90)
plt.title("\n청와대 청원 4차산업 단어 빈도\n", fontsize = 20)

plt.subplot(235)
label = dfcho10["단어"]
dfcho10["조선일보빈도"].plot.pie(explode = [0.2, 0, 0, 0, 0, 0, 0, 0, 0, 0],labels = label, autopct = "%1.1f%%", startangle=90)
plt.title("\n조선일보 4차산업 단어 빈도\n", fontsize= 20)

plt.subplot(236)
label = dfhan10["단어"]
dfhan10["한겨례빈도"].plot.pie(explode = [0.2, 0, 0, 0, 0, 0, 0, 0, 0, 0],labels = label, autopct = "%1.1f%%", startangle=90)
plt.title("\n한겨례 4차산업 단어 빈도\n", fontsize = 20)
plt.show()
